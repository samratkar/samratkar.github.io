# %% [markdown]
# # **Problem Description**
#
# ---

# %% [markdown]
# # **Reinforcement Learning (RL) and OpenAI Gym**
#
# *   The set of tasks that can be solved using the means of
# reinforcement learning tools is quite broad, and each of these tasks may
# have its own code implementation.
# *   At the same time, various RL techniques
# can be applied to any RL problem.
# *   But at this point, an applicability
# problem may arise since each task can have its own implementation, and it
# can be quite challenging to implement a specific RL algorithm in a
# particular situation.
# * Gym solves this problem by unifying all reinforcement
# learning tasks.
# * OpenAI Gym is a free Python toolkit that provides developers with an environment for developing and testing learning agents for deep learning models.
#
# # **Benefits of Gym**
#
# * Gym unifies the process of testing solutions to reinforcement learning
# problems.
# * Each RL problem can have its own unique solution, which will
# allow the agent to maximize rewards.
# * It is often helpful to test several predesigned
# RL algorithms and see which one performs the best. Such brute
# force technique can provide a useful direction for developing your own
# solution or possibly applying an existing one.
# * The Gym toolkit offers a
# standard interface for all RL problems, which allows you to test various
# solution production-ready algorithms.

# %% [markdown]
# # ***Key Concept of RL***
#
# ![img3.png](data:image/png;base64,...)

# %% [markdown]
# * **Agent** is a decision-maker who defines what action to take.
#   **Examples:** Self-driving car, chess player, stock trading robot
# * **Action** is a concrete act in a surrounding environment that is taken by the
# agent. **Examples:** Turn car left, move chess pawn one cell forward, sell all
# assets
# * **Environment** is a problem context that the agent cooperates with. **Examples:** Car track, chess board, stock market
# * **State** is a position of the agent in the environment. **Examples:** Car coordinates on the track and its speed, arrangement of pieces on the chessboard, price of assets
# * **Reward** is a numerical value returned by an environment as the reaction
# to the agent's action. **Example:** To reach a goal on the car without any accidents, to win chess play, to earn more money

# %% [markdown]
# # **Execution**
#
# ---

# %% [markdown]
# # **Working With Gym**

# %% [markdown]
# **Gym Installation:** Install gym and give instruction for the output to be displayed in standard output

# %%
# pip install gymnasium

# %%
import gymnasium as gym

# %% [markdown]
# ***To view the existing Environments in Gym***

# %%
from gymnasium import envs
for e in envs.registry.values():
    print(e.id)
# Out:
# CartPole-v0
# CartPole-v1
# MountainCar-v0
# MountainCarContinuous-v0
# Pendulum-v1
# Acrobot-v1
# phys2d/CartPole-v0
# phys2d/CartPole-v1
# phys2d/Pendulum-v0
# LunarLander-v3
# LunarLanderContinuous-v3
# BipedalWalker-v3
# BipedalWalkerHardcore-v3
# CarRacing-v3
# Blackjack-v1
# FrozenLake-v1
# FrozenLake8x8-v1
# CliffWalking-v1
# CliffWalkingSlippery-v1
# Taxi-v3
# tabular/Blackjack-v0
# tabular/CliffWalking-v0
# Reacher-v2
# Reacher-v4
# Reacher-v5
# Pusher-v2
# Pusher-v4
# Pusher-v5
# InvertedPendulum-v2
# InvertedPendulum-v4
# InvertedPendulum-v5
# InvertedDoublePendulum-v2
# InvertedDoublePendulum-v4
# InvertedDoublePendulum-v5
# HalfCheetah-v2
# HalfCheetah-v3
# HalfCheetah-v4
# HalfCheetah-v5
# Hopper-v2
# Hopper-v3
# Hopper-v4
# Hopper-v5
# Swimmer-v2
# Swimmer-v3
# Swimmer-v4
# Swimmer-v5
# Walker2d-v2
# Walker2d-v3
# Walker2d-v4
# Walker2d-v5
# Ant-v2
# Ant-v3
# Ant-v4
# Ant-v5
# Humanoid-v2
# Humanoid-v3
# Humanoid-v4
# Humanoid-v5
# HumanoidStandup-v2
# HumanoidStandup-v4
# HumanoidStandup-v5
# GymV21Environment-v0
# GymV26Environment-v0

# %% [markdown]
# ***To realise the working of RL and its concepts, we will see how it is implemented in real time using Gym.***

# %% [markdown]
# The Mountain Car problem consists of a car placed stochastically at the bottom of a sinusoidal valley, with the only possible actions being the accelerations that can be applied to the car in either direction. The goal of the MDP is to strategically accelerate the car to reach the goal state on top of the right hill.

# %%
from IPython.display import Image, display

# For a public URL
display(Image(url="https://gymnasium.farama.org/_images/mountain_car.gif"))
# Out:
# <img src="https://gymnasium.farama.org/_images/mountain_car.gif"/>

# %% [markdown]
# Step 2: Import the sleep function from the time module, allowing for pauses in the code execution.
#
# ---
#
#
# Step 3: Import the Gym library, which provides a collection of environments to test reinforcement learning algorithms.
#
# ---
#
#
# Step 4: Import the random module, used for generating random numbers.

# %%
from time import sleep
import random

# %% [markdown]
# Environment Initialization - Create an instance of the Mountain car environment named env using Gym's make function. The 'MountainCar-v0' environment simulates a car climbing the mountain, with the goal of making the car to reach the goal at the right side of the mountain hill.

# %%
env = gym.make('MountainCar-v0', render_mode='human')

# %%
env.reset()
env.render()

# %% [markdown]
# Initialize the seed variable.
#
# Set the seed for the random number generator in the random module to ensure reproducibility. In other words, using this parameter makes sure that anyone who re-runs your code will get the exact same outputs.
#
# Set the seed for Gym's environment to maintain consistency in the environment's behavior across runs.

# %%
seed = 0
random.seed(seed)

# %% [markdown]
# Print the action space of the Mountain car environment, which in this case, has three possible actions: accelerate to left or accelerate to right or don't accelerate.
#
# ---
#
# 0 - Accelerate to left, 1 - Don't accelerate and 2 - Accelerate to right
#
# ---
#
# The data returned by the mountain car environment after an action is taken is shown in the following table.
# ![image-2.png](attachment:image-2.png)

# %%
print(f'Action Space: {env.action_space}')
# Out:
# Action Space: Discrete(3)

# %% [markdown]
# Action Spaces:
#
# | Action Value | Action Description                    |
# | ------------ | ------------------------------------- |
# | **0**        | Push car to the **left**              |
# | **1**        | **No push** (coast / no acceleration) |
# | **2**        | Push car to the **right**             |
#
#
# State Spaces:
#
# | Observation Index | Variable | Min Value | Max Value | Description                                 |
# | ----------------- | -------- | --------- | --------- | ------------------------------------------- |
# | **0**             | Position | -1.2      | 0.6       | Horizontal position of the car on the track |
# | **1**             | Velocity | -0.07     | 0.07      | Velocity of the car                         |
#
#
# The episode ends if either of the following happens:
# | Condition Type  | Description                                                |
# | --------------- | ---------------------------------------------------------- |
# | **Termination** | The car reaches the goal position: **position ≥ 0.5**      |
# | **Truncation**  | The episode reaches the **maximum step limit (200 steps)** |

# %% [markdown]
# Set the number of episodes (iterations) for the agent to interact with the environment.

# %%
print(env.observation_space)
# Out:
# Box([-1.2  -0.07], [0.6  0.07], (2,), float32)

# %%
episodes = 10

# %% [markdown]
# Initiate a loop to run a specified number of episodes.
#
# ---
#
# Reset the environment to its initial state at the beginning of each episode and captures the initial state.
#
# ---
#
# Initialize the variable reward_sum to keep track of the total rewards obtained in an episode.

# %%
for i in range(episodes):
    init_state = env.reset()
    reward_sum = 0

# %%
init_state
# Out:
# (array([-0.5081861,  0.       ], dtype=float32), {})

# %% [markdown]
# Start an infinite loop for each episode until a termination condition (done) is reached.
#
# ---
#
# Render the environment, allowing you to see the simulation (visual representation) of the Mountain car.
#
# ---
#
# Choose a random action (0 or 1 or 2) for the agent (accelerate left or don't accelerate or accelerate right).
#
# ---
#
# Execute the chosen action in the environment and receive the next state, reward obtained, termination status (done), and additional debug information.
#
# ---
#
# Update the total reward obtained in the current episode.
#
# ---
#
# Introduce a short delay for visualization purposes.

# %%
reward_sum=0
while True:
    env.render()
    random_action = random.randint(0, 2)
    state, reward, done,truncated,info = env.step(random_action)
    env.render()
    reward_sum += reward
    if done or truncated:
        print(f"Episode ended with total reward: {reward_sum}")
        obs, info = env.reset()
        break
    print('Reward_sum is', reward_sum)
    sleep(.01)
env.close()
# Out:
# Reward_sum is -1.0
# Reward_sum is -2.0
# Reward_sum is -3.0
# Reward_sum is -4.0
# Reward_sum is -5.0
# Reward_sum is -6.0
# Reward_sum is -7.0
# Reward_sum is -8.0
# Reward_sum is -9.0
# Reward_sum is -10.0
# Reward_sum is -11.0
# Reward_sum is -12.0
# Reward_sum is -13.0
# Reward_sum is -14.0
# Reward_sum is -15.0
# Reward_sum is -16.0
# Reward_sum is -17.0
# Reward_sum is -18.0
# Reward_sum is -19.0
# Reward_sum is -20.0
# Reward_sum is -21.0
# Reward_sum is -22.0
# Reward_sum is -23.0
# Reward_sum is -24.0
# Reward_sum is -25.0
# Reward_sum is -26.0
# Reward_sum is -27.0
# Reward_sum is -28.0
# Reward_sum is -29.0
# Reward_sum is -30.0
# Reward_sum is -31.0
# Reward_sum is -32.0
# Reward_sum is -33.0
# Reward_sum is -34.0
# Reward_sum is -35.0
# Reward_sum is -36.0
# Reward_sum is -37.0
# Reward_sum is -38.0
# Reward_sum is -39.0
# Reward_sum is -40.0
# Reward_sum is -41.0
# Reward_sum is -42.0
# Reward_sum is -43.0
# Reward_sum is -44.0
# Reward_sum is -45.0
# Reward_sum is -46.0
# Reward_sum is -47.0
# Reward_sum is -48.0
# Reward_sum is -49.0
# Reward_sum is -50.0
# Reward_sum is -51.0
# Reward_sum is -52.0
# Reward_sum is -53.0
# Reward_sum is -54.0
# Reward_sum is -55.0
# Reward_sum is -56.0
# Reward_sum is -57.0
# Reward_sum is -58.0
# Reward_sum is -59.0
# Reward_sum is -60.0
# Reward_sum is -61.0
# Reward_sum is -62.0
# Reward_sum is -63.0
# Reward_sum is -64.0
# Reward_sum is -65.0
# Reward_sum is -66.0
# Reward_sum is -67.0
# Reward_sum is -68.0
# Reward_sum is -69.0
# Reward_sum is -70.0
# Reward_sum is -71.0
# Reward_sum is -72.0
# Reward_sum is -73.0
# Reward_sum is -74.0
# Reward_sum is -75.0
# Reward_sum is -76.0
# Reward_sum is -77.0
# Reward_sum is -78.0
# Reward_sum is -79.0
# Reward_sum is -80.0
# Reward_sum is -81.0
# Reward_sum is -82.0
# Reward_sum is -83.0
# Reward_sum is -84.0
# Reward_sum is -85.0
# Reward_sum is -86.0
# Reward_sum is -87.0
# Reward_sum is -88.0
# Reward_sum is -89.0
# Reward_sum is -90.0
# Reward_sum is -91.0
# Reward_sum is -92.0
# Reward_sum is -93.0
# Reward_sum is -94.0
# Reward_sum is -95.0
# Reward_sum is -96.0
# Reward_sum is -97.0
# Reward_sum is -98.0
# Reward_sum is -99.0
# Reward_sum is -100.0
# Reward_sum is -101.0
# Reward_sum is -102.0
# Reward_sum is -103.0
# Reward_sum is -104.0
# Reward_sum is -105.0
# Reward_sum is -106.0
# Reward_sum is -107.0
# Reward_sum is -108.0
# Reward_sum is -109.0
# Reward_sum is -110.0
# Reward_sum is -111.0
# Reward_sum is -112.0
# Reward_sum is -113.0
# Reward_sum is -114.0
# Reward_sum is -115.0
# Reward_sum is -116.0
# Reward_sum is -117.0
# Reward_sum is -118.0
# Reward_sum is -119.0
# Reward_sum is -120.0
# Reward_sum is -121.0
# Reward_sum is -122.0
# Reward_sum is -123.0
# Reward_sum is -124.0
# Reward_sum is -125.0
# Reward_sum is -126.0
# Reward_sum is -127.0
# Reward_sum is -128.0
# Reward_sum is -129.0
# Reward_sum is -130.0
# Reward_sum is -131.0
# Reward_sum is -132.0
# Reward_sum is -133.0
# Reward_sum is -134.0
# Reward_sum is -135.0
# Reward_sum is -136.0
# Reward_sum is -137.0
# Reward_sum is -138.0
# Reward_sum is -139.0
# Reward_sum is -140.0
# Reward_sum is -141.0
# Reward_sum is -142.0
# Reward_sum is -143.0
# Reward_sum is -144.0
# Reward_sum is -145.0
# Reward_sum is -146.0
# Reward_sum is -147.0
# Reward_sum is -148.0
# Reward_sum is -149.0
# Reward_sum is -150.0
# Reward_sum is -151.0
# Reward_sum is -152.0
# Reward_sum is -153.0
# Reward_sum is -154.0
# Reward_sum is -155.0
# Reward_sum is -156.0
# Reward_sum is -157.0
# Reward_sum is -158.0
# Reward_sum is -159.0
# Reward_sum is -160.0
# Reward_sum is -161.0
# Reward_sum is -162.0
# Reward_sum is -163.0
# Reward_sum is -164.0
# Reward_sum is -165.0
# Reward_sum is -166.0
# Reward_sum is -167.0
# Reward_sum is -168.0
# Reward_sum is -169.0
# Reward_sum is -170.0
# Reward_sum is -171.0
# Reward_sum is -172.0
# Reward_sum is -173.0
# Reward_sum is -174.0
# Reward_sum is -175.0
# Reward_sum is -176.0
# Reward_sum is -177.0
# Reward_sum is -178.0
# Reward_sum is -179.0
# Reward_sum is -180.0
# Reward_sum is -181.0
# Reward_sum is -182.0
# Reward_sum is -183.0
# Reward_sum is -184.0
# Reward_sum is -185.0
# Reward_sum is -186.0
# Reward_sum is -187.0
# Reward_sum is -188.0
# Reward_sum is -189.0
# Reward_sum is -190.0
# Reward_sum is -191.0
# Reward_sum is -192.0
# Reward_sum is -193.0
# Reward_sum is -194.0
# Reward_sum is -195.0
# Reward_sum is -196.0
# Reward_sum is -197.0
# Reward_sum is -198.0
# Reward_sum is -199.0
# Episode ended with total reward: -200.0

# %% [markdown]
# Check if the episode is done (the car has reached the goal or the maximum number of steps is reached).
#
# ---
#
# Print the total reward obtained in the current episode.
#
# ---
#
# Pause execution briefly before starting the next episode for visualization purposes.
#
# ---
#
#
# Break out of the current episode loop once the episode is finished.
#
# Close the environment once all episodes are completed.

# %%
if done:
    print(f'Episode {i} reward: {reward_sum}')
    sleep(1)
    #break

# %% [markdown]
# ### Full Implementation

# %%
from time import sleep
import gymnasium as gym
import random
env = gym.make('MountainCar-v0', render_mode='human')

seed = 0
random.seed(seed)

print(f'Action Space: {env.action_space}')
print(f'Observation Space: {env.observation_space}')

episodes = 10
reward_sum = 0
for i in range(episodes):
    print('Episode number:', i)
    init_state = env.reset()
    env.render()
    random_action = random.randint(0, 2)
    print('Action taken :',random_action)
    state, reward, done, truncated,debug = env.step(random_action)
    print('Environment state value:',state)

    reward_sum += reward
    sleep(.01)
    if done or truncated:
        print(f'Episode {i} reward: {reward_sum}')
        sleep(1)
        break
    print('Total reward:', reward_sum)
env.close()
# Out:
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Episode number: 0
# Action taken : 1
# Environment state value: [-4.6681815e-01 -4.2695360e-04]
# Total reward: -1.0
# Episode number: 1
# Action taken : 1
# Environment state value: [-5.08691788e-01 -1.12608956e-04]
# Total reward: -2.0
# Episode number: 2
# Action taken : 0
# Environment state value: [-0.44172964 -0.00161964]
# Total reward: -3.0
# Episode number: 3
# Action taken : 1
# Environment state value: [-5.6849152e-01  3.3819207e-04]
# Total reward: -4.0
# Episode number: 4
# Action taken : 2
# Environment state value: [-0.51964736  0.0009777 ]
# Total reward: -5.0
# Episode number: 5
# Action taken : 1
# Environment state value: [-0.42079622 -0.00076431]
# Total reward: -6.0
# Episode number: 6
# Action taken : 1
# Environment state value: [-4.946639e-01 -2.183707e-04]
# Total reward: -7.0
# Episode number: 7
# Action taken : 1
# Environment state value: [-5.617535e-01  2.876794e-04]
# Total reward: -8.0
# Episode number: 8
# Action taken : 1
# Environment state value: [-0.40541598 -0.00087406]
# Total reward: -9.0
# Episode number: 9
# Action taken : 1
# Environment state value: [-0.40961942 -0.00084425]
# Total reward: -10.0

# %% [markdown]
# ***Random movements cannot make the car reach the goal soon.
# Balancing is one of the most challenging tasks in robotics.***
#
# ---
#
# ***The key is understanding the dynamics: the car cannot reach the top directly—it needs to build momentum by moving back and forth. We need to build the momentum to climb the hill. If the car is moving left (velocity < 0), apply a leftward force (action = 0) to maximize momentum in that direction.If the car is moving right (velocity >= 0), apply a rightward force (action = 2) to boost momentum in the forward direction.***
#
# ---
#
# ***So, let's try to implement this idea. We accelerate the car to the left if the velocity is negative, and we accelerate the car to the right if the velocity
# is positive***

# %% [markdown]
# Here, we determine the action based on the current state of the environment. If the velocity (state[1]) is negative, it chooses action 0 (accelerate left);If the velocity (state[1]) is 0 or positive, it chooses action 2 (accelerate right);

# %%
from time import sleep
import random
env = gym.make('MountainCar-v0', render_mode='human')

seed = 0
random.seed(seed)

print(f'Action Space: {env.action_space}')
print(f'Observation Space: {env.observation_space}')

episodes=200
reward_sum=0

state,_ = env.reset()  # Reset the environment
for episode in range(episodes):
    env.render()  # Visualize the environment

    position, velocity = state  # Unpack state (position, velocity)

    # Improved Policy: Build momentum to the right to reach the top
    if velocity < 0:
        action = 0  # Push left if velocity is negative
    elif velocity >= 0:
        action = 2  # Push right to gain momentum

    # Taking the action and getting the new state
    state, reward, done, truncated, info = env.step(action)
    reward_sum += reward

    # Environment information
    print(f"Position: {position:.3f}, Velocity: {velocity:.3f}, Action: {action},Reward: {reward}")
    print(f'Reward sum: {reward_sum}')

    # Break if the episode is done
    if done or truncated:
        print(f"Episode ended with total reward: {reward_sum}")
        break

    sleep(0.01)

env.close()
# Out:
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Position: -0.440, Velocity: 0.000, Action: 2,Reward: -1.0
# Reward sum: -1.0
# Position: -0.439, Velocity: 0.000, Action: 2,Reward: -1.0
# Reward sum: -2.0
# Position: -0.439, Velocity: 0.001, Action: 2,Reward: -1.0
# Reward sum: -3.0
# Position: -0.438, Velocity: 0.001, Action: 2,Reward: -1.0
# Reward sum: -4.0
# Position: -0.436, Velocity: 0.001, Action: 2,Reward: -1.0
# Reward sum: -5.0
# Position: -0.434, Velocity: 0.002, Action: 2,Reward: -1.0
# Reward sum: -6.0
# Position: -0.432, Velocity: 0.002, Action: 2,Reward: -1.0
# Reward sum: -7.0
# Position: -0.430, Velocity: 0.002, Action: 2,Reward: -1.0
# Reward sum: -8.0
# Position: -0.427, Velocity: 0.003, Action: 2,Reward: -1.0
# Reward sum: -9.0
# Position: -0.424, Velocity: 0.003, Action: 2,Reward: -1.0
# Reward sum: -10.0
# Position: -0.420, Velocity: 0.003, Action: 2,Reward: -1.0
# Reward sum: -11.0
# Position: -0.417, Velocity: 0.004, Action: 2,Reward: -1.0
# Reward sum: -12.0
# Position: -0.413, Velocity: 0.004, Action: 2,Reward: -1.0
# Reward sum: -13.0
# Position: -0.409, Velocity: 0.004, Action: 2,Reward: -1.0
# Reward sum: -14.0
# Position: -0.405, Velocity: 0.004, Action: 2,Reward: -1.0
# Reward sum: -15.0
# Position: -0.401, Velocity: 0.004, Action: 2,Reward: -1.0
# Reward sum: -16.0
# Position: -0.396, Velocity: 0.004, Action: 2,Reward: -1.0
# Reward sum: -17.0
# Position: -0.392, Velocity: 0.004, Action: 2,Reward: -1.0
# Reward sum: -18.0
# Position: -0.387, Velocity: 0.004, Action: 2,Reward: -1.0
# Reward sum: -19.0
# Position: -0.383, Velocity: 0.004, Action: 2,Reward: -1.0
# Reward sum: -20.0
# Position: -0.378, Velocity: 0.004, Action: 2,Reward: -1.0
# Reward sum: -21.0
# Position: -0.374, Velocity: 0.004, Action: 2,Reward: -1.0
# Reward sum: -22.0
# Position: -0.370, Velocity: 0.004, Action: 2,Reward: -1.0
# Reward sum: -23.0
# Position: -0.365, Velocity: 0.004, Action: 2,Reward: -1.0
# Reward sum: -24.0
# Position: -0.361, Velocity: 0.004, Action: 2,Reward: -1.0
# Reward sum: -25.0
# Position: -0.358, Velocity: 0.004, Action: 2,Reward: -1.0
# Reward sum: -26.0
# Position: -0.354, Velocity: 0.004, Action: 2,Reward: -1.0
# Reward sum: -27.0
# Position: -0.350, Velocity: 0.003, Action: 2,Reward: -1.0
# Reward sum: -28.0
# Position: -0.347, Velocity: 0.003, Action: 2,Reward: -1.0
# Reward sum: -29.0
# Position: -0.344, Velocity: 0.003, Action: 2,Reward: -1.0
# Reward sum: -30.0
# Position: -0.341, Velocity: 0.003, Action: 2,Reward: -1.0
# Reward sum: -31.0
# Position: -0.339, Velocity: 0.002, Action: 2,Reward: -1.0
# Reward sum: -32.0
# Position: -0.337, Velocity: 0.002, Action: 2,Reward: -1.0
# Reward sum: -33.0
# Position: -0.335, Velocity: 0.002, Action: 2,Reward: -1.0
# Reward sum: -34.0
# Position: -0.334, Velocity: 0.001, Action: 2,Reward: -1.0
# Reward sum: -35.0
# Position: -0.333, Velocity: 0.001, Action: 2,Reward: -1.0
# Reward sum: -36.0
# Position: -0.332, Velocity: 0.001, Action: 2,Reward: -1.0
# Reward sum: -37.0
# Position: -0.332, Velocity: 0.000, Action: 2,Reward: -1.0
# Reward sum: -38.0
# Position: -0.332, Velocity: -0.000, Action: 0,Reward: -1.0
# Reward sum: -39.0
# Position: -0.334, Velocity: -0.002, Action: 0,Reward: -1.0
# Reward sum: -40.0
# Position: -0.339, Velocity: -0.005, Action: 0,Reward: -1.0
# Reward sum: -41.0
# Position: -0.346, Velocity: -0.007, Action: 0,Reward: -1.0
# Reward sum: -42.0
# Position: -0.355, Velocity: -0.009, Action: 0,Reward: -1.0
# Reward sum: -43.0
# Position: -0.367, Velocity: -0.012, Action: 0,Reward: -1.0
# Reward sum: -44.0
# Position: -0.380, Velocity: -0.014, Action: 0,Reward: -1.0
# Reward sum: -45.0
# Position: -0.396, Velocity: -0.016, Action: 0,Reward: -1.0
# Reward sum: -46.0
# Position: -0.414, Velocity: -0.018, Action: 0,Reward: -1.0
# Reward sum: -47.0
# Position: -0.433, Velocity: -0.019, Action: 0,Reward: -1.0
# Reward sum: -48.0
# Position: -0.454, Velocity: -0.021, Action: 0,Reward: -1.0
# Reward sum: -49.0
# Position: -0.477, Velocity: -0.023, Action: 0,Reward: -1.0
# Reward sum: -50.0
# Position: -0.501, Velocity: -0.024, Action: 0,Reward: -1.0
# Reward sum: -51.0
# Position: -0.526, Velocity: -0.025, Action: 0,Reward: -1.0
# Reward sum: -52.0
# Position: -0.552, Velocity: -0.026, Action: 0,Reward: -1.0
# Reward sum: -53.0
# Position: -0.579, Velocity: -0.027, Action: 0,Reward: -1.0
# Reward sum: -54.0
# Position: -0.606, Velocity: -0.028, Action: 0,Reward: -1.0
# Reward sum: -55.0
# Position: -0.634, Velocity: -0.028, Action: 0,Reward: -1.0
# Reward sum: -56.0
# Position: -0.662, Velocity: -0.028, Action: 0,Reward: -1.0
# Reward sum: -57.0
# Position: -0.690, Velocity: -0.028, Action: 0,Reward: -1.0
# Reward sum: -58.0
# Position: -0.718, Velocity: -0.028, Action: 0,Reward: -1.0
# Reward sum: -59.0
# Position: -0.746, Velocity: -0.027, Action: 0,Reward: -1.0
# Reward sum: -60.0
# Position: -0.773, Velocity: -0.027, Action: 0,Reward: -1.0
# Reward sum: -61.0
# Position: -0.799, Velocity: -0.026, Action: 0,Reward: -1.0
# Reward sum: -62.0
# Position: -0.824, Velocity: -0.025, Action: 0,Reward: -1.0
# Reward sum: -63.0
# Position: -0.849, Velocity: -0.024, Action: 0,Reward: -1.0
# Reward sum: -64.0
# Position: -0.872, Velocity: -0.023, Action: 0,Reward: -1.0
# Reward sum: -65.0
# Position: -0.894, Velocity: -0.022, Action: 0,Reward: -1.0
# Reward sum: -66.0
# Position: -0.915, Velocity: -0.021, Action: 0,Reward: -1.0
# Reward sum: -67.0
# Position: -0.935, Velocity: -0.020, Action: 0,Reward: -1.0
# Reward sum: -68.0
# Position: -0.953, Velocity: -0.018, Action: 0,Reward: -1.0
# Reward sum: -69.0
# Position: -0.970, Velocity: -0.017, Action: 0,Reward: -1.0
# Reward sum: -70.0
# Position: -0.986, Velocity: -0.015, Action: 0,Reward: -1.0
# Reward sum: -71.0
# Position: -1.000, Velocity: -0.014, Action: 0,Reward: -1.0
# Reward sum: -72.0
# Position: -1.012, Velocity: -0.013, Action: 0,Reward: -1.0
# Reward sum: -73.0
# Position: -1.023, Velocity: -0.011, Action: 0,Reward: -1.0
# Reward sum: -74.0
# Position: -1.033, Velocity: -0.010, Action: 0,Reward: -1.0
# Reward sum: -75.0
# Position: -1.041, Velocity: -0.008, Action: 0,Reward: -1.0
# Reward sum: -76.0
# Position: -1.047, Velocity: -0.007, Action: 0,Reward: -1.0
# Reward sum: -77.0
# Position: -1.052, Velocity: -0.005, Action: 0,Reward: -1.0
# Reward sum: -78.0
# Position: -1.056, Velocity: -0.004, Action: 0,Reward: -1.0
# Reward sum: -79.0
# Position: -1.058, Velocity: -0.002, Action: 0,Reward: -1.0
# Reward sum: -80.0
# Position: -1.059, Velocity: -0.001, Action: 0,Reward: -1.0
# Reward sum: -81.0
# Position: -1.058, Velocity: 0.001, Action: 2,Reward: -1.0
# Reward sum: -82.0
# Position: -1.053, Velocity: 0.004, Action: 2,Reward: -1.0
# Reward sum: -83.0
# Position: -1.045, Velocity: 0.008, Action: 2,Reward: -1.0
# Reward sum: -84.0
# Position: -1.034, Velocity: 0.011, Action: 2,Reward: -1.0
# Reward sum: -85.0
# Position: -1.019, Velocity: 0.015, Action: 2,Reward: -1.0
# Reward sum: -86.0
# Position: -1.000, Velocity: 0.018, Action: 2,Reward: -1.0
# Reward sum: -87.0
# Position: -0.978, Velocity: 0.022, Action: 2,Reward: -1.0
# Reward sum: -88.0
# Position: -0.953, Velocity: 0.025, Action: 2,Reward: -1.0
# Reward sum: -89.0
# Position: -0.924, Velocity: 0.029, Action: 2,Reward: -1.0
# Reward sum: -90.0
# Position: -0.892, Velocity: 0.032, Action: 2,Reward: -1.0
# Reward sum: -91.0
# Position: -0.857, Velocity: 0.035, Action: 2,Reward: -1.0
# Reward sum: -92.0
# Position: -0.818, Velocity: 0.038, Action: 2,Reward: -1.0
# Reward sum: -93.0
# Position: -0.777, Velocity: 0.041, Action: 2,Reward: -1.0
# Reward sum: -94.0
# Position: -0.733, Velocity: 0.044, Action: 2,Reward: -1.0
# Reward sum: -95.0
# Position: -0.686, Velocity: 0.047, Action: 2,Reward: -1.0
# Reward sum: -96.0
# Position: -0.638, Velocity: 0.049, Action: 2,Reward: -1.0
# Reward sum: -97.0
# Position: -0.587, Velocity: 0.051, Action: 2,Reward: -1.0
# Reward sum: -98.0
# Position: -0.535, Velocity: 0.052, Action: 2,Reward: -1.0
# Reward sum: -99.0
# Position: -0.482, Velocity: 0.053, Action: 2,Reward: -1.0
# Reward sum: -100.0
# Position: -0.428, Velocity: 0.054, Action: 2,Reward: -1.0
# Reward sum: -101.0
# Position: -0.374, Velocity: 0.054, Action: 2,Reward: -1.0
# Reward sum: -102.0
# Position: -0.320, Velocity: 0.054, Action: 2,Reward: -1.0
# Reward sum: -103.0
# Position: -0.266, Velocity: 0.054, Action: 2,Reward: -1.0
# Reward sum: -104.0
# Position: -0.214, Velocity: 0.053, Action: 2,Reward: -1.0
# Reward sum: -105.0
# Position: -0.162, Velocity: 0.052, Action: 2,Reward: -1.0
# Reward sum: -106.0
# Position: -0.111, Velocity: 0.051, Action: 2,Reward: -1.0
# Reward sum: -107.0
# Position: -0.062, Velocity: 0.049, Action: 2,Reward: -1.0
# Reward sum: -108.0
# Position: -0.014, Velocity: 0.048, Action: 2,Reward: -1.0
# Reward sum: -109.0
# Position: 0.032, Velocity: 0.046, Action: 2,Reward: -1.0
# Reward sum: -110.0
# Position: 0.077, Velocity: 0.045, Action: 2,Reward: -1.0
# Reward sum: -111.0
# Position: 0.121, Velocity: 0.043, Action: 2,Reward: -1.0
# Reward sum: -112.0
# Position: 0.163, Velocity: 0.042, Action: 2,Reward: -1.0
# Reward sum: -113.0
# Position: 0.203, Velocity: 0.041, Action: 2,Reward: -1.0
# Reward sum: -114.0
# Position: 0.243, Velocity: 0.040, Action: 2,Reward: -1.0
# Reward sum: -115.0
# Position: 0.282, Velocity: 0.039, Action: 2,Reward: -1.0
# Reward sum: -116.0
# Position: 0.320, Velocity: 0.038, Action: 2,Reward: -1.0
# Reward sum: -117.0
# Position: 0.358, Velocity: 0.038, Action: 2,Reward: -1.0
# Reward sum: -118.0
# Position: 0.396, Velocity: 0.038, Action: 2,Reward: -1.0
# Reward sum: -119.0
# Position: 0.434, Velocity: 0.038, Action: 2,Reward: -1.0
# Reward sum: -120.0
# Position: 0.472, Velocity: 0.038, Action: 2,Reward: -1.0
# Reward sum: -121.0
# Episode ended with total reward: -121.0

# %% [markdown]
# An updated policy where the agent:
#
# Accelerates to the right when the car is at a low position.
# Decelerates to the left (or applies less force) when the car is close to the goal to avoid overshooting.
# i.e Apply a small force or dont accelerate if the car is getting closer to the goal

# %%
from time import sleep
import random
env = gym.make('MountainCar-v0', render_mode='human')

seed = 0
random.seed(seed)

print(f'Action Space: {env.action_space}')
print(f'Observation Space: {env.observation_space}')

episodes=200
state,_ = env.reset()  # Reset the environment
reward_sum=0

for episode in range(episodes):
    env.render()  # Visualize the environment

    position, velocity = state  # Unpack state (position, velocity)

    # Improved Policy: Build momentum to the right to reach the top
    if velocity < 0:
        action = 0  # Push left if velocity is negative
    elif velocity >= 0:
        if position < 0:  # Car is in the valley, needs to build momentum
            action = 2  # Push right to gain momentum
        else:  # Car is getting closer to the goal
            action = 0  # No action or apply a small force

    # Taking the action and getting the new state
    state, reward, done, truncated, info = env.step(action)
    reward_sum += reward

    # Environment information
    print(f"Position: {position:.3f}, Velocity: {velocity:.3f}, Action: {action}, Reward: {reward}")
    print(f"Reward sum: {reward_sum}")

    # Break if the episode is done
    if done or truncated:
        print(f"Episode ended with total reward: {reward_sum}")
        break

    sleep(0.01)

env.close()
# Out:
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Position: -0.563, Velocity: 0.000, Action: 2, Reward: -1.0
# Reward sum: -1.0
# Position: -0.561, Velocity: 0.001, Action: 2, Reward: -1.0
# Reward sum: -2.0
# Position: -0.559, Velocity: 0.003, Action: 2, Reward: -1.0
# Reward sum: -3.0
# Position: -0.555, Velocity: 0.004, Action: 2, Reward: -1.0
# Reward sum: -4.0
# Position: -0.550, Velocity: 0.005, Action: 2, Reward: -1.0
# Reward sum: -5.0
# Position: -0.544, Velocity: 0.006, Action: 2, Reward: -1.0
# Reward sum: -6.0
# Position: -0.536, Velocity: 0.007, Action: 2, Reward: -1.0
# Reward sum: -7.0
# Position: -0.528, Velocity: 0.009, Action: 2, Reward: -1.0
# Reward sum: -8.0
# Position: -0.518, Velocity: 0.010, Action: 2, Reward: -1.0
# Reward sum: -9.0
# Position: -0.508, Velocity: 0.010, Action: 2, Reward: -1.0
# Reward sum: -10.0
# Position: -0.496, Velocity: 0.011, Action: 2, Reward: -1.0
# Reward sum: -11.0
# Position: -0.484, Velocity: 0.012, Action: 2, Reward: -1.0
# Reward sum: -12.0
# Position: -0.471, Velocity: 0.013, Action: 2, Reward: -1.0
# Reward sum: -13.0
# Position: -0.458, Velocity: 0.013, Action: 2, Reward: -1.0
# Reward sum: -14.0
# Position: -0.444, Velocity: 0.014, Action: 2, Reward: -1.0
# Reward sum: -15.0
# Position: -0.429, Velocity: 0.014, Action: 2, Reward: -1.0
# Reward sum: -16.0
# Position: -0.415, Velocity: 0.015, Action: 2, Reward: -1.0
# Reward sum: -17.0
# Position: -0.400, Velocity: 0.015, Action: 2, Reward: -1.0
# Reward sum: -18.0
# Position: -0.385, Velocity: 0.015, Action: 2, Reward: -1.0
# Reward sum: -19.0
# Position: -0.370, Velocity: 0.015, Action: 2, Reward: -1.0
# Reward sum: -20.0
# Position: -0.355, Velocity: 0.015, Action: 2, Reward: -1.0
# Reward sum: -21.0
# Position: -0.340, Velocity: 0.015, Action: 2, Reward: -1.0
# Reward sum: -22.0
# Position: -0.326, Velocity: 0.014, Action: 2, Reward: -1.0
# Reward sum: -23.0
# Position: -0.312, Velocity: 0.014, Action: 2, Reward: -1.0
# Reward sum: -24.0
# Position: -0.298, Velocity: 0.013, Action: 2, Reward: -1.0
# Reward sum: -25.0
# Position: -0.286, Velocity: 0.013, Action: 2, Reward: -1.0
# Reward sum: -26.0
# Position: -0.273, Velocity: 0.012, Action: 2, Reward: -1.0
# Reward sum: -27.0
# Position: -0.262, Velocity: 0.012, Action: 2, Reward: -1.0
# Reward sum: -28.0
# Position: -0.251, Velocity: 0.011, Action: 2, Reward: -1.0
# Reward sum: -29.0
# Position: -0.241, Velocity: 0.010, Action: 2, Reward: -1.0
# Reward sum: -30.0
# Position: -0.232, Velocity: 0.009, Action: 2, Reward: -1.0
# Reward sum: -31.0
# Position: -0.224, Velocity: 0.008, Action: 2, Reward: -1.0
# Reward sum: -32.0
# Position: -0.216, Velocity: 0.007, Action: 2, Reward: -1.0
# Reward sum: -33.0
# Position: -0.210, Velocity: 0.006, Action: 2, Reward: -1.0
# Reward sum: -34.0
# Position: -0.205, Velocity: 0.005, Action: 2, Reward: -1.0
# Reward sum: -35.0
# Position: -0.201, Velocity: 0.004, Action: 2, Reward: -1.0
# Reward sum: -36.0
# Position: -0.198, Velocity: 0.003, Action: 2, Reward: -1.0
# Reward sum: -37.0
# Position: -0.196, Velocity: 0.002, Action: 2, Reward: -1.0
# Reward sum: -38.0
# Position: -0.195, Velocity: 0.001, Action: 2, Reward: -1.0
# Reward sum: -39.0
# Position: -0.195, Velocity: -0.000, Action: 0, Reward: -1.0
# Reward sum: -40.0
# Position: -0.198, Velocity: -0.003, Action: 0, Reward: -1.0
# Reward sum: -41.0
# Position: -0.204, Velocity: -0.006, Action: 0, Reward: -1.0
# Reward sum: -42.0
# Position: -0.214, Velocity: -0.009, Action: 0, Reward: -1.0
# Reward sum: -43.0
# Position: -0.226, Velocity: -0.012, Action: 0, Reward: -1.0
# Reward sum: -44.0
# Position: -0.241, Velocity: -0.015, Action: 0, Reward: -1.0
# Reward sum: -45.0
# Position: -0.260, Velocity: -0.018, Action: 0, Reward: -1.0
# Reward sum: -46.0
# Position: -0.281, Velocity: -0.021, Action: 0, Reward: -1.0
# Reward sum: -47.0
# Position: -0.304, Velocity: -0.024, Action: 0, Reward: -1.0
# Reward sum: -48.0
# Position: -0.330, Velocity: -0.026, Action: 0, Reward: -1.0
# Reward sum: -49.0
# Position: -0.359, Velocity: -0.029, Action: 0, Reward: -1.0
# Reward sum: -50.0
# Position: -0.389, Velocity: -0.031, Action: 0, Reward: -1.0
# Reward sum: -51.0
# Position: -0.422, Velocity: -0.033, Action: 0, Reward: -1.0
# Reward sum: -52.0
# Position: -0.457, Velocity: -0.034, Action: 0, Reward: -1.0
# Reward sum: -53.0
# Position: -0.492, Velocity: -0.036, Action: 0, Reward: -1.0
# Reward sum: -54.0
# Position: -0.530, Velocity: -0.037, Action: 0, Reward: -1.0
# Reward sum: -55.0
# Position: -0.568, Velocity: -0.038, Action: 0, Reward: -1.0
# Reward sum: -56.0
# Position: -0.607, Velocity: -0.039, Action: 0, Reward: -1.0
# Reward sum: -57.0
# Position: -0.646, Velocity: -0.039, Action: 0, Reward: -1.0
# Reward sum: -58.0
# Position: -0.685, Velocity: -0.039, Action: 0, Reward: -1.0
# Reward sum: -59.0
# Position: -0.724, Velocity: -0.039, Action: 0, Reward: -1.0
# Reward sum: -60.0
# Position: -0.763, Velocity: -0.039, Action: 0, Reward: -1.0
# Reward sum: -61.0
# Position: -0.801, Velocity: -0.038, Action: 0, Reward: -1.0
# Reward sum: -62.0
# Position: -0.838, Velocity: -0.037, Action: 0, Reward: -1.0
# Reward sum: -63.0
# Position: -0.874, Velocity: -0.036, Action: 0, Reward: -1.0
# Reward sum: -64.0
# Position: -0.909, Velocity: -0.035, Action: 0, Reward: -1.0
# Reward sum: -65.0
# Position: -0.943, Velocity: -0.034, Action: 0, Reward: -1.0
# Reward sum: -66.0
# Position: -0.975, Velocity: -0.032, Action: 0, Reward: -1.0
# Reward sum: -67.0
# Position: -1.006, Velocity: -0.031, Action: 0, Reward: -1.0
# Reward sum: -68.0
# Position: -1.036, Velocity: -0.029, Action: 0, Reward: -1.0
# Reward sum: -69.0
# Position: -1.063, Velocity: -0.028, Action: 0, Reward: -1.0
# Reward sum: -70.0
# Position: -1.090, Velocity: -0.026, Action: 0, Reward: -1.0
# Reward sum: -71.0
# Position: -1.115, Velocity: -0.025, Action: 0, Reward: -1.0
# Reward sum: -72.0
# Position: -1.138, Velocity: -0.023, Action: 0, Reward: -1.0
# Reward sum: -73.0
# Position: -1.160, Velocity: -0.022, Action: 0, Reward: -1.0
# Reward sum: -74.0
# Position: -1.181, Velocity: -0.021, Action: 0, Reward: -1.0
# Reward sum: -75.0
# Position: -1.200, Velocity: 0.000, Action: 2, Reward: -1.0
# Reward sum: -76.0
# Position: -1.197, Velocity: 0.003, Action: 2, Reward: -1.0
# Reward sum: -77.0
# Position: -1.190, Velocity: 0.006, Action: 2, Reward: -1.0
# Reward sum: -78.0
# Position: -1.180, Velocity: 0.010, Action: 2, Reward: -1.0
# Reward sum: -79.0
# Position: -1.167, Velocity: 0.013, Action: 2, Reward: -1.0
# Reward sum: -80.0
# Position: -1.151, Velocity: 0.016, Action: 2, Reward: -1.0
# Reward sum: -81.0
# Position: -1.131, Velocity: 0.020, Action: 2, Reward: -1.0
# Reward sum: -82.0
# Position: -1.108, Velocity: 0.023, Action: 2, Reward: -1.0
# Reward sum: -83.0
# Position: -1.081, Velocity: 0.027, Action: 2, Reward: -1.0
# Reward sum: -84.0
# Position: -1.051, Velocity: 0.030, Action: 2, Reward: -1.0
# Reward sum: -85.0
# Position: -1.018, Velocity: 0.034, Action: 2, Reward: -1.0
# Reward sum: -86.0
# Position: -0.980, Velocity: 0.037, Action: 2, Reward: -1.0
# Reward sum: -87.0
# Position: -0.940, Velocity: 0.041, Action: 2, Reward: -1.0
# Reward sum: -88.0
# Position: -0.896, Velocity: 0.044, Action: 2, Reward: -1.0
# Reward sum: -89.0
# Position: -0.849, Velocity: 0.047, Action: 2, Reward: -1.0
# Reward sum: -90.0
# Position: -0.798, Velocity: 0.050, Action: 2, Reward: -1.0
# Reward sum: -91.0
# Position: -0.745, Velocity: 0.053, Action: 2, Reward: -1.0
# Reward sum: -92.0
# Position: -0.690, Velocity: 0.056, Action: 2, Reward: -1.0
# Reward sum: -93.0
# Position: -0.632, Velocity: 0.058, Action: 2, Reward: -1.0
# Reward sum: -94.0
# Position: -0.572, Velocity: 0.060, Action: 2, Reward: -1.0
# Reward sum: -95.0
# Position: -0.511, Velocity: 0.061, Action: 2, Reward: -1.0
# Reward sum: -96.0
# Position: -0.449, Velocity: 0.062, Action: 2, Reward: -1.0
# Reward sum: -97.0
# Position: -0.387, Velocity: 0.062, Action: 2, Reward: -1.0
# Reward sum: -98.0
# Position: -0.324, Velocity: 0.062, Action: 2, Reward: -1.0
# Reward sum: -99.0
# Position: -0.262, Velocity: 0.062, Action: 2, Reward: -1.0
# Reward sum: -100.0
# Position: -0.201, Velocity: 0.061, Action: 2, Reward: -1.0
# Reward sum: -101.0
# Position: -0.141, Velocity: 0.060, Action: 2, Reward: -1.0
# Reward sum: -102.0
# Position: -0.082, Velocity: 0.059, Action: 2, Reward: -1.0
# Reward sum: -103.0
# Position: -0.025, Velocity: 0.057, Action: 2, Reward: -1.0
# Reward sum: -104.0
# Position: 0.031, Velocity: 0.056, Action: 0, Reward: -1.0
# Reward sum: -105.0
# Position: 0.084, Velocity: 0.052, Action: 0, Reward: -1.0
# Reward sum: -106.0
# Position: 0.133, Velocity: 0.049, Action: 0, Reward: -1.0
# Reward sum: -107.0
# Position: 0.178, Velocity: 0.046, Action: 0, Reward: -1.0
# Reward sum: -108.0
# Position: 0.221, Velocity: 0.043, Action: 0, Reward: -1.0
# Reward sum: -109.0
# Position: 0.261, Velocity: 0.040, Action: 0, Reward: -1.0
# Reward sum: -110.0
# Position: 0.297, Velocity: 0.037, Action: 0, Reward: -1.0
# Reward sum: -111.0
# Position: 0.332, Velocity: 0.034, Action: 0, Reward: -1.0
# Reward sum: -112.0
# Position: 0.364, Velocity: 0.032, Action: 0, Reward: -1.0
# Reward sum: -113.0
# Position: 0.393, Velocity: 0.030, Action: 0, Reward: -1.0
# Reward sum: -114.0
# Position: 0.421, Velocity: 0.028, Action: 0, Reward: -1.0
# Reward sum: -115.0
# Position: 0.447, Velocity: 0.026, Action: 0, Reward: -1.0
# Reward sum: -116.0
# Position: 0.472, Velocity: 0.024, Action: 0, Reward: -1.0
# Reward sum: -117.0
# Position: 0.495, Velocity: 0.023, Action: 0, Reward: -1.0
# Reward sum: -118.0
# Episode ended with total reward: -118.0

# %% [markdown]
# **Additional Exercises**
#
# **1.Implement a Custom Environment with Two Cars similar to MountainCar-v0**
# * Create a custom environment where two cars try to reach the goal (top of the hill) in a MountainCar-like environment. (Use the gym.Env class and inherit it to create our custom environment.)
# * The environment will have two cars. The state will contain the position and velocity of both cars.
# * Each car will have 3 actions (move left, move right, or do nothing).
# * The reward for each car will be -1 for each step until it reaches the goal. If either car reaches the top of the hill, it will receive a reward of +100.
# * The episode will end if either car reaches the goal.
# * Test the environment with 5 episodes where random actions are chosen, and the total reward for each episode is printed.
#
# **2.Implement a random policy and track the performance in the CartPole-v1 environment.**
# * Set up the CartPole-v1 environment.
# * Create a random policy where the action is randomly chosen between 0 and 1.
# * Run multiple episodes and track the cumulative reward for each episode.
# * Analyze how random movements perform in balancing the pole.
#
# **3. Implement a rule-based policy for the Acrobot-v1 environment.**
# * Set up the Acrobot-v1 environment.
# * Implement a policy based on the angle of the two joints of the acrobot:
# * If the angle of the second joint is less than 0, apply action 1 (move the first joint upward).Otherwise, apply action 0 (move the first joint downward).
# * Run the policy for several episodes and observe the performance.
# * Track the rewards and see if you can improve the performance with better rules.

# %% [markdown]
# Sources / References:
#
# 1.https://www.gymlibrary.dev/content/environment_creation/
#
# 2.https://www.gymlibrary.dev/environments/classic_control/cart_pole/
#
# 3.https://www.gymlibrary.dev/environments/classic_control/acrobot/
