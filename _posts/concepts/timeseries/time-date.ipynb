# %%
import pandas as pd # takes as  string 
from datetime import datetime # takes year, month, day, hour, minute, second

# %%
time_stamp = pd.Timestamp('2024-06-15 14:30:00')
# pd.timestamp can take a datatime object or a string 
time_stamp == datetime(2024, 6, 15, 14, 30, 0) 
time_stamp == pd.Timestamp
