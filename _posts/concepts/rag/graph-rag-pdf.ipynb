# %% [markdown]
# #### Limitations of vector RAG
# 1. **Themes and relationships** - Document embedding captures semantic meaning but struggles to capture themes and relationships between entities in the document corpus.
# 2. **Scalability** - as the volume of the database grows, the retrieval process can become less efficient, as the computational load increases with the search space.
# 3. **Diverse Data** - the structured and diverse data are harder to embed.

# %%
import os 
from langchain_openai import OpenAIEmbeddings
from langchain_experimental.text_splitter import SemanticChunker
from langchain_core.documents import Document 
from langchain_community.document_loaders import PyPDFLoader
from langchain_community.retrievers import BM25Retriever
from langchain.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI 
from langchain_core.runnables import RunnablePassthrough
from langchain_core.output_parsers import StrOutputParser
from langchain.prompts import PromptTemplate
from langsmith.evaluation import LangChainStringEvaluator
from ragas.integrations.langchain import EvaluatorChain #!pip install ragas==0.1.22
from ragas.metrics import faithfulness, ContextPrecision
import nest_asyncio 
nest_asyncio.apply()
# Out:
# c:\Users\samra\anaconda3\envs\ml\lib\site-packages\pandas\core\computation\expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
pdf_loader = PyPDFLoader(file_path='../../../data/pilot-manual.pdf')

openai_api_key = os.environ.get('OPENAI_API_KEY')
# 1st model to do embedding. 
embeddings = OpenAIEmbeddings(api_key=openai_api_key, model='text-embedding-3-small')
semantic_splitter = SemanticChunker(
    embeddings=embeddings, 
    breakpoint_threshold_amount=0.8)
documents = pdf_loader.load()
chunks = semantic_splitter.split_documents(documents)

bm25_retriever = BM25Retriever.from_documents(
    documents=chunks, k=5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 pdf_loader = PyPDFLoader(file_path='../../../data/pilot-manual-787.pdf')
#       3 openai_api_key = os.environ.get('OPENAI_API_KEY')
#       4 # 1st model to do embedding.
#
# File c:\Users\samra\anaconda3\envs\ml\lib\site-packages\langchain_community\document_loaders\pdf.py:241, in PyPDFLoader.__init__(self, file_path, password, headers, extract_images, extraction_mode, extraction_kwargs)
#     237 except ImportError:
#     238     raise ImportError(
#     239         "pypdf package not found, please install it with `pip install pypdf`"
#     240     )
# --> 241 super().__init__(file_path, headers=headers)
#     242 self.parser = PyPDFParser(
#     243     password=password,
#     244     extract_images=extract_images,
#     245     extraction_mode=extraction_mode,
#     246     extraction_kwargs=extraction_kwargs,
#     247 )
#
# File c:\Users\samra\anaconda3\envs\ml\lib\site-packages\langchain_community\document_loaders\pdf.py:117, in BasePDFLoader.__init__(self, file_path, headers)
#     115         self.file_path = str(temp_pdf)
#     116 elif not os.path.isfile(self.file_path):
# --> 117     raise ValueError("File path %s is not a valid file or url" % self.file_path)
#
# ValueError: File path ../../../data/pilot-manual-787.pdf is not a valid file or url

# %% [markdown]
# #### Document to graph

# %% [markdown]
# #### create nodes and edges data structure

# %%
from langchain_openai import ChatOpenAI
from langchain_experimental.graph_transformers import LLMGraphTransformer
import os 

openai_api_key = os.getenv("OPENAI_API_KEY")

llm = ChatOpenAI (api_key = openai_api_key, temperature=0, model_name="gpt-4o-mini")
llm_transformer = LLMGraphTransformer(llm=llm)

graph_documents = llm_transformer.convert_to_graph_documents(documents)
print(graph_documents)
# Out:
# [GraphDocument(nodes=[Node(id='Pmdg 737', type='Aircraft'), Node(id='Tutorial Flight', type='Flight'), Node(id='Pmdg Simulations', type='Company'), Node(id='July 2022', type='Date')], relationships=[Relationship(source=Node(id='Pmdg 737', type='Aircraft'), target=Node(id='Tutorial Flight', type='Flight'), type='HAS_TUTORIAL'), Relationship(source=Node(id='Pmdg Simulations', type='Company'), target=Node(id='Pmdg 737', type='Aircraft'), type='DEVELOPER'), Relationship(source=Node(id='July 2022', type='Date'), target=Node(id='Tutorial Flight', type='Flight'), type='PUBLISHED_IN')], source=Document(metadata={'source': '../../../data/pilot-manual-787.pdf', 'page': 0}, page_content=' PMDG 7 37 0.00.1 \n  TUTORIAL FLIGHT  \n \nFor Simulator Use Only  DO NOT DUPLICATE  JULY 2022  \n \n \n \n \n \nPMDG 737 \n \n \nTutorial Flight  \n \nCopyright © 2011-2022 \nPMDG Simulations  \nAll Rights Reserved  \n   \n')), GraphDocument(nodes=[Node(id='Pmdg 737', type='Simulator'), Node(id='Microsoft Flight Simulator', type='Simulator'), Node(id='Pmdg Simulations', type='Company'), Node(id='Boeing', type='Company'), Node(id='Copyright 2022 Pmdg Simulations', type='Copyright'), Node(id='Boeing Management Company', type='Company')], relationships=[Relationship(source=Node(id='Pmdg 737', type='Simulator'), target=Node(id='Microsoft Flight Simulator', type='Simulator'), type='USED_WITH'), Relationship(source=Node(id='Pmdg Simulations', type='Company'), target=Node(id='Pmdg 737', type='Simulator'), type='PRODUCED'), Relationship(source=Node(id='Boeing', type='Company'), target=Node(id='Boeing 737', type='Simulator'), type='LICENSED_FROM'), Relationship(source=Node(id='Copyright 2022 Pmdg Simulations', type='Copyright'), target=Node(id='Pmdg Simulations', type='Company'), type='HELD_BY'), Relationship(source=Node(id='Boeing Management Company', type='Company'), target=Node(id='Boeing', type='Company'), type='LICENSED_TO')], source=Document(metadata={'source': '../../../data/pilot-manual-787.pdf', 'page': 1}, page_content='0.00.2 PMDG 7 37  \nTUTORIAL FLIGHT    \n \n JULY 2022 DO NOT DUPLICATE  For Simulator Use Only  \nDISCLAIMER AND COPYRIGHT INFORMATION   \nThis manual was compiled for use only with the PMDG 737  simulation  for \nMicrosoft Flight Simulator . The information contained within this manual is derived \nfrom multiple sources and is not subject to revision or checking for accuracy. This \nmanual is not to be used for training or familiarity with any aircraft. This manual is \nnot assumed to pro vide operating procedures for use on any aircraft and is written \nfor entertainment purposes.  \n \nIt is a violation of the owner’s copyright to distribute this document or any portion \nthereof without permission of the author.  \n \n \nThe PMDG Simulations Web Site ca n be found at:  \nhttp://www.pmdg.com  \n \nCopyright  © 2022 PMDG Simulations  \n \nThis manual and all of its contents, pages, text and graphic s are protected under \ncopyright law of the United States of America and international treaties . \nDuplication of this manual is prohibited . Permission to conduct duplication of this \nmanual will not be sub -contracted, leased or given.  \n \nMicrosoft , the Microsof t logo  and Microsoft Flight Simulator  are registered \ntrademarks of the  Microsoft Corporation. Boeing, the Boeing name and certain \nbrand marks are the propert y of The Boeing Company . Some graphics contained \nin this manual were taken directly from the simulat or and altered in order to suit  \nduplication on a printed page . All images contained in this manual were used with \npermission.  \n \n \n \nProduced under license from Boeing Management Company. Boeing 737, 737 - \n600, 737 -700, 737 -800, 737 -900 & Boeing are amo ng the trademarks owned by \nBoeing.  \n \n \n \n \n')), GraphDocument(nodes=[Node(id='Pmdg 7 37 0.00.3', type='Software'), Node(id='End User License Agreement', type='Agreement'), Node(id='July 2022', type='Date'), Node(id='Pmdg', type='Compa ...

# %% [markdown]
# #### render the graph using neo4j

# %%
import os 
from langchain_community.graphs import Neo4jGraph
from langchain_experimental.graph_transformers import LLMGraphTransformer
from langchain_openai import ChatOpenAI

openai_api_key = os.getenv("OPENAI_API_KEY")
pwd=os.getenv("NEO4J_PASSWORD")
graph = Neo4jGraph(url="bolt://localhost:7687", username="neo4j", password="esoterics17")

# generation of graph from the text using LLM
llm = ChatOpenAI(api_key=openai_api_key, temperature=0, model_name="gpt-4o-mini")
llm_transformer = LLMGraphTransformer(llm=llm)
graph_documents = llm_transformer.convert_to_graph_documents(documents[:3])

# adding the graph into the Neo4j database
graph.add_graph_documents(
    graph_documents=graph_documents,
    include_source=True,
    baseEntityLabel=True 
)
graph.refresh_schema()
schema = graph.get_schema
print(schema)
# Out:
# Node properties:
# Document {id: STRING, text: STRING, source: STRING, page: INTEGER}
# Aircraft {id: STRING}
# Flight {id: STRING}
# Company {id: STRING}
# Date {id: STRING}
# Simulator {id: STRING}
# Copyright {id: STRING}
# Software {id: STRING}
# Organization {id: STRING}
# Relationship properties:
#
# The relationships:
# (:Document)-[:MENTIONS]->(:Aircraft)
# (:Document)-[:MENTIONS]->(:Simulator)
# (:Document)-[:MENTIONS]->(:Flight)
# (:Document)-[:MENTIONS]->(:Company)
# (:Document)-[:MENTIONS]->(:Date)
# (:Document)-[:MENTIONS]->(:Copyright)
# (:Document)-[:MENTIONS]->(:Document)
# (:Document)-[:MENTIONS]->(:Software)
# (:Document)-[:MENTIONS]->(:Organization)
# (:Aircraft)-[:HAS_TUTORIAL]->(:Flight)
# (:Aircraft)-[:USED_WITH]->(:Simulator)
# (:Company)-[:HOLD]->(:Copyright)
# (:Company)-[:DEVELOPER]->(:Aircraft)
# (:Company)-[:DEVELOPER]->(:Simulator)
# (:Company)-[:SUPPLIER_OF]->(:Company)
# (:Company)-[:LICENSED_TO]->(:Aircraft)
# (:Company)-[:LICENSED_TO]->(:Simulator)
# (:Company)-[:OWNS]->(:Simulator)
# (:Company)-[:GRANTS_LICENSE]->(:Document)
# (:Date)-[:PUBLISHED_IN]->(:Flight)
# (:Simulator)-[:HAS_TUTORIAL]->(:Flight)
# (:Simulator)-[:USED_WITH]->(:Simulator)
# (:Software)-[:USE_IN_ACCORDANCE_WITH]->(:Document)
# (:Software)-[:RELEASE_DATE]->(:Date)
# (:Software)-[:SUPERCEDES_INFORMATION]->(:Document)
# (:Organization)-[:ISSUES_MANUALS]->(:Document)

# %% [markdown]
# #### Querying the Graph
#
# ![](images/cipher.png)

# %%
# query the graph via manual Cypher query
results = graph.query("""
MATCH (m:Model {id:"Gpt-3"})-[:DEVELOPED_BY]->(org:Organization)
RETURN org
""")
print (results)
print (results[0]['org']['id']) # first arg is 0 because there is only one element in the array. the other subscripts are based on the structure
# Out:
# [{'org': {'id': 'Openai'}}]
# Openai

# %% [markdown]
# ```cypher
# MATCH (p:Person)-[:KNOWN_FOR]->(c:Concept {id: 'Theory of Relativity'})
# RETURN p
# ```
# **Explanation:**
# - ```(p:Person)```: Matches nodes labeled Person.
# - ```[:KNOWN_FOR]```: Matches the relationship indicating the person is known for a particular concept.
# - ```(c:Concept {id: 'Theory of Relativity'})```: Matches nodes labeled Concept with the id property set to "Theory of Relativity".
# - ```RETURN p```: Returns the Person node(s) that match this condition.
#
# **code for getting scientist who is known for Theory of Relativity**
# ```python
# # Print the graph schema
# print(graph.get_schema)
#
# # Query the graph
# results = graph.query("""
# MATCH (relativity:Concept {id: "Theory Of Relativity"}) <-[:KNOWN_FOR]- (scientist:Person)
# return scientist
# """)
#
# print(results[0])
# ```

# %% [markdown]
# ![](images/graphical-rag-arch.png)
# ![](images/graph-cypher-qa-chain.png)
#
# Steps -
# 1. Receive a user input
# 2. Use LLM to convert the user input to Cypher query
# 3. Query the graph database using the Cypher query
# 4. Use LLM to convert the retrieved graph document into natural language.
# 5. Return the natural language response to the user.

# %%
# query the graph using automated cypher query using  llm 
# automated querying not working!! 
from langchain_community.chains.graph_qa.cypher import GraphCypherQAChain
chain = GraphCypherQAChain.from_llm(
    llm=ChatOpenAI(api_key=openai_api_key, temperature=0, model_name="gpt-4o-mini"), graph=graph, verbose=True
)
result = chain.invoke({"query":"Which organization developed Gpt-3?"})
print(result)
# Out:
# > Entering new GraphCypherQAChain chain...
# Generated Cypher:
# cypher
# MATCH (o:Organization)-[:DEVELOPED_BY]->(c:Concept {id: 'Gpt-3'})
# RETURN o
#
# Full Context:
# []
#
# > Finished chain.
# {'query': 'Which organization developed Gpt-3?', 'result': "I don't know the answer."}

# %% [markdown]
# #### Improving the user to cypher query generation
# 1. Filter graph schema
# 2. Validate cypher query
# 3. Few shot prompting

# %%
# filtering did not help. 
# putting validate_cypher = True helped! 
chain = GraphCypherQAChain.from_llm(
    llm=ChatOpenAI(api_key=openai_api_key, temperature=0, model_name="gpt-3.5-turbo"), graph=graph, verbose=True, exclude_types=["Document","Concept","Date","Tmeperiod","Dataset","Event","Technology","Paper","Person","Leaderboard","Architecture"], validate_cypher=True
)
result = chain.invoke({"query":"Which organization developed Gpt-3?"})
print(result)
graph.refresh_schema
print (graph.get_schema)
# Out:
# > Entering new GraphCypherQAChain chain...
# Generated Cypher:
# MATCH (m:Model {id: 'Gpt-3'})-[:DEVELOPED_BY]->(o:Organization)
# RETURN o;
# Full Context:
# [{'o': {'id': 'Openai'}}]
#
# > Finished chain.
# {'query': 'Which organization developed Gpt-3?', 'result': 'Openai'}
# Node properties:
# Document {id: STRING, text: STRING, summary: STRING, source: STRING, title: STRING}
# Concept {id: STRING}
# Date {id: STRING}
# Model {id: STRING}
# Timeperiod {id: STRING}
# Dataset {id: STRING}
# Organization {id: STRING}
# Event {id: STRING}
# Technology {id: STRING}
# Paper {id: STRING}
# Person {id: STRING}
# Leaderboard {id: STRING}
# Architecture {id: STRING}
# Ai model {id: STRING}
# Entity {id: STRING}
# Ai assistant {id: STRING}
# Technique {id: STRING}
# Language model {id: STRING}
# Company {id: STRING}
# Software {id: STRING}
# Product {id: STRING}
# Measurement {id: STRING}
# Equation {id: STRING}
# Unknown {id: STRING}
# Variable {id: STRING}
# Constant {id: STRING}
# Mathematical expression {id: STRING}
# Function {id: STRING}
# Parameter {id: STRING}
# Year {id: STRING}
# Process {id: STRING}
# Version {id: STRING}
# Unit {id: STRING}
# License {id: STRING}
# Mathematicalexpression {id: STRING}
# Platform {id: STRING}
# Service {id: STRING}
# Feature {id: STRING}
# Quantity {id: STRING}
# Relationship properties:
#
# The relationships:
# (:Document)-[:MENTIONS]->(:Concept)
# (:Document)-[:MENTIONS]->(:Date)
# (:Document)-[:MENTIONS]->(:Timeperiod)
# (:Document)-[:MENTIONS]->(:Model)
# (:Document)-[:MENTIONS]->(:Dataset)
# (:Document)-[:MENTIONS]->(:Organization)
# (:Document)-[:MENTIONS]->(:Technology)
# (:Document)-[:MENTIONS]->(:Event)
# (:Document)-[:MENTIONS]->(:Architecture)
# (:Document)-[:MENTIONS]->(:Paper)
# (:Document)-[:MENTIONS]->(:Person)
# (:Document)-[:MENTIONS]->(:Year)
# (:Document)-[:MENTIONS]->(:Leaderboard)
# (:Document)-[:MENTIONS]->(:License)
# (:Document)-[:MENTIONS]->(:Process)
# (:Document)-[:MENTIONS]->(:Ai model)
# (:Document)-[:MENTIONS]->(:Ai assistant)
# (:Document)-[:MENTIONS]->(:Language model)
# (:Document)-[:MENTIONS]->(:Software)
# (:Document)-[:MENTIONS]->(:Version)
# (:Document)-[:MENTIONS]->(:Company)
# (:Document)-[:MENTIONS]->(:Entity)
# (:Document)-[:MENTIONS]->(:Document)
# (:Document)-[:MENTIONS]->(:Technique)
# (:Document)-[:MENTIONS]->(:Product)
# (:Document)-[:MENTIONS]->(:Measurement)
# (:Document)-[:MENTIONS]->(:Unit)
# (:Document)-[:MENTIONS]->(:Equation)
# (:Document)-[:MENTIONS]->(:Unknown)
# (:Document)-[:MENTIONS]->(:Variable)
# (:Document)-[:MENTIONS]->(:Constant)
# (:Document)-[:MENTIONS]->(:Parameter)
# (:Document)-[:MENTIONS]->(:Mathematical expression)
# (:Document)-[:MENTIONS]->(:Mathematicalexpression)
# (:Document)-[:MENTIONS]->(:Function)
# (:Document)-[:MENTIONS]->(:Platform)
# (:Document)-[:MENTIONS]->(:Service)
# (:Document)-[:MENTIONS]->(:Feature)
# (:Document)-[:MENTIONS]->(:Quantity)
# (:Document)-[:INCLUDES]->(:Document)
# (:Concept)-[:DESIGNED_FOR]->(:Concept)
# (:Concept)-[:IS_A]->(:Concept)
# (:Concept)-[:IS_A]->(:Model)
# (:Concept)-[:IS_A]->(:Technology)
# (:Concept)-[:GENERATES]->(:Concept)
# (:Concept)-[:PROCESSING]->(:Concept)
# (:Concept)-[:PROCESSES]->(:Concept)
# (:Concept)-[:BUILT_WITH]->(:Concept)
# (:Concept)-[:ENABLES]->(:Concept)
# (:Concept)-[:BEFORE]->(:Date)
# (:Concept)-[:BEFORE]->(:Timeperiod)
# (:Concept)-[:ACQUIRES]->(:Concept)
# (:Concept)-[:INHERITS]->(:Concept)
# (:Concept)-[:GUIDED_BY]->(:Concept)
# (:Concept)-[:FINE-TUNED_FOR]->(:Concept)
# (:Concept)-[:REGARDING]->(:Concept)
# (:Concept)-[:DOMINATED_OVER]->(:Concept)
# (:Concept)-[:BECAME_DOMINANT_IN]->(:Concept)
# (:Concept)-[:APPLIED_TO]->(:Concept)
# (:Concept)-[:DONE_BY]->(:Concept)
# (:Concept)-[:DONE_BY]->(:Technology)
# (:Concept)-[:IMPLEMENTED_BY]->(:Concept)
# (:Concept)-[:IMPLEMENTED_BY]->(:Technology)
# (:Concept)-[:BASED_ON]->(:Technology)
# (:Concept)-[:BASED_ON]->(:Architecture)
# (:Concept)-[:BASED_ON]->(:Document)
# (:Concept)-[:BASED_ON]->(:Concept)
# (:Concept)-[:MODEL_TYPE]->(:Concept)
# (:Concept)-[:MODEL_TYPE]->(:Technology)
# (:Concept)-[:IS_BASED_ON]->(:Technology)
# (:Concept)-[:IS_BASED_ON]->(:Architecture)
# (:Concept)-[:ENCODER_ONLY_MODEL]->(:Concept)
# (:Concept)-[:ENCODER_ONLY_MODEL]->(:Technology)
# (:Concept)-[:INTRODUCED]->(:Concept)
# (:Concept)-[:INTRODUCED]->(:Technology)
# (:Concept)-[:INTROCED]->(:Concept)
# (:Concept)-[:INTROCED]->(:Technology)
# (:Concept)-[:SUCCESSOR]->(:Concept)
# (:Concept)-[:SUCCESSOR]->(:Model)
# (:Concept)-[:SUCCESSOR]->(:Technology)
# (:Concept)-[:DEVELOPED_BY]->(:Organization)
# (:Concept)-[:DEVELOPED_BY]->(:Company)
# (:Concept)-[:DEVELOPED_BY]->(:Person)
# (:Concept)-[:DEEMED_TOO_POWERFUL]->(:Organization)
# (:Concept)-[:AVAILABLE_VIA_API]->(:Organization)
# (:Concept)-[:AVAILABLE_VIA]->(:Year)
# (:Concept)-[:RELEASED]->(:Year)
# (:Concept)-[:PROCESS]->(:Concept)
# (:Concept)-[:MUST_BE_CONVERTED_TO]->(:Concept)
# (:Concept)-[:CONVERTED_TO]->(:Concept)
# (:Concept)-[:DECIDED_UPON]->(:Concept)
# (:Concept)-[:ARBITRARILY_ASSIGNED]->(:Concept)
# (:Concept)-[:TRAINING_FOR]->(:Model)
# (:Concept)-[:TRAINING_FOR]->(:Person)
# (:Concept)-[:TRAINING_FOR]->(:Ai model)
# (:Concept)-[:TRAINING_FOR]->(:Ai assistant)
# (:Concept)-[:TRAINING_FOR]->(:Language model)
# (:Concept)-[:TRAINING_FOR]->(:Software)
# (:Concept)-[:TRAINING_FOR]->(:Version)
# (:Concept)-[:DETAILED_IN]->(:Paper)
# (:Concept)-[:TRAINING_METHOD_FOR]->(:Model)
# (:Concept)-[:TRAINING_METHOD_FOR]->(:Person)
# (:Concept)-[:TRAINING_METHOD_FOR]->(:Ai model)
# (:Concept)-[:TRAINING_METHOD_FOR]->(:Ai assistant)
# (:Concept)-[:TRAINING_METHOD_FOR]->(:Language model)
# (:Concept)-[:TRAINING_METHOD_FOR]->(:Software)
# (:Concept)-[:TRAINING_METHOD_FOR]->(:Version)
# (:Concept)-[:DEFINED_BY]->(:Document)
# (:Concept)-[:DEFINED_BY]->(:Concept)
# (:Concept)-[:INCLUDES]->(:Document)
# (:Concept)-[:INCLUDES]->(:Concept)
# (:Concept)-[:SELF_CRITIQUES]->(:Concept)
# (:Concept)-[:RESPONDS_TO]->(:Concept)
# (:Concept)-[:CRITIQUES]->(:Concept)
# (:Concept)-[:COMPARED_WITH]->(:Concept)
# (:Concept)-[:TRAINS]->(:Concept)
# (:Concept)-[:TRAINS]->(:Model)
# (:Concept)-[:TRAINS]->(:Entity)
# (:Concept)-[:COMPARES_WITH]->(:Document)
# (:Concept)-[:COMPARES_WITH]->(:Concept)
# (:Concept)-[:FINE-TUNED_TO_ALIGN_WITH]->(:Model)
# (:Concept)-[:FINE-TUNED_TO_ALIGN_WITH]->(:Person)
# (:Concept)-[:FINE-TUNED_TO_ALIGN_WITH]->(:Ai model)
# (:Concept)-[:FINE-TUNED_TO_ALIGN_WITH]->(:Ai assistant)
# (:Concept)-[:FINE-TUNED_TO_ALIGN_WITH]->(:Language model)
# (:Concept)-[:FINE-TUNED_TO_ALIGN_WITH]->(:Software)
# (:Concept)-[:FINE-TUNED_TO_ALIGN_WITH]->(:Version)
# (:Concept)-[:HAS_VALUE]->(:Measurement)
# (:Concept)-[:HAS]->(:Measurement)
# (:Concept)-[:IS_A_MODEL_OF]->(:Concept)
# (:Concept)-[:IS_A_TYPE_OF]->(:Concept)
# (:Concept)-[:USEFUL_FOR]->(:Concept)
# (:Concept)-[:INVOLVED]->(:Person)
# (:Concept)-[:IDENTIFIED_SOURCES_FOR_IMPROVEMENT]->(:Concept)
# (:Concept)-[:HELPS_PREVENT_PREDICTIONS_OF]->(:Concept)
# (:Concept)-[:IS_USEFUL_FOR]->(:Concept)
# (:Concept)-[:SUPERSCEDED_BY]->(:Concept)
# (:Concept)-[:COMPOSED_OF]->(:Concept)
# (:Concept)-[:APPLICATION_OF]->(:Concept)
# (:Concept)-[:ENCODES_RELATIONSHIP]->(:Concept)
# (:Concept)-[:ENCODE_RELATIONSHIP]->(:Concept)
# (:Concept)-[:USES]->(:Concept)
# (:Concept)-[:DESCRIBES]->(:Equation)
# (:Concept)-[:FUNCTION_OF]->(:Variable)
# (:Concept)-[:FUNCTION_OF]->(:Parameter)
# (:Concept)-[:INPUT_FOR]->(:Variable)
# (:Concept)-[:TAKES_ARGUMENT]->(:Entity)
# (:Concept)-[:TAKES_ARGUMENT]->(:Variable)
# (:Concept)-[:IS_A_FUNCTION_OF]->(:Concept)
# (:Concept)-[:IS]->(:Concept)
# (:Concept)-[:INDICATOR_OF]->(:Concept)
# (:Concept)-[:HELPFUL_TO_USE]->(:Concept)
# (:Concept)-[:INDICATES]->(:Concept)
# (:Concept)-[:INDICATES_PRESENCE_OF]->(:Concept)
# (:Concept)-[:EXAMPLE_OF]->(:Concept)
# (:Concept)-[:RELATED_TO]->(:Concept)
# (:Concept)-[:ALLEVATES]->(:Concept)
# (:Concept)-[:ALSO_KNOWN_AS]->(:Concept)
# (:Concept)-[:ALLEVIATES]->(:Concept)
# (:Concept)-[:DEVELOPED]->(:Person)
# (:Concept)-[:USED_IN]->(:Concept)
# (:Concept)-[:INVESTIGATED]->(:Concept)
# (:Concept)-[:INVESTIGATED]->(:Model)
# (:Concept)-[:INVESTIGATED]->(:Technology)
# (:Concept)-[:TRAINED_ON]->(:Concept)
# (:Concept)-[:SCALES_TO]->(:Quantity)
# (:Concept)-[:HAS_AMOUNT]->(:Quantity)
# (:Date)-[:INTRODUCED]->(:Concept)
# (:Date)-[:INTRODUCED]->(:Technology)
# (:Model)-[:PIONEERED]->(:Date)
# (:Model)-[:PIONEERED]->(:Timeperiod)
# (:Model)-[:PIONEERED]->(:Concept)
# (:Model)-[:AVAILABLE_VIA_API]->(:Organization)
# (:Model)-[:DEVELOPED_BY]->(:Organization)
# (:Model)-[:DEVELOPED_BY]->(:Company)
# (:Model)-[:AVAILABLE_VIA]->(:Year)
# (:Model)-[:RELEASED]->(:Year)
# (:Model)-[:RELEASED]->(:Date)
# (:Model)-[:RELEASED]->(:Model)
# (:Model)-[:RELATED_TO]->(:Concept)
# (:Model)-[:RELATED_TO]->(:Model)
# (:Model)-[:RELATED_TO]->(:Technology)
# (:Model)-[:COMPETITION]->(:Model)
# (:Model)-[:BASED_ON]->(:Technology)
# (:Model)-[:BASED_ON]->(:Architecture)
# (:Model)-[:BASED_ON]->(:Document)
# (:Model)-[:BASED_ON]->(:Concept)
# (:Model)-[:IS_A]->(:Model)
# (:Model)-[:HAS_RESTRICTIONS]->(:Model)
# (:Model)-[:RELEASED_BY]->(:Organization)
# (:Model)-[:RELEASE_DATE]->(:Date)
# (:Model)-[:ACCESS_GRANTED_BY]->(:Organization)
# (:Model)-[:SHARED_VIA]->(:Platform)
# (:Model)-[:DMCA_TAKEDOWN_REQUEST]->(:Platform)
# (:Model)-[:TRAINED_AT_PARAMETER_SIZES]->(:Model)
# (:Model)-[:LICENSED_UNDER]->(:License)
# (:Model)-[:HAS_LICENSE]->(:License)
# (:Model)-[:MORE_POWERFUL_THAN]->(:Model)
# (:Model)-[:IS_MOST_POWERFUL]->(:Leaderboard)
# (:Model)-[:IS_MORE_POWERFUL_THAN]->(:Model)
# (:Model)-[:IS_LESS_POWERFUL_THAN]->(:Model)
# (:Model)-[:IS_LESS_POWERFUL_THAN]->(:Technology)
# (:Model)-[:LESS_POWERFUL_THAN]->(:Model)
# (:Model)-[:LESS_POWERFUL_THAN]->(:Technology)
# (:Model)-[:RANKED_IN]->(:Leaderboard)
# (:Model)-[:INSPIRED_BY]->(:Person)
# (:Model)-[:VERSION_OF]->(:Language model)
# (:Model)-[:VERSION_OF]->(:Software)
# (:Model)-[:VERSION_OF]->(:Version)
# (:Model)-[:PARTNERED_WITH]->(:Company)
# (:Model)-[:HAS_VERSION]->(:Language model)
# (:Model)-[:HAS_VERSION]->(:Software)
# (:Model)-[:HAS_VERSION]->(:Version)
# (:Model)-[:RELEASED_ON]->(:Date)
# (:Model)-[:FINE_TUNED_WITH]->(:Concept)
# (:Model)-[:IS_A_FAMILY_OF]->(:Model)
# (:Model)-[:IS_A_FAMILY_OF]->(:Person)
# (:Model)-[:IS_A_FAMILY_OF]->(:Ai model)
# (:Model)-[:IS_A_FAMILY_OF]->(:Ai assistant)
# (:Model)-[:IS_A_FAMILY_OF]->(:Language model)
# (:Model)-[:IS_A_FAMILY_OF]->(:Software)
# (:Model)-[:IS_A_FAMILY_OF]->(:Version)
# (:Model)-[:INCLUDES]->(:Model)
# (:Model)-[:INCLUDES]->(:Feature)
# (:Model)-[:HANDLES]->(:Measurement)
# (:Model)-[:EQUIVALENT_TO]->(:Measurement)
# (:Model)-[:DEMONSTRATES_ABILITY]->(:Concept)
# (:Model)-[:EQUALS]->(:Measurement)
# (:Model)-[:WINDOW_SIZE]->(:Measurement)
# (:Model)-[:FINE-TUNED_TO_ALIGN_WITH]->(:Model)
# (:Model)-[:FINE-TUNED_TO_ALIGN_WITH]->(:Person)
# (:Model)-[:FINE-TUNED_TO_ALIGN_WITH]->(:Ai model)
# (:Model)-[:FINE-TUNED_TO_ALIGN_WITH]->(:Ai assistant)
# (:Model)-[:FINE-TUNED_TO_ALIGN_WITH]->(:Language model)
# (:Model)-[:FINE-TUNED_TO_ALIGN_WITH]->(:Software)
# (:Model)-[:FINE-TUNED_TO_ALIGN_WITH]->(:Version)
# (:Model)-[:HAS]->(:Concept)
# (:Model)-[:USES]->(:Service)
# (:Model)-[:IS_POWERFUL_MODEL]->(:Leaderboard)
# (:Model)-[:TRAINED_ON]->(:Dataset)
# (:Model)-[:ACHIEVED]->(:Concept)
# (:Model)-[:SUCCESSOR_OF]->(:Model)
# (:Model)-[:INVESTIGATED]->(:Concept)
# (:Model)-[:INVESTIGATED]->(:Model)
# (:Model)-[:INVESTIGATED]->(:Technology)
# (:Timeperiod)-[:RELEVANT_TO]->(:Timeperiod)
# (:Dataset)-[:TRAINED_ON]->(:Timeperiod)
# (:Dataset)-[:TRAINED_ON]->(:Concept)
# (:Dataset)-[:CONSTRUCTED]->(:Timeperiod)
# (:Dataset)-[:CONSTRUCTED_FROM]->(:Concept)
# (:Dataset)-[:USED_TO_TRAIN]->(:Concept)
# (:Dataset)-[:USED_TO_TRAIN]->(:Model)
# (:Dataset)-[:USED_TO_TRAIN]->(:Entity)
# (:Organization)-[:CONVERTED_TO]->(:Concept)
# (:Organization)-[:INTRODUCED]->(:Technology)
# (:Organization)-[:INTRODUCED]->(:Architecture)
# (:Organization)-[:RESEARCHED]->(:Technology)
# (:Organization)-[:RESEARCHED]->(:Architecture)
# (:Organization)-[:DEVELOPER]->(:Model)
# (:Organization)-[:DEVELOPER]->(:Technology)
# (:Organization)-[:DEVELOPS]->(:Model)
# (:Organization)-[:DEVELOPS]->(:Technology)
# (:Organization)-[:PARTNERED_WITH]->(:Company)
# (:Organization)-[:PERFORMED]->(:Concept)
# (:Event)-[:PRESENTED_AT]->(:Concept)
# (:Event)-[:PRESENTED]->(:Organization)
# (:Technology)-[:INTRODUCED]->(:Paper)
# (:Technology)-[:IMPROVED_UPON]->(:Concept)
# (:Technology)-[:IMPROVED_UPON]->(:Technology)
# (:Technology)-[:BASED_ON]->(:Paper)
# (:Technology)-[:BASED_ON]->(:Technology)
# (:Technology)-[:BASED_ON]->(:Architecture)
# (:Technology)-[:IS_BASED_ON]->(:Paper)
# (:Technology)-[:IS_BASED_ON]->(:Technology)
# (:Technology)-[:IS_BASED_ON]->(:Architecture)
# (:Technology)-[:RELATED_TO]->(:Architecture)
# (:Technology)-[:RELATED_TO]->(:Concept)
# (:Technology)-[:RELATED_TO]->(:Model)
# (:Technology)-[:RELATED_TO]->(:Technology)
# (:Technology)-[:MODEL_TYPE]->(:Concept)
# (:Technology)-[:MODEL_TYPE]->(:Technology)
# (:Technology)-[:ENCODER_ONLY_MODEL]->(:Concept)
# (:Technology)-[:ENCODER_ONLY_MODEL]->(:Technology)
# (:Technology)-[:AVAILABLE_VIA_API]->(:Organization)
# (:Technology)-[:DEVELOPED_BY]->(:Organization)
# (:Technology)-[:AVAILABLE_VIA]->(:Year)
# (:Technology)-[:RELEASED]->(:Year)
# (:Technology)-[:COMPETITION]->(:Model)
# (:Paper)-[:IMPROVED_UPON]->(:Technology)
# (:Paper)-[:IMPROVES_UPON]->(:Technology)
# (:Person)-[:DEVELOPED]->(:Technology)
# (:Person)-[:DEVELOPED]->(:Architecture)
# (:Person)-[:INSPIRED_BY]->(:Person)
# (:Person)-[:VERSION_OF]->(:Language model)
# (:Person)-[:VERSION_OF]->(:Software)
# (:Person)-[:VERSION_OF]->(:Version)
# (:Person)-[:PARTNERED_WITH]->(:Company)
# (:Person)-[:HAS_VERSION]->(:Language model)
# (:Person)-[:HAS_VERSION]->(:Software)
# (:Person)-[:HAS_VERSION]->(:Version)
# (:Person)-[:RELEASED_ON]->(:Date)
# (:Person)-[:RELEASED]->(:Date)
# (:Person)-[:RELEASED]->(:Model)
# (:Person)-[:FINE_TUNED_WITH]->(:Concept)
# (:Person)-[:IS_A_FAMILY_OF]->(:Model)
# (:Person)-[:IS_A_FAMILY_OF]->(:Person)
# (:Person)-[:IS_A_FAMILY_OF]->(:Ai model)
# (:Person)-[:IS_A_FAMILY_OF]->(:Ai assistant)
# (:Person)-[:IS_A_FAMILY_OF]->(:Language model)
# (:Person)-[:IS_A_FAMILY_OF]->(:Software)
# (:Person)-[:IS_A_FAMILY_OF]->(:Version)
# (:Person)-[:DEVELOPED_BY]->(:Organization)
# (:Person)-[:DEVELOPED_BY]->(:Company)
# (:Person)-[:OBSERVED_IN]->(:Concept)
# (:Person)-[:COMMENTED_ON]->(:Model)
# (:Person)-[:COMMENTED_ON]->(:Technology)
# (:Architecture)-[:INTRODUCED]->(:Paper)
# (:Architecture)-[:IMPROVED_UPON]->(:Concept)
# (:Architecture)-[:IMPROVED_UPON]->(:Technology)
# (:Architecture)-[:BASED_ON]->(:Paper)
# (:Architecture)-[:BASED_ON]->(:Model)
# (:Architecture)-[:BASED_ON]->(:Architecture)
# (:Architecture)-[:IS_BASED_ON]->(:Paper)
# (:Architecture)-[:RELATED_TO]->(:Architecture)
# (:Architecture)-[:RELATED_TO]->(:Model)
# (:Ai model)-[:INSPIRED_BY]->(:Person)
# (:Ai model)-[:VERSION_OF]->(:Language model)
# (:Ai model)-[:VERSION_OF]->(:Software)
# (:Ai model)-[:VERSION_OF]->(:Version)
# (:Ai model)-[:PARTNERED_WITH]->(:Company)
# (:Ai model)-[:HAS_VERSION]->(:Language model)
# (:Ai model)-[:HAS_VERSION]->(:Software)
# (:Ai model)-[:HAS_VERSION]->(:Version)
# (:Ai model)-[:RELEASED_ON]->(:Date)
# (:Ai model)-[:RELEASED]->(:Date)
# (:Ai model)-[:RELEASED]->(:Model)
# (:Ai model)-[:FINE_TUNED_WITH]->(:Concept)
# (:Ai model)-[:IS_A_FAMILY_OF]->(:Model)
# (:Ai model)-[:IS_A_FAMILY_OF]->(:Person)
# (:Ai model)-[:IS_A_FAMILY_OF]->(:Ai model)
# (:Ai model)-[:IS_A_FAMILY_OF]->(:Ai assistant)
# (:Ai model)-[:IS_A_FAMILY_OF]->(:Language model)
# (:Ai model)-[:IS_A_FAMILY_OF]->(:Software)
# (:Ai model)-[:IS_A_FAMILY_OF]->(:Version)
# (:Ai model)-[:DEVELOPED_BY]->(:Organization)
# (:Ai model)-[:DEVELOPED_BY]->(:Company)
# (:Entity)-[:PARTICIPATES_IN]->(:Concept)
# (:Entity)-[:USES]->(:Concept)
# (:Entity)-[:GENERATES]->(:Concept)
# (:Entity)-[:REVISES]->(:Concept)
# (:Entity)-[:PERFORMS]->(:Concept)
# (:Entity)-[:BASED_ON]->(:Document)
# (:Entity)-[:BASED_ON]->(:Concept)
# (:Entity)-[:FINE-TUNED_TO_ALIGN_WITH]->(:Model)
# (:Entity)-[:FINE-TUNED_TO_ALIGN_WITH]->(:Person)
# (:Entity)-[:FINE-TUNED_TO_ALIGN_WITH]->(:Ai model)
# (:Entity)-[:FINE-TUNED_TO_ALIGN_WITH]->(:Ai assistant)
# (:Entity)-[:FINE-TUNED_TO_ALIGN_WITH]->(:Language model)
# (:Entity)-[:FINE-TUNED_TO_ALIGN_WITH]->(:Software)
# (:Entity)-[:FINE-TUNED_TO_ALIGN_WITH]->(:Version)
# (:Entity)-[:TESTED_DURING]->(:Concept)
# (:Entity)-[:RELATED_TO]->(:Entity)
# (:Entity)-[:RELATED_TO]->(:Variable)
# (:Entity)-[:TRAINS]->(:Concept)
# (:Entity)-[:TRAINS]->(:Model)
# (:Entity)-[:TRAINS]->(:Entity)
# (:Entity)-[:COMPARES]->(:Concept)
# (:Entity)-[:COMPLIANCE_WITH]->(:Document)
# (:Entity)-[:COMPLIANCE_WITH]->(:Concept)
# (:Ai assistant)-[:INSPIRED_BY]->(:Person)
# (:Ai assistant)-[:VERSION_OF]->(:Language model)
# (:Ai assistant)-[:VERSION_OF]->(:Software)
# (:Ai assistant)-[:VERSION_OF]->(:Version)
# (:Ai assistant)-[:PARTNERED_WITH]->(:Company)
# (:Ai assistant)-[:HAS_VERSION]->(:Language model)
# (:Ai assistant)-[:HAS_VERSION]->(:Software)
# (:Ai assistant)-[:HAS_VERSION]->(:Version)
# (:Ai assistant)-[:RELEASED_ON]->(:Date)
# (:Ai assistant)-[:RELEASED]->(:Date)
# (:Ai assistant)-[:RELEASED]->(:Model)
# (:Ai assistant)-[:FINE_TUNED_WITH]->(:Concept)
# (:Ai assistant)-[:IS_A_FAMILY_OF]->(:Model)
# (:Ai assistant)-[:IS_A_FAMILY_OF]->(:Person)
# (:Ai assistant)-[:IS_A_FAMILY_OF]->(:Ai model)
# (:Ai assistant)-[:IS_A_FAMILY_OF]->(:Ai assistant)
# (:Ai assistant)-[:IS_A_FAMILY_OF]->(:Language model)
# (:Ai assistant)-[:IS_A_FAMILY_OF]->(:Software)
# (:Ai assistant)-[:IS_A_FAMILY_OF]->(:Version)
# (:Ai assistant)-[:DEVELOPED_BY]->(:Organization)
# (:Ai assistant)-[:DEVELOPED_BY]->(:Company)
# (:Technique)-[:SIMILAR_TO]->(:Concept)
# (:Technique)-[:SIMILAR_TO]->(:Model)
# (:Technique)-[:SIMILAR_TO]->(:Entity)
# (:Language model)-[:INSPIRED_BY]->(:Person)
# (:Language model)-[:VERSION_OF]->(:Language model)
# (:Language model)-[:VERSION_OF]->(:Software)
# (:Language model)-[:VERSION_OF]->(:Version)
# (:Language model)-[:PARTNERED_WITH]->(:Company)
# (:Language model)-[:HAS_VERSION]->(:Language model)
# (:Language model)-[:HAS_VERSION]->(:Software)
# (:Language model)-[:HAS_VERSION]->(:Version)
# (:Language model)-[:RELEASED_ON]->(:Date)
# (:Language model)-[:RELEASED]->(:Date)
# (:Language model)-[:RELEASED]->(:Model)
# (:Language model)-[:FINE_TUNED_WITH]->(:Concept)
# (:Language model)-[:IS_A_FAMILY_OF]->(:Model)
# (:Language model)-[:IS_A_FAMILY_OF]->(:Person)
# (:Language model)-[:IS_A_FAMILY_OF]->(:Ai model)
# (:Language model)-[:IS_A_FAMILY_OF]->(:Ai assistant)
# (:Language model)-[:IS_A_FAMILY_OF]->(:Language model)
# (:Language model)-[:IS_A_FAMILY_OF]->(:Software)
# (:Language model)-[:IS_A_FAMILY_OF]->(:Version)
# (:Language model)-[:DEVELOPED_BY]->(:Organization)
# (:Language model)-[:DEVELOPED_BY]->(:Company)
# (:Company)-[:PARTNERED_WITH]->(:Company)
# (:Software)-[:INSPIRED_BY]->(:Person)
# (:Software)-[:VERSION_OF]->(:Language model)
# (:Software)-[:VERSION_OF]->(:Software)
# (:Software)-[:VERSION_OF]->(:Version)
# (:Software)-[:PARTNERED_WITH]->(:Company)
# (:Software)-[:HAS_VERSION]->(:Language model)
# (:Software)-[:HAS_VERSION]->(:Software)
# (:Software)-[:HAS_VERSION]->(:Version)
# (:Software)-[:RELEASED_ON]->(:Date)
# (:Software)-[:RELEASED]->(:Date)
# (:Software)-[:RELEASED]->(:Model)
# (:Software)-[:FINE_TUNED_WITH]->(:Concept)
# (:Software)-[:IS_A_FAMILY_OF]->(:Model)
# (:Software)-[:IS_A_FAMILY_OF]->(:Person)
# (:Software)-[:IS_A_FAMILY_OF]->(:Ai model)
# (:Software)-[:IS_A_FAMILY_OF]->(:Ai assistant)
# (:Software)-[:IS_A_FAMILY_OF]->(:Language model)
# (:Software)-[:IS_A_FAMILY_OF]->(:Software)
# (:Software)-[:IS_A_FAMILY_OF]->(:Version)
# (:Software)-[:DEVELOPED_BY]->(:Organization)
# (:Software)-[:DEVELOPED_BY]->(:Company)
# (:Software)-[:IS_ITERATION_OF]->(:Model)
# (:Software)-[:IS_ITERATION_OF]->(:Person)
# (:Software)-[:IS_ITERATION_OF]->(:Ai model)
# (:Software)-[:IS_ITERATION_OF]->(:Ai assistant)
# (:Software)-[:IS_ITERATION_OF]->(:Language model)
# (:Software)-[:IS_ITERATION_OF]->(:Software)
# (:Software)-[:IS_ITERATION_OF]->(:Version)
# (:Software)-[:RELEASED_BY]->(:Organization)
# (:Software)-[:RELEASED_BY]->(:Company)
# (:Software)-[:UPGRADE]->(:Product)
# (:Software)-[:NEXT_ITERATION]->(:Model)
# (:Software)-[:NEXT_ITERATION]->(:Person)
# (:Software)-[:NEXT_ITERATION]->(:Ai model)
# (:Software)-[:NEXT_ITERATION]->(:Ai assistant)
# (:Software)-[:NEXT_ITERATION]->(:Language model)
# (:Software)-[:NEXT_ITERATION]->(:Software)
# (:Software)-[:NEXT_ITERATION]->(:Version)
# (:Software)-[:RELEASED_AFTER]->(:Software)
# (:Software)-[:RELEASED_AFTER]->(:Product)
# (:Software)-[:RELEASED_AFTER]->(:Version)
# (:Software)-[:FEATURES]->(:Software)
# (:Software)-[:FEATURES]->(:Product)
# (:Software)-[:FEATURES]->(:Version)
# (:Software)-[:SUCCESSOR]->(:Software)
# (:Software)-[:SUCCESSOR]->(:Product)
# (:Software)-[:SUCCESSOR]->(:Version)
# (:Software)-[:APPROVED_BY]->(:Organization)
# (:Software)-[:APPROVED_BY]->(:Company)
# (:Product)-[:IS_ITERATION_OF]->(:Model)
# (:Product)-[:IS_ITERATION_OF]->(:Person)
# (:Product)-[:IS_ITERATION_OF]->(:Ai model)
# (:Product)-[:IS_ITERATION_OF]->(:Ai assistant)
# (:Product)-[:IS_ITERATION_OF]->(:Language model)
# (:Product)-[:IS_ITERATION_OF]->(:Software)
# (:Product)-[:IS_ITERATION_OF]->(:Version)
# (:Product)-[:RELEASED_BY]->(:Organization)
# (:Product)-[:RELEASED_BY]->(:Company)
# (:Product)-[:UPGRADE]->(:Product)
# (:Product)-[:NEXT_ITERATION]->(:Model)
# (:Product)-[:NEXT_ITERATION]->(:Person)
# (:Product)-[:NEXT_ITERATION]->(:Ai model)
# (:Product)-[:NEXT_ITERATION]->(:Ai assistant)
# (:Product)-[:NEXT_ITERATION]->(:Language model)
# (:Product)-[:NEXT_ITERATION]->(:Software)
# (:Product)-[:NEXT_ITERATION]->(:Version)
# (:Product)-[:RELEASED_AFTER]->(:Software)
# (:Product)-[:RELEASED_AFTER]->(:Product)
# (:Product)-[:RELEASED_AFTER]->(:Version)
# (:Product)-[:FEATURES]->(:Software)
# (:Product)-[:FEATURES]->(:Product)
# (:Product)-[:FEATURES]->(:Version)
# (:Product)-[:SUCCESSOR]->(:Software)
# (:Product)-[:SUCCESSOR]->(:Product)
# (:Product)-[:SUCCESSOR]->(:Version)
# (:Product)-[:APPROVED_BY]->(:Organization)
# (:Product)-[:APPROVED_BY]->(:Company)
# (:Product)-[:DOUBLED_CONTEXT_WINDOW]->(:Measurement)
# (:Unknown)-[:SUBTRACTION]->(:Variable)
# (:Variable)-[:SUBTRACTION]->(:Variable)
# (:Variable)-[:SUBTRACTION]->(:Constant)
# (:Variable)-[:INPUT_FOR]->(:Concept)
# (:Variable)-[:INPUT_FOR]->(:Function)
# (:Variable)-[:IS_A]->(:Concept)
# (:Variable)-[:INPUT_TO]->(:Concept)
# (:Variable)-[:INPUT_TO]->(:Function)
# (:Variable)-[:DEPENDS_ON]->(:Entity)
# (:Variable)-[:DEPENDS_ON]->(:Function)
# (:Mathematical expression)-[:DEPENDENT_ON]->(:Mathematical expression)
# (:Mathematical expression)-[:DEPENDENT_ON]->(:Mathematicalexpression)
# (:Mathematical expression)-[:DEFINED_AS]->(:Mathematical expression)
# (:Mathematical expression)-[:DEFINED_AS]->(:Mathematicalexpression)
# (:Function)-[:RELATED_TO]->(:Entity)
# (:Function)-[:RELATED_TO]->(:Variable)
# (:Function)-[:INPUT_FOR]->(:Variable)
# (:Function)-[:IS_A]->(:Concept)
# (:Function)-[:TAKES_ARGUMENT]->(:Entity)
# (:Function)-[:TAKES_ARGUMENT]->(:Variable)
# (:Function)-[:IS_A_FUNCTION_OF]->(:Concept)
# (:Function)-[:IS]->(:Concept)
# (:Parameter)-[:INPUT_FOR]->(:Concept)
# (:Parameter)-[:INPUT_FOR]->(:Function)
# (:Parameter)-[:IS_A]->(:Concept)
# (:Parameter)-[:INPUT_TO]->(:Concept)
# (:Parameter)-[:INPUT_TO]->(:Function)
# (:Process)-[:INCLUDES]->(:Process)
# (:Version)-[:INSPIRED_BY]->(:Person)
# (:Version)-[:VERSION_OF]->(:Language model)
# (:Version)-[:VERSION_OF]->(:Software)
# (:Version)-[:VERSION_OF]->(:Version)
# (:Version)-[:PARTNERED_WITH]->(:Company)
# (:Version)-[:HAS_VERSION]->(:Language model)
# (:Version)-[:HAS_VERSION]->(:Software)
# (:Version)-[:HAS_VERSION]->(:Version)
# (:Version)-[:RELEASED_ON]->(:Date)
# (:Version)-[:RELEASED]->(:Date)
# (:Version)-[:RELEASED]->(:Model)
# (:Version)-[:FINE_TUNED_WITH]->(:Concept)
# (:Version)-[:IS_A_FAMILY_OF]->(:Model)
# (:Version)-[:IS_A_FAMILY_OF]->(:Person)
# (:Version)-[:IS_A_FAMILY_OF]->(:Ai model)
# (:Version)-[:IS_A_FAMILY_OF]->(:Ai assistant)
# (:Version)-[:IS_A_FAMILY_OF]->(:Language model)
# (:Version)-[:IS_A_FAMILY_OF]->(:Software)
# (:Version)-[:IS_A_FAMILY_OF]->(:Version)
# (:Version)-[:DEVELOPED_BY]->(:Organization)
# (:Version)-[:DEVELOPED_BY]->(:Company)
# (:Version)-[:IS_ITERATION_OF]->(:Model)
# (:Version)-[:IS_ITERATION_OF]->(:Person)
# (:Version)-[:IS_ITERATION_OF]->(:Ai model)
# (:Version)-[:IS_ITERATION_OF]->(:Ai assistant)
# (:Version)-[:IS_ITERATION_OF]->(:Language model)
# (:Version)-[:IS_ITERATION_OF]->(:Software)
# (:Version)-[:IS_ITERATION_OF]->(:Version)
# (:Version)-[:RELEASED_BY]->(:Organization)
# (:Version)-[:RELEASED_BY]->(:Company)
# (:Version)-[:UPGRADE]->(:Product)
# (:Version)-[:NEXT_ITERATION]->(:Model)
# (:Version)-[:NEXT_ITERATION]->(:Person)
# (:Version)-[:NEXT_ITERATION]->(:Ai model)
# (:Version)-[:NEXT_ITERATION]->(:Ai assistant)
# (:Version)-[:NEXT_ITERATION]->(:Language model)
# (:Version)-[:NEXT_ITERATION]->(:Software)
# (:Version)-[:NEXT_ITERATION]->(:Version)
# (:Version)-[:RELEASED_AFTER]->(:Software)
# (:Version)-[:RELEASED_AFTER]->(:Product)
# (:Version)-[:RELEASED_AFTER]->(:Version)
# (:Version)-[:FEATURES]->(:Software)
# (:Version)-[:FEATURES]->(:Product)
# (:Version)-[:FEATURES]->(:Version)
# (:Version)-[:SUCCESSOR]->(:Software)
# (:Version)-[:SUCCESSOR]->(:Product)
# (:Version)-[:SUCCESSOR]->(:Version)
# (:Version)-[:APPROVED_BY]->(:Organization)
# (:Version)-[:APPROVED_BY]->(:Company)
# (:Mathematicalexpression)-[:DEPENDENT_ON]->(:Mathematical expression)
# (:Mathematicalexpression)-[:DEPENDENT_ON]->(:Mathematicalexpression)
# (:Mathematicalexpression)-[:DEFINED_AS]->(:Mathematical expression)
# (:Mathematicalexpression)-[:DEFINED_AS]->(:Mathematicalexpression)

# %% [markdown]
# ![](images/graph-pdf.png)

# %% [markdown]
# ![](images/graph.pilot-man.png)

# %% [markdown]
# #### Few shot prompting

# %%
from langchain_core.prompts import FewShotPromptTemplate, PromptTemplate

examples = [
    {
        "question": "How many notable large language models are mentioned in the article?",
        "query": "MATCH (m:Concept {id: 'Large Language Model'}) RETURN count(DISTINCT m)",
    },
    {
        "question": "Which companies or organizations have developed the large language models mentioned?",
        "query": "MATCH (o:Organization)-[:DEVELOPS]->(m:Concept {id: 'Large Language Model'}) RETURN DISTINCT o.id",
    },
    {
        "question": "What is the largest model size mentioned in the article, in terms of number of parameters?",
        "query": "MATCH (m:Concept {id: 'Large Language Model'}) RETURN max(m.parameters) AS largest_model",
    },
]

example_prompt = PromptTemplate.from_template(
    "User input: {question}\nCypher query: {query}")

cypher_prompt = FewShotPromptTemplate(
    examples=examples,
    example_prompt=example_prompt,
    prefix="You are a Neo4j expert. Given an input question, create a syntactically correct Cypher query to run.\n\nHere is the schema information\n{schema}.\n\n Below are a number of examples of questions and their corresponding Cypher queries.",
    suffix="User input: {question}\nCypher query: ",
    input_variables=["question"],
)

print(cypher_prompt)
llm=ChatOpenAI(api_key=openai_api_key, temperature=0, model_name="gpt-3.5-turbo")
# Create the graph Cypher QA chain
graph_qa_chain = GraphCypherQAChain.from_llm(
    llm=llm, graph=graph, verbose=True, validate_cypher=True)

# Invoke the chain with the input provided
result = graph_qa_chain.invoke({"query": "Which organization created Gpt-3?"})
print(f"Final answer: {result['result']}")
# Out:
# input_variables=['question', 'schema'] examples=[{'question': 'How many notable large language models are mentioned in the article?', 'query': "MATCH (m:Concept {id: 'Large Language Model'}) RETURN count(DISTINCT m)"}, {'question': 'Which companies or organizations have developed the large language models mentioned?', 'query': "MATCH (o:Organization)-[:DEVELOPS]->(m:Concept {id: 'Large Language Model'}) RETURN DISTINCT o.id"}, {'question': 'What is the largest model size mentioned in the article, in terms of number of parameters?', 'query': "MATCH (m:Concept {id: 'Large Language Model'}) RETURN max(m.parameters) AS largest_model"}] example_prompt=PromptTemplate(input_variables=['query', 'question'], template='User input: {question}\nCypher query: {query}') suffix='User input: {question}\nCypher query: ' prefix='You are a Neo4j expert. Given an input question, create a syntactically correct Cypher query to run.\n\nHere is the schema information\n{schema}.\n\n Below are a number of examples of questions and their corresponding Cypher queries.'
#
#
# > Entering new GraphCypherQAChain chain...
# Generated Cypher:
# MATCH (o:Organization)<-[:DEVELOPED_BY]-(:Model {id: "Gpt-3"})
# RETURN o;
# Full Context:
# [{'o': {'id': 'Openai'}}]
#
# > Finished chain.
# Final answer: Openai created Gpt-3.
