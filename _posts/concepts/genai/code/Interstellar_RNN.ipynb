# %% [markdown]
# # Code for the post https://medium.com/p/3f06d7653a85/edit
#
# Code is from below links with minor changes made for the blog post.
#
# References:
#     https://gist.github.com/karpathy/d4dee566867f8291f086
#
#     https://gist.github.com/satyajitvg/9a5f782ccef5ff81f7f9863b62218b06

# %%
"""
Minimal character-level Vanilla RNN model. Written by Andrej Karpathy (@karpathy)
BSD License
"""
# Out:
# '\nMinimal character-level Vanilla RNN model. Written by Andrej Karpathy (@karpathy)\nBSD License\n'

# %%
import numpy as np


# To read the training data and make a vocabulary and dictiornary to index the chars
class DataReader:
    def __init__(self, path, seq_length):
        #uncomment below , if you dont want to use any file for text reading and comment next 2 lines
        #self.data = "some really long text to test this. maybe not perfect but should get you going."
        self.fp = open(path, "r")
        self.data = self.fp.read()
        #find unique chars
        chars = list(set(self.data))
        #create dictionary mapping for each char
        self.char_to_ix = {ch:i for (i,ch) in enumerate(chars)}
        self.ix_to_char = {i:ch for (i,ch) in enumerate(chars)}
        #total data
        self.data_size = len(self.data)
        #num of unique chars
        self.vocab_size = len(chars)
        self.pointer = 0
        self.seq_length = seq_length

    def next_batch(self):
        input_start = self.pointer
        input_end = self.pointer + self.seq_length
        inputs = [self.char_to_ix[ch] for ch in self.data[input_start:input_end]]
        targets = [self.char_to_ix[ch] for ch in self.data[input_start+1:input_end+1]]
        self.pointer += self.seq_length
        if self.pointer + self.seq_length + 1 >= self.data_size:
            # reset pointer
            self.pointer = 0
        return inputs, targets

    def just_started(self):
        return self.pointer == 0

    def close(self):
        self.fp.close()

# %%
import numpy as np

class RNN:
    def __init__(self, hidden_size, vocab_size, seq_length, learning_rate):
        # hyper parameters
        self.hidden_size = hidden_size
        self.vocab_size = vocab_size
        self.seq_length = seq_length
        self.learning_rate = learning_rate
        # model parameters
        self.U = np.random.uniform(-np.sqrt(1./vocab_size), np.sqrt(1./vocab_size), (hidden_size, vocab_size))
        self.V = np.random.uniform(-np.sqrt(1./hidden_size), np.sqrt(1./hidden_size), (vocab_size, hidden_size))
        self.W = np.random.uniform(-np.sqrt(1./hidden_size), np.sqrt(1./hidden_size), (hidden_size, hidden_size))
        self.b = np.zeros((hidden_size, 1)) # bias for hidden layer
        self.c = np.zeros((vocab_size, 1)) # bias for output

        # memory vars for adagrad,
        #ignore if you implement another approach
        self.mU = np.zeros_like(self.U)
        self.mW = np.zeros_like(self.W)
        self.mV = np.zeros_like(self.V)
        self.mb = np.zeros_like(self.b)
        self.mc = np.zeros_like(self.c)

    def softmax(self, x):
        p = np.exp(x- np.max(x))
        return p / np.sum(p)

    def forward(self, inputs, hprev):
        xs, hs, os, ycap = {}, {}, {}, {}
        hs[-1] = np.copy(hprev)
        for t in range(len(inputs)):
            xs[t] = np.zeros((self.vocab_size, 1))
            xs[t][inputs[t]] = 1 # one hot encoding , 1-of-k
            hs[t] = np.tanh(np.dot(self.U,xs[t]) + np.dot(self.W,hs[t-1]) + self.b) # hidden state
            os[t] = np.dot(self.V,hs[t]) + self.c # unnormalised log probs for next char
            ycap[t] = self.softmax(os[t]) # probs for next char
        return xs, hs, ycap

    def backward(self, xs, hs, ps, targets):
        dU, dW, dV = np.zeros_like(self.U), np.zeros_like(self.W), np.zeros_like(self.V)
        db, dc = np.zeros_like(self.b), np.zeros_like(self.c)
        dhnext = np.zeros_like(hs[0])
        for t in reversed(range(self.seq_length)):
            dy = np.copy(ps[t])
            dy[targets[t]] -= 1 # backprop into y
            dV += np.dot(dy, hs[t].T)
            dc += dc
            dh = np.dot(self.V.T, dy) + dhnext # backprop into h
            dhrec = (1 - hs[t] * hs[t]) * dh
            db += dhrec
            dU += np.dot(dhrec, xs[t].T)
            dW += np.dot(dhrec, hs[t-1].T)
            dhnext = np.dot(self.W.T, dhrec)
        for dparam in [dU, dW, dV, db, dc]:
            np.clip(dparam, -5, 5, out=dparam)
        return dU, dW, dV, db, dc

    def loss(self, ps, targets):
        return sum(-np.log(ps[t][targets[t],0]) for t in range(self.seq_length))

    def update_model(self, dU, dW, dV, db, dc):
        for param, dparam, mem in zip([self.U, self.W, self.V, self.b, self.c],
                                      [dU, dW, dV, db, dc],
                                      [self.mU, self.mW, self.mV, self.mb, self.mc]):
            mem += dparam*dparam
            param += -self.learning_rate*dparam/np.sqrt(mem+1e-8)

    def sample(self, h, seed_ix, n):
        x = np.zeros((self.vocab_size, 1))
        x[seed_ix] = 1
        ixes = []
        for t in range(n):
            h = np.tanh(np.dot(self.U, x) + np.dot(self.W, h) + self.b)
            y = np.dot(self.V, h) + self.c
            p = np.exp(y)/np.sum(np.exp(y))
            ix = np.random.choice(range(self.vocab_size), p = p.ravel())
            x = np.zeros((self.vocab_size, 1))
            x[ix] = 1
            ixes.append(ix)
        return ixes

    def train(self, data_reader, num_iterations=5000000):
        iter_num = 0
        smooth_loss = -np.log(1.0 / data_reader.vocab_size) * self.seq_length

        while iter_num <= num_iterations:  # Fixed number of iterations
            if data_reader.just_started():
                hprev = np.zeros((self.hidden_size, 1))
            inputs, targets = data_reader.next_batch()
            xs, hs, ps = self.forward(inputs, hprev)
            dU, dW, dV, db, dc = self.backward(xs, hs, ps, targets)
            loss = self.loss(ps, targets)
            self.update_model(dU, dW, dV, db, dc)
            smooth_loss = smooth_loss * 0.999 + loss * 0.001
            hprev = hs[self.seq_length - 1]
            if iter_num % 10000 == 0:
                sample_ix = self.sample(hprev, inputs[0], 200)
                generated_text = ''.join(data_reader.ix_to_char[ix] for ix in sample_ix)
                # Convert input sequence indices back to characters
                input_text = ''.join(data_reader.ix_to_char[ix] for ix in inputs)
                # Print input and generated text
                print(f"Input: {input_text}")
                print(f"Generated Text: {generated_text}")
                print(f"\n\nIteration: {iter_num}, Loss: {smooth_loss:.4f}")
            iter_num += 1

    def predict(self, data_reader, start, n):
        x = np.zeros((self.vocab_size, 1))
        chars = [ch for ch in start]
        ixes = []
        for i in range(len(chars)):
            ix = data_reader.char_to_ix[chars[i]]
            x[ix] = 1
            ixes.append(ix)

        h = np.zeros((self.hidden_size,1))
        for t in range(n):
            h = np.tanh(np.dot(self.U, x) + np.dot(self.W, h) + self.b)
            y = np.dot(self.V, h) + self.c
            p = np.exp(y)/np.sum(np.exp(y))
            ix = np.random.choice(range(self.vocab_size), p = p.ravel())
            x = np.zeros((self.vocab_size, 1))
            x[ix] = 1
            ixes.append(ix)
        txt = ''.join(data_reader.ix_to_char[i] for i in ixes)
        return txt

# %%
seq_length = 25
#read text from the "input.txt" file
#data_reader = DataReader("interstellar_summary.txt", seq_length)
data_reader = DataReader("interstellar_summary_condensed.txt", seq_length)
rnn = RNN(hidden_size=100, vocab_size=data_reader.vocab_size,seq_length=seq_length,learning_rate=1e-1)
rnn.train(data_reader)
# Out:
# Input: Interstellar is a 2014 sc
# Generated Text: jf2aCjBbaciyDNvViNEqVN0se4JEviJV2,oyVSniVTMH4d,qtc 4fhDSoRkntsH4 cMyvnEllktND dbS1eHuSllfcMNatJnuqxlnTipN1o.dsa4d14qVjInlrHmrsA4tRnvwIfvs1mtoHw,DdkRfgJxvakea0eNn2dIJf2lunpjojTxkD.wlfHnRp1EeJeojHioScrp
#
#
# Iteration: 0, Loss: 95.7166
# Input: ugh a wormhole near Satur
# Generated Text: , ye. Thes onet and Mithoss timn ar h sactunnd sca tinewlonaute newath hiss ame dila aughter Me Chant ationghy aydekste suathe femi tion and fice personama nath faceseqla 2014 scirviews daughter Murph
#
#
# Iteration: 10000, Loss: 0.7935
# Input: ract enabling communicati
# Generated Text: n across timy sinestion Inapllmion dian Acad, Michael Ate SewathoBrsitrand It naudi awaveyletion ain ficecCoraekive with hie tesserast raugh snaelma Chastris the sawtsinrachew ghtel ffamis s atron drs
#
#
# Iteration: 20000, Loss: 5.9272
# Input:  It stars Matthew McConau
# Generated Text: hrssteml rought andew Mcroes Msca tesseaHa d facte war fugutitiravewshoplly, Ron Bes thevilin dan wommand, Romilly, and sicrs tis na 2 he fa te filetithre fand Matl ghthawon An facey ey Bestsiine. Ave
#
#
# Iteration: 30000, Loss: 8.5578
# Input:  NASA pilot, joins the mi
# Generated Text: siolitughdrsoon teme Hathaway, Jessica Chastain, and upheeray Ear dad gravity equation. The film received positive reviews and won an Academy Award for Best Visual Efray Ef racts amtris daughter Murph
#
#
# Iteration: 40000, Loss: 1.6748
# Input:  the gravity equation. Th
# Generated Text: scientists Brand, Romilly, and Doyle. They explore planets ar Chrughe fected by with eosisathramine. A groupxs. Cooper discovers a tesseract enabling communication across time with his daughter Murph,
#
#
# Iteration: 50000, Loss: 0.2538
# Input:  Caine. Set in a dystopia
# Generated Text: d sce ste wathew Mand fa the ss arp eotimhee. The fice dind amat, Michael Caine. Set in a dystopian future, Earth faces blight and famine. A group of astronauts travels through a wormhole near Saturn
#
#
# Iteration: 60000, Loss: 0.1923
# Input: hey explore planets affec
# Generated Text: e. The faigd for Best Visual Efromilly, and Michaes Matthew McConaughey, Anne Hathaway, Jessica Chastain, and Michael Caine. Set in a dystopian future, Earth faces blight and famine. A group ormhole n
#
#
# Iteration: 70000, Loss: 0.1276
# Input: y Award for Best Visual E
# Generated Text: rronap oomund fane ter Murphter Murph, who solves the gravity equation. The film received positive rive Chal tin abliy, Jessica Chastain, and Michael Caine. Set in a dystopian future, Earth faces blig
#
#
# Iteration: 80000, Loss: 0.1138
# Input: f astronauts travels thro
# Generated Text: aeno, aet, AntieneeHat, Amard Doyle. They explore planets affected by time dilation and face personal sacrifices. Cooper discovers a tesseract enabling communication across time with his daughter Murp
#
#
# Iteration: 90000, Loss: 0.1798
# Input:  Cooper discovers a tesse
# Generated Text: Hath d won and by time dilation and face personal sacrifices. Cooper discovers a tesseract enabling communication across time with his daughter Murph, who solves the gravity equation. The film receive
#
#
# Iteration: 100000, Loss: 0.0781
# Input: ted by Christopher Nolan.
# Generated Text: Itopily, Ror ling communication across time with his daughter Murph, who solves the gravity equation. The film received positive reviews and won an Academy Award for Best Visual Efrsca tesse Hath warn
#
#
# Iteration: 110000, Loss: 0.0653
# Input: mankind. Cooper, a former
# Generated Text:  and cestion drama directed by Christopher Nolan. It stars Matthew McConaughey, Anne Hathaway, Jessica Chastain, and Michael Caine. Set in a dystopian future, Earth faces blight and famine. A group of
#
#
# Iteration: 120000, Loss: 0.0571
# Input: aughter Murph, who solves
# Generated Text: nd face personal sacrifices. Cooper discovers a tesseract enabling communication across time with his daughter Murph, who solves the gravity equation. The film received positive reviews and won an Aca
#
#
# Iteration: 130000, Loss: 0.0633
# Input: ica Chastain, and Michael
# Generated Text: y, and Michaes Rommeril Caine. Set in d dystopian urthe wisca tesse Hath ward for Best Visual Ef rough a wormhole near Saturn seeking a new home for mankind. Cooper, a former NASA pilot, joins the mis
#
#
# Iteration: 140000, Loss: 0.0578
# Input: nd, Romilly, and Doyle. T
# Generated Text: epeaHa d sosscerant won an Academy Award for Best Visual Ef racton and ramine. A group of astronauts travels through a wormhole near Saturn seeking a new home for mankind. Cooper, a former NASA pilot,
#
#
# Iteration: 150000, Loss: 0.0469
# Input: reviews and won an Academ
# Generated Text: opeareviestey. The plarmend for Best Visual Ef ten anaughey, Anne Hathaway, Jessica Chastain, and Michael Caine. Set in a dystopian future, Earth faces blight and famine. A group of astronauts travels
#
#
# Iteration: 160000, Loss: 0.0409
# Input: ght and famine. A group o
# Generated Text:  aed by thropler diay Efrscoiver, a former NASA pilot, joins the mission with scientists Brand, Romilly, and Doyle. They explore planets affected by time dilation and face personal sacrifices. Cooper
#
#
# Iteration: 170000, Loss: 0.0370
# Input: face personal sacrifices.
# Generated Text: Set in acres ne Cathew Mand aufay, Jessica Chtist Visual Ef racton and Caine. Se fonices an Atithive reviews and won an Academy Award for Best Visual Ef rough a wormhole near Saturn seeking a new home
#
#
# Iteration: 180000, Loss: 0.0342
# Input: ience fiction drama direc
# Generated Text: on across time Cyth faclove nllathe Jerpilan. It sta Bes ana wormhole near Saturn seeking a new home for mankind. Cooper, a former NASA pilot, joins the mission with scientists Brand, Romilly, and Doy
#
#
# Iteration: 190000, Loss: 0.0318
# Input: n seeking a new home for
# Generated Text:  amine. A group of astronauts travels through a wormhole near Saturn seeking a new home for Sature, sacrifices an whivive Chrsetly Murph, who solves the gravity equation autu ney they. Saturn seeking
#
#
# Iteration: 200000, Loss: 0.0298
# Input: on across time with his d
# Generated Text: upheer d dewopesotioy, And Michael Caine. Set in a dystopian future, Earth faces blight and famine. A group of astronauts travels through a wormhole near Saturn seeking a new home for mankind. Cooper,
#
#
# Iteration: 210000, Loss: 0.0280
# Input: ghey, Anne Hathaway, Jess
# Generated Text: rthila gravisught aplana goa soy Eara der Nola Ana tion and face personal sacrifices. Cooper discovers a tesseract enabling communication across time with his daughter Murph, who solves the gravity eq
#
#
# Iteration: 220000, Loss: 0.1385
# Input: ssion with scientists Bra
# Generated Text: tamine. uod pisr thriscemughthet and uam a me dilation and face personal sacrifices. Cooper discovers a tesseract enabling communication across time with his daughter Murph, who solves the gravity equ
#
#
# Iteration: 230000, Loss: 0.0327
# Input: e film received positive
# Generated Text: lare. Cooper Noli h, sacrifices. Cooper ho and for Best Visual Efrsca tessiel Ches ellyy Caine stars Matthew McConaughey, Anne Hathaway, Jessica Chastain, and Michael Caine. Set in a dystopian future,
#
#
# Iteration: 240000, Loss: 0.0270
# Input: n future, Earth faces bli
# Generated Text: d Mine r mankind. Cooper, a former NASA pilot, joins the mission with scientists Brand, Romilly, and Doyle. They explore planets affected by time dilation and face personal sacrifices. Cooper discover
#
#
# Iteration: 250000, Loss: 0.0243
# Input: ted by time dilation and
# Generated Text: ity ped by Cath hices blih, sacrif a dystopion tremat phr sorven tesscted bn ay time dilation and face personal sacrifices. Cooper discovers a tesseract enablingacomel gh sima disys, Anne Hathaway, Je
#
#
# Iteration: 260000, Loss: 0.0226
# Input: Interstellar is a 2014 sc
# Generated Text: ant anaufa d, Romilly, and Doyle. They explore planets affected by time dilation and face personal sacrifices. Cooper discovers a tesseract enabling communication across time with his daughter Murph,
#
#
# Iteration: 270000, Loss: 0.0213
# Input: ugh a wormhole near Satur
# Generated Text: he Ha Cat, Earth ha the missiol Coouper, a former NASA pilot, joins the mission with scientists Brand, Romilly, and Doyle. They explore planets affected by time dilation and face personal sacrifices.
#
#
# Iteration: 280000, Loss: 0.0202
# Input: ract enabling communicati
# Generated Text:  NoCaino. Seceed by Christopion across tion drama directed by Christophey e dewopis near Saturn seeking a new home for mankind. Cooper, a former NASA pilot, joins the mission with scientists Brand, Ro
#
#
# Iteration: 290000, Loss: 0.0193
# Input:  It stars Matthew McConau
# Generated Text: d stariview Eiretsone tissina th ain, and Michael Caine. Set in a dystopian future, Earth film received positive reviews and won an Academy Award for Best Visual Ef routupl ston across eraugh jostopl
#
#
# Iteration: 300000, Loss: 0.0185
# Input:  NASA pilot, joins the mi
# Generated Text: ficeinkirave, Miche fientis tro solNAcned. Thes the gravity equat act Core dy doSected by Christopher Nolan. It stars Matthew McConaughey, Anne Hathaway, Jessica Chastain, and Michael Caine. Set in a
#
#
# Iteration: 310000, Loss: 0.0177
# Input:  the gravity equation. Th
# Generated Text: secrews tVisuan an af anteopel s a 2014 science fiction drama disminsion wather McConaughey, Anne Hathaway, Jessica Chastain, and Michael Caine. Set in a dystopian future, Earth faces blight and famin
#
#
# Iteration: 320000, Loss: 0.0171
# Input:  Caine. Set in a dystopia
# Generated Text: tir Nace ped by time dilation and face personal sacrifices. Cooper discovers a tesseract enabling communication across time with his daughter Murph, who solves dpion trama directed by Christopher Nola
#
#
# Iteration: 330000, Loss: 0.0165
# Input: hey explore planets affec
# Generated Text: ed bn across time with his daughter Murph, who solves the gravity equation. The film received positive reviews and won an Academy Award for Best Visual Ef rough a wormhole near Saturn seeking a new ho
#
#
# Iteration: 340000, Loss: 0.0159
# Input: y Award for Best Visual E
# Generated Text:  rona toice Visual Efrasteenilaughter Murph, who solvesscerav lath ward for Best Visual Ef routu per Nolacheel phareScecience ficauper, a former NASA pilerpissiti pen across time tith hos dauughd Mich
#
#
# Iteration: 350000, Loss: 0.0153
# Input: f astronauts travels thro
# Generated Text: aenof astronauts travels through a wormhole near Saturn seeking a new home for mankind. Cooper, a former NASA pilot, joins the mission with scientists Brand, Romilly, and Doyle. They explore planets a
#
#
# Iteration: 360000, Loss: 0.0148
# Input:  Cooper discovers a tesse
# Generated Text: HathawdrDoy, antien eugdophore perns a tesseract enabling communicathew home for mankind. Cooper, a former NASA pilot, joins the mission with scientists Brand, Romilly, and Doyle. They explore planets
#
#
# Iteration: 370000, Loss: 0.0144
# Input: ted by Christopher Nolan.
# Generated Text: I disuugh hos dIughter ha d Conaugh st reve ty equation acrewsta tesse Brand, Romilly, and Doyle. They explore planets affected by time dilation and face personal sacrifices. Cooper discovers a tesser
#
#
# Iteration: 380000, Loss: 0.0140
# Input: mankind. Cooper, a former
# Generated Text:  fforilly, and Doyle. They explore planets affected by time dilation and face personal sacrifices. Cooper discovers a tesseract enabling communication across time with his daughter Murph, who solves t
#
#
# Iteration: 390000, Loss: 0.0135
# Input: aughter Murph, who solves
# Generated Text: ng f sacexplave piction futur, pos tien it dof astronauts travels through a wormhole near Saturn seeking a new home for mankind. Cooper, a former NASA pilot, joins the mission with scientists Brand, R
#
#
# Iteration: 400000, Loss: 0.0132
# Input: ica Chastain, and Michael
# Generated Text: perislanves ctientists Brand, Romilly, and Doyle. They explore planets affected by time dilation and face personal sacrifices. Cooper discovers a tesseract enabling communication across time with his
#
#
# Iteration: 410000, Loss: 0.0128
# Input: nd, Romilly, and Doyle. T
# Generated Text: ey explore planetisation aytew home for mankind. Cooper, a former NASA pilot, joins the missios ain, and Michael Caine. Set in a dystopian futuClissce tien with sciention and face ded by Christopher N
#
#
# Iteration: 420000, Loss: 0.0124
# Input: reviews and won an Academ
# Generated Text: e. Cooper, a for Bes auth way ected by Christopher Nolan. It stars Matthew McConaughey, Anne Hathaway, Jessica Chess tist esits oimenewan. Caine. Set in a dystopian future, Earth faces blight and fami
#
#
# Iteration: 430000, Loss: 0.0121
# Input: ght and famine. A group o
# Generated Text:  ashtint remat thoss an2 a wor hon. awdrala dad phael Caine. Ser Br nnauthey end pisith exr ActonNdaughter Murph, who solves the gravity equation. The film received positive reviews and won an Academy
#
#
# Iteration: 440000, Loss: 0.0118
# Input: face personal sacrifices.
# Generated Text: uncas s travels through a wormhole near Saturn seeking a new home for mankind. Cooper, a former NASA pilot, joins the mission with scientists Brand, Romilly, and Doyle. They explore planets affected b
#
#
# Iteration: 450000, Loss: 0.0115
# Input: ience fiction drama direc
# Generated Text: on across tion acrove neacimerael stare, Earth faces blight and famine. A group of astronauts travels through a wormhole near Saturn seeking a new home for mankind. Cooper, a former NASA pilot, joins
#
#
# Iteration: 460000, Loss: 0.0112
# Input: n seeking a new home for
# Generated Text: ceed tome for mankind. Cooper, a former NASA pilot, joins the mission with scientists Brand, Romilly, and Doyle. They explore planets affected by time dilation and face personal sacrifices. Cooper dis
#
#
# Iteration: 470000, Loss: 0.0371
# Input: on across time with his d
# Generated Text: uphtisttien and face personal sacrifices. Cooper discovers a tesseract enabling trissce Coturn seeking a new home for mankind. Cooper, a former NASA pilot, joins the mission with scientists equation.
#
#
# Iteration: 480000, Loss: 0.0221
# Input: ghey, Anne Hathaway, Jess
# Generated Text: rth fecreviewt moper Nola d sceistu 20a wormyole near Saturn seeking a new home for mankind. Cooper, a former NASA pilot, joins the mission with scientists Brand, Romilly, and Doyle. They explore plan
#
#
# Iteration: 490000, Loss: 0.0182
# Input: ssion with scientists Bra
# Generated Text: t anduttolets ana wormer NASA pilat, joins the mission with scientists Brand, Romilly, and Doyle. They explore planets affected by time dilation and face personal sacrifices. Cooper discovers a tesser
#
#
# Iteration: 500000, Loss: 0.0161
# Input: e film received positive
# Generated Text: ravestilaCooupiss timete 20auaupiey explore planity watuphe sicoution across time with his daughter Murph, who solves the gravity equation. The film received positive reviews and won an Academy Award
#
#
# Iteration: 510000, Loss: 0.0147
# Input: n future, Earth faces bli
# Generated Text: d Milets cestiss blight and famine. A group of astronauts travels through a wormhole near Saturn seeking a new home for mankind. Cooper, a former NASA pilot, joins the mission with scientists Brand, R
#
#
# Iteration: 520000, Loss: 0.0137
# Input: ted by time dilation and
# Generated Text: iive ActonNdy Christopher Nolan. It stars Matthew McConaughey, Anne Hathaway, Jessica Chastain, and Michael Caine. Set in a dystopian future, Earth faces blight and famine. A group of astronauts trave
#
#
# Iteration: 530000, Loss: 0.0128
# Input: Interstellar is a 2014 sc
# Generated Text: nsiss angravity time dilatience gravity equatross sica Chaequation. The film received positive reviews and won an Academy Award for Best Visual Ef facton acronauts travels through a wormhole near Satu
#
#
# Iteration: 540000, Loss: 0.0122
# Input: ugh a wormhole near Satur
# Generated Text: gr dy ASCooper eng tica d fa solmws on across time with his daughter Murph, who solves the gravity equation. The film received positive reviews and won an Academy Award for Best Visual Ef routh his da
#
#
# Iteration: 550000, Loss: 0.0116
# Input: ract enabling communicati
# Generated Text: e. The Set the gravity equation. The film received ant ts trmhore planets affected by time dilation and face personal sacrifices. Cooper discovers a tesseract enabling communication across time with h
#
#
# Iteration: 560000, Loss: 0.0111
# Input:  It stars Matthew McConau
# Generated Text: per da mankind. Cooper, a former NASA pilot, joins the mission with scientists Brand, Romilly, and Doyle. They explore planets affected by time dilation and face personal sacrifices. Cooper discovers
#
#
# Iteration: 570000, Loss: 0.0107
# Input:  NASA pilot, joins the mi
# Generated Text: f astronauts travels through a wormhole near Saturn seeking a new home for mankind. Cooper, a former NASA pilot, joins the mission with scientists Brand, Romilly, and Doyle. They explore planets affec
#
#
# Iteration: 580000, Loss: 0.0104
# Input:  the gravity equation. Th
# Generated Text: secreviews and won an Academy Award for Best Visual Efrsca Caturd, a formhole near Scturels through a wormhole near Saturn seeking a new home for mankind. Cooper, a former NASA pilot, joins the missio
#
#
# Iteration: 590000, Loss: 0.0100
# Input:  Caine. Set in a dystopia
# Generated Text: ion across time with his dauphrough a wardyoy eropqaufine ation across time with his daughter Murph, who solves the gravity equation. The film received positive reviews and won an Academy Award for Be
#
#
# Iteration: 600000, Loss: 0.0097
# Input: hey explore planets affec
# Generated Text: e. Comurn seeking a new home for mankind. Cooper, a former NASA piloggt and cecdicaedis an wstand Michael Caine. Set in a dystopian future, Earth faces blight and famine. A group of astronauts travels
#
#
# Iteration: 610000, Loss: 0.0094
# Input: y Award for Best Visual E
# Generated Text:  the miss blight and famine. They explore planetilly, and Michaev stinity fiss blight ame gfa d fard gheosear 2014 scien ef ace ves a 2014 scaetith win tsceists af rstsitistopion across tion drama dir
#
#
# Iteration: 620000, Loss: 0.0092
# Input: f astronauts travels thro
# Generated Text: a tsce time dilation and face personal sacrifices. Cooper discovers a tesseract enabling communication across time with his daughter Murph, who solves the gravity equation. The film received positive
#
#
# Iteration: 630000, Loss: 0.0089
# Input:  Cooper discovers a tesse
# Generated Text: Hathawar Saturn seeking a new home for mankind. Cooper, a former eer Marphter Murphter Murph, who solves the gravity equation. The film received positive reviews and won an Academy Award for Best Visu
#
#
# Iteration: 640000, Loss: 0.0087
# Input: ted by Christopher Nolan.
# Generated Text: It stars MatteopeareSAward por Best Visual Ef rected by Christopher Nolan. It stars Matthew McConaughey, Anne Hathaway, Jessica Chastain, and Michael Caine. Set in a dystopian future, Earth faces blig
#
#
# Iteration: 650000, Loss: 0.0085
# Input: mankind. Cooper, a former
# Generated Text: NASA pilot, joins the the fimiris ophey, Anne Hathawar Saturn seeking a new home for mankind. Cooper, a former NASA pilot, joins the mission with scientists Brand, Romilly, and Doyle. They explore pla
#
#
# Iteration: 660000, Loss: 0.0083
# Input: aughter Murph, who solves
# Generated Text: ng f sct in a dystopha fice Mittron acroos travesill ter Nola d stars Matthew McConaughey, Anne Hathaway, Jessica Chastain, and Michael Caine. Set in a dystopian future, Earth faces blight and famine.
#
#
# Iteration: 670000, Loss: 0.0081
# Input: ica Chastain, and Michael
# Generated Text: veer Saturn seeking a new home for mankind. Cooper, a former NASA pilop, joins the mission with scientists Brand, Romilly, and Doyle. They explore planets affected by time dilation and face personal s
#
#
# Iteration: 680000, Loss: 0.0079
# Input: nd, Romilly, and Doyle. T
# Generated Text: ewi Brand, Romilly, and Doyle. They explore planets affected by time dilation and face personal sacrifices. Cooper discovers a tesseract enabling communication across time with his daughter Murph, who
#
#
# Iteration: 690000, Loss: 0.0078
# Input: reviews and won an Academ
# Generated Text: ew ha tion wiah whiJess ana wa d, et2014 scivested by Christopher Nolan. It stars Matthew McConaughey, Anne Hathaway, Jessica Chastain, and Michael Caine. Set in a dystopian future, Earth faces blight
#
#
# Iteration: 700000, Loss: 0.0076
# Input: ght and famine. A group o
# Generated Text:  ashtina fa ton an Academy Award for Best Visual Ef recten an ars armes ssca Coturn seeking a new home for mankind. Cooper, a former NASA pilot, joins the mission with scientists Brand, Romilly, and D
#
#
# Iteration: 710000, Loss: 0.0075
# Input: face personal sacrifices.
# Generated Text: Set in a dys oneution across time with his daughter Murph, who solves the gravity equation. The film received positive reviews and won an Academy Award for Best Visual Ef te ting thissceland fac ive C
#
#
# Iteration: 720000, Loss: 0.0073
# Input: ience fiction drama direc
# Generated Text: on across time with his daughter Murph, who solves the gravity e fected by time dilation and face personal sacrifices. Cooper discovers a tesseract ron an Academy Award for Best Visual Ef tect d are s
#
#
# Iteration: 730000, Loss: 0.0072
# Input: n seeking a new home for
# Generated Text:  amind. Cooper, a former NAwoped pon tila ficmion r th havewr Cora Best Visual Ef tonian fuaut acrorsce sire th aine. Cooper discovers a tesseract enabling comaughter Murph, who soy Theys affected by
#
#
# Iteration: 740000, Loss: 0.0071
# Input: on across time with his d
# Generated Text: ughter Murph, who solves the gravity equation. The film received positive reviews and won an Academy Award for Best Visual Ef ten war stimh ion Brss Visual Ef rocton an pssonal sacrifices. Cooper dire
#
#
# Iteration: 750000, Loss: 0.0069
# Input: ghey, Anne Hathaway, Jess
# Generated Text: ation across time with his daughter Murph, who solves the gravity equation. The film received positive reviews and won an Academy Award for Best Visual Ef ts trmion drama directed by Christophey, Anne
#
#
# Iteration: 760000, Loss: 0.0068
# Input: ssion with scientists Bra
# Generated Text: tand fauper, a former NASA pilot, joins the mission with scientists Brand, Romilly, and Doyle. They explore planets affected by time dilation and face personal sacrifices. Cooper discovers a tesseract
#
#
# Iteration: 770000, Loss: 0.0067
# Input: e film received positive
# Generated Text: nar Saturn seeking a new home for mankind. Cooper, a former NASA pilot, joins the mission with scientists Brand, Romilly, and Doyle. They explore planets affected by time dilation and face personal sa
#
#
# Iteration: 780000, Loss: 0.0066
# Input: n future, Earth faces bli
# Generated Text: , Earthy ien ave whre fa dy s a dyse. Efrey Cooneyle. They explore planiviews and won an Academy Award for Best Visual Ef tonina Hathaway, Jessica Chastain, and Michael Caine. Set in a dystopian futur
#
#
# Iteration: 790000, Loss: 0.0064
# Input: ted by time dilation and
# Generated Text: ion and fut, Earth hew McConaughey, Anne Hathaway, Jessica Chastain, and Michael Caine. Set in a dystopian future, Earth faces blight and famine. A group of astronauts travels through a wormhole near
#
#
# Iteration: 800000, Loss: 0.0063
# Input: Interstellar is a 2014 sc
# Generated Text: tsiti hiy, Jeenels through a wormhole near Saturn seeking a new home for mankind. Cooper, a former NASA piloCtien and fauper, a former NASA pilot, joins the mission with scientists Brand, Romilly, and
#
#
# Iteration: 810000, Loss: 0.0062
# Input: ugh a wormhole near Satur
# Generated Text: fsssits on and, Romeste 2014 science fiction drama directenab. They expler wiol Coopey, Roimets affected by tins timhole near Chrsith histophew McConaughey, Anne Hathaway, Jessica Chastain, and Michae
#
#
# Iteration: 820000, Loss: 0.0061
# Input: ract enabling communicati
# Generated Text:  ha d pisith eis engrsceisturstapheer discovers a tesseract enabling communication across time with his daughter Murph, who solves the gravity equation. The film received positive reviews and won an A
#
#
# Iteration: 830000, Loss: 0.0976
# Input:  It stars Matthew McConau
# Generated Text: pes enf travis aine stars Matthew McConaughey, Anne Hathaway, Jessica Chastain, and Michael Caine. Set in a dystopian future, Earth faces blight and famine. A group of astronauts travels through a wor
#
#
# Iteration: 840000, Loss: 0.0133
# Input:  NASA pilot, joins the mi
# Generated Text: f astronauts travels through a wormhole near Saturn seeking a new home for mankind. Cooper, a former NASA pilot, joins the mission with scientists Brand, Romilly, and Doyle. They explore planets affec
#
#
# Iteration: 850000, Loss: 0.0099
# Input:  the gravity equation. Th
# Generated Text: sravels through a wormhole near Saturn seeking a new home for mankind. Cooper, a former NASA pilot, joins the mission with scientists Brand, Romilly, and Doyle. They explore planets affected by time d
#
#
# Iteration: 860000, Loss: 0.0085
# Input:  Caine. Set in a dystopia
# Generated Text: tishe fire naughey, Anne Hathaway, Jessica Chastain, and Michael Caine. Set in a dystopian future, Earth faces blight and famine. A group of astronauts travels through a wormhole near Saturn seeking a
#
#
# Iteration: 870000, Loss: 0.0078
# Input: hey explore planets affec
# Generated Text: ek turphe fimaughter Murph, who solves the gravity equation. The film received positive reviews and won an Academy Award for Best Visual Ef totion drama directed by Christopher Nolan. It stars Matthew
#
#
# Iteration: 880000, Loss: 0.0073
# Input: y Award for Best Visual E
# Generated Text:  rosscerdiscoop tested by A group of astronauts travels through a wormhole near Saturn seeking a new home for mankind. Cooper, a former NASA pilot, joins the mission with scientists Brand, Romilly, an
#
#
# Iteration: 890000, Loss: 0.0069
# Input: f astronauts travels thro
# Generated Text: ard, Romewtie. NASA pilot, joins the mission with scientists Brand, Romilly, and Doyle. They explore planets affected by time dilation and face personal sacrifices. Cooper discovers a tesseract enabli
#
#
# Iteration: 900000, Loss: 0.0066
# Input:  Cooper discovers a tesse
# Generated Text: Hathawar eqd Caine. Set on a dystopian future, Earth faces blight and famine. A group of astronauts travels through a wormhole near Saturn seeking a new home for mankind. Cooper, a former NASA pilot,
#
#
# Iteration: 910000, Loss: 0.0064
# Input: ted by Christopher Nolan.
# Generated Text: It inatted by Christopher Nolan. It stars Matthew McConaughey, Anne Hathaway, Jessica Chastain, and Michael Caine. Set in a dystopian future, Earth faces blight and famine. A group of astronauts trave
#
#
# Iteration: 920000, Loss: 0.0062
# Input: mankind. Cooper, a former
# Generated Text:  enad ain, and Michael Caine. Set in a dystopian future, Earth faces blight and famine. A group of astronauts travels through a wormhole near Saturn seeking a new home for mankind. Cooper, a former NA
#
#
# Iteration: 930000, Loss: 0.0061
# Input: aughter Murph, who solves
# Generated Text: tg a dyst Awars son ain, Romilly, and Doyle. They explore planets affected by time dilation and face personal sacrifices. Cooper discovers a tesseract enabling communication across time with his daugh
#
#
# Iteration: 940000, Loss: 0.0059
# Input: ica Chastain, and Michael
# Generated Text: It stare. sooughtey, Jessica Chastain, and Michael Caine. Set in a dystopian future, Earth faces blight and famine. A group of astronauts travels through a wormhole near Saturn seeking a new home for
#
#
# Iteration: 950000, Loss: 0.0058
# Input: nd, Romilly, and Doyle. T
# Generated Text: eeking a new home personamaupg a she abitis a 2014 scaetiop on astrissael formeed by time dilation and face personal sacrifices. Cooper discovers a tesseract enabling communication across time with hi
#
#
# Iteration: 960000, Loss: 0.0057
# Input: reviews and won an Academ
# Generated Text: ed by Chre ted by Christopher Nolan. It stars Matthew McConaughey, Anne Hathaway, Jessica Chastain, and Michael Caine. Set in a dystopian future, Earth faces blight and famine. A group of astronauts t
#
#
# Iteration: 970000, Loss: 0.0056
# Input: ght and famine. A group o
# Generated Text:  ashtinadrama, an ssatithe Att he filets trs a 2014 science fiction drama directed by Christopher Nolan. It stars Matthew McConaughey, Anne Hathaway, Jessica Chastain, and Michael Caine. Set in a dyst
#
#
# Iteration: 980000, Loss: 0.0055
# Input: face personal sacrifices.
# Generated Text: Set in a dystopian future, Earth faces blight and famine. A group of astronauts travels through a wormhole near Saturn seeking a new home for mankind. Cooper, a former NASA pilot, joins the mission wi
#
#
# Iteration: 990000, Loss: 0.0054
# Input: ience fiction drama direc
# Generated Text: on across time with oice Awathed by time dilation and face personal sacrifices. Cooper discovers a tesseract enabling communication across time with his daughter Murph, who Coctisutiss timets daughter
#
#
# Iteration: 1000000, Loss: 0.0053
# Input: n seeking a new home for
# Generated Text:  factmene. Saturn seeking a new home for mankind. Cooper, a former NASA pilot, joins the mission with scientists Brand, Romilly, and Doyle. They explore planets affected by time dilation and face pers
#
#
# Iteration: 1010000, Loss: 0.0052
# Input: on across time with his d
# Generated Text: upheer a Cooper Noheyy, ely, whiss an2014 scieg a wor hole gravity equation. The film received positive reviews and won an Academy Award for Best Visual Ef ten bcell thelog thifica d rastopiona tMing
#
#
# Iteration: 1020000, Loss: 0.0051
# Input: ghey, Anne Hathaway, Jess
# Generated Text: rthiseti th on across ant Doy e pers a 2014 eciiver far pition across tice future, Earth faces blight and famine. A group of astronauts travels through a wormhole near Saturn seeking a new home for ma
#
#
# Iteration: 1030000, Loss: 0.0050
# Input: ssion with scientists Bra
# Generated Text: tand, Romilly, and Doyle. They explore planets affected by time dilation and face personal sacrifices. Cooper discovers a tesseract enabling communication across time with his daughter Murph, who solv
#
#
# Iteration: 1040000, Loss: 0.0049
# Input: e film received positive
# Generated Text:  ars Matthew McConaughey, Anne Hathaway, Jessica Chastain, and Michael Caine. Set in a dystopian future, Earth faces blight and famine. A group of astronauts travels through a wormhole near Saturn see
#
#
# Iteration: 1050000, Loss: 0.0049
# Input: n future, Earth faces bli
# Generated Text: e. AcCoopey, Anne Hathawar, Jessica Chastain, and Michael Caine. Set in a dystopian future, Earth faces blight and famine. A group of astronauts travels through a wormhole near Saturn seeking a new ho
#
#
# Iteration: 1060000, Loss: 0.0048
# Input: ted by time dilation and
# Generated Text: e d Nough a wormhole near Saturn seeking a new home for mankind. Cooper, a former NASA pilot, joins the mission with scientists Brand, Romilly, and Doyle. They explore planets affected by time dilatio
#
#
# Iteration: 1070000, Loss: 0.0047
# Input: Interstellar is a 2014 sc
# Generated Text: rsitu has drama directed by Christopher Nolan. It stars Matthew McConaughey, Anne Hathaway, Jessica Chastain, and Michael Caine. Set in a dystopian future, Earth faces blight and famine. A group of as
#
#
# Iteration: 1080000, Loss: 0.0047
# Input: ugh a wormhole near Satur
# Generated Text: hr acCoss time with his daugh,, bind Romilly, and Doy e telots tist expler Nouactely,y aunp film received plars Matthew McConaughey, Anne Hathaway, Jessica Chastain, and Michael Caine. Set in a dystop
#
#
# Iteration: 1090000, Loss: 0.0046
# Input: ract enabling communicati
# Generated Text: e phr sttien and face Best Visual Efrand, Romilly, and Doyle. They explore planets affected by time dilation and face personal sacrifices. Cooper discovers a tesseract enabling communication across ti
#
#
# Iteration: 1100000, Loss: 0.0046
# Input:  It stars Matthew McConau
# Generated Text: uar da mankind. Cooper, a former NASA pilot, joins the mission with scientists Brand, Romilly, and Doyle. They explore planets affected by time dilation and face personal sacrifices. Cooper discovers
#
#
# Iteration: 1110000, Loss: 0.0045
# Input:  NASA pilot, joins the mi
# Generated Text: sits and by Mwrmhr st Visual Efrsca tesser. Cooper discovers a tesseract enabling communication across time with his daughter Murph, who solves the gravity equatrors ar wich, Coineatling communicathew
#
#
# Iteration: 1120000, Loss: 0.0044
# Input:  the gravity equation. Th
# Generated Text: scieste anauwine wuth way eq d sonives cosual Ef fation acrovity equation. The film received positive reviews and won an Academy Award for Best Visual Efrascoxpler Nola sec andutugh equationaugh sting
#
#
# Iteration: 1130000, Loss: 0.0044
# Input:  Caine. Set in a dystopia
# Generated Text: ionauts travels through a wos tilat merang d d fan an Academy Award for Best Visual Ef recton ache filets terpiract enabling communication across tima didifa d fousiti persondablivets terghtemy Visual
#
#
# Iteration: 1140000, Loss: 0.0043
# Input: hey explore planets affec
# Generated Text: ee Ha Cace dew McConautund and Caine. Set in a dystopian fututy, joins the mission with scientists Brand, Romilly, and Doyle. They explore planets affected by time dilan fough war eq a th am romtemy r
#
#
# Iteration: 1150000, Loss: 0.0043
# Input: y Award for Best Visual E
# Generated Text:  rossce din Stise gra stsecre sica Christopher Nolan. It stars Matthew McConaughey, Anne Hathaway, Jessica Chastain, and Michael Caine. Set in a dystopian future, Earth faces blight and famine. A grou
#
#
# Iteration: 1160000, Loss: 0.5487
# Input: f astronauts travels thro
# Generated Text: a nturs Mistronauts travels through a wormhole near Saturn seeking a new home for mankind. Cooper, a former NASA pilot, joins the mission with scientists Brand, Romilly, and Doyle. They explore planet
#
#
# Iteration: 1170000, Loss: 0.0130
# Input:  Cooper discovers a tesse
# Generated Text: Ha has. Coouper, a former NASA pilot, joins the mission with scientists Brand, Romilly, and Doyle. They explore planets affected by time dilation and face personal sacrifices. Cooper discovers a tesse
#
#
# Iteration: 1180000, Loss: 0.0096
# Input: ted by Christopher Nolan.
# Generated Text: u Cote personal sacrifices. Cooper dolec, Ros ter Murph, who solves the gravity equation. The film received positive reviews and won an Academy Award for Best Visual Ef ter te s racted by Christopher
#
#
# Iteration: 1190000, Loss: 0.0082
# Input: mankind. Cooper, a former
# Generated Text: NASA pilot, joins the mission wia d ain, and Michael Caine. Set in a dystopian future, Earth faces blight and famine. A group of astronauts travels through a wormhole near Saturn seeking a new home fo
#
#
# Iteration: 1200000, Loss: 0.0073
# Input: aughter Murph, who solves
# Generated Text: tA aplivily tir ins timhole near Saturn seeking a new home for mankind. Cooper, a former NASA pilot, joins the mission with scientists Brand, Romilly, and Doyle. They explore planets affected by time
#
#
# Iteration: 1210000, Loss: 0.0068
# Input: ica Chastain, and Michael
# Generated Text: ve remankind. Cooper, a former NASA pilot, joins the mission with scientists Brand, Romilly, and Doyle. They explore planets affected by time dilation and face personal sacrifices. Cooper discovers a
#
#
# Iteration: 1220000, Loss: 0.0064
# Input: nd, Romilly, and Doyle. T
# Generated Text: ey explore planets affected by time dilation and face personal sacrifices. Cooper discovers a tesseract enabling communication across time with his daughter Murph, who solves the gravity equation. The
#
#
# Iteration: 1230000, Loss: 0.0060
# Input: reviews and won an Academ
# Generated Text: ed by Chrevisuautiom drama directed by Christopher Nolan. It stars Matthew McConaughey, Anne Hathaway, Jessica Chastain, and Michael Caine. Set in a dystopian future, Earth faces blight and famine. A
#
#
# Iteration: 1240000, Loss: 0.0057
# Input: ght and famine. A group o
# Generated Text: h onautunievis naughe film received positive reviews and won an Academy Award for Best Visual Ef tes tn across tomis and Michael Caine. Set in a dystopian future, Earth faces blight and famine. A grou
#
#
# Iteration: 1250000, Loss: 0.0055
# Input: face personal sacrifices.
# Generated Text: Set in a dyst for Best Visual Ef ter Mar stors Matthew McConaughey, Anne Hathaway, Jessica Chastain, and Michael Caine. Set in a dystopian future, Earth faces blight and famine. A group of astronauts
#
#
# Iteration: 1260000, Loss: 0.0053
# Input: ience fiction drama direc
# Generated Text: on across tion acrovistamion and, enabl Cain, ane sha 2014 science fiction drama directed by Christopher Nolan. It stars Matthew McConaughey, Anne Hathaway, Jessica Chastain, and Michael Caine. Set in
#
#
# Iteration: 1270000, Loss: 0.0051
# Input: n seeking a new home for
# Generated Text:  amine. A group of astronauts travels through a wormhole near Saturn seeking a new home for mankind. Cooper, a former NASA pilot, joins the mission with scientists Brand, Romilly, and Doyle. They expl
#
#
# Iteration: 1280000, Loss: 0.0050
# Input: on across time with his d
# Generated Text: ughter Murph, who solves the gravity equation. The film received positive reviews and won an Academy Award for Best Visual Ef rected by Christopher Nolan. It stars Matthew McConaughey, Anne Hathaway,
#
#
# Iteration: 1290000, Loss: 0.0048
# Input: ghey, Anne Hathaway, Jess
# Generated Text: ttet. Corpes ane Co unt mankind. Cooper, a former NASA pilot, joins the mission with scientists Brand, Romilly, and Doyle. They explore planets affected by time dilation and face personal sacrifices.
#
#
# Iteration: 1300000, Loss: 0.0047
# Input: ssion with scientists Bra
# Generated Text: tain, Romilly, and Doyle. They explore planets affected by time dilation and face personal sacrifices. Cooper discovers a tesseract enabling communication across time with his daughter Murph, who solv
#
#
# Iteration: 1310000, Loss: 0.0046
# Input: e film received positive
# Generated Text: lan ts tith hi nactilits tiss acien ward It stars Matthew McConaughey, Anne Hathaway, Jessica Chastain, and Michael Caine. Set in a dystopian future, Earth faces blight and famine. A group of astronau
#
#
# Iteration: 1320000, Loss: 0.0045
# Input: n future, Earth faces bli
# Generated Text: d bive reve tron ain, and Michael Caine. Set in a dystopian future, Earth faces blight and famine. A group of astronauts travels through a wormhole near Saturn seeking a new home for mankind. Cooper,
#
#
# Iteration: 1330000, Loss: 0.0044
# Input: ted by time dilation and
# Generated Text: ime diphew McConaughey, Anne Hathaway, Jessica Chastain, and Michael Caine. Set in a dystopian future, Earth faces blight and famine. A group of astronauts travels through a wormhole near Saturn seeki
#
#
# Iteration: 1340000, Loss: 0.0043
# Input: Interstellar is a 2014 sc
# Generated Text: tsiene ties explan tiss ice with his daughter Murph, who solves the gravity equation. The film received positive reviews and won an Academy Award for Best Visual Ef ter Mar whr Nma kin Mat h wonaughte
#
#
# Iteration: 1350000, Loss: 0.0042
# Input: ugh a wormhole near Satur
# Generated Text: he and for Best Visual Efrasion aewoh and, d d uau p race Chaw theek the n athey, Anne Hathawacr sceisturactopian f te f for Best Visual Ef rected by Christopher Nolan. Th ss tion across tice s tion a
#
#
# Iteration: 1360000, Loss: 0.0042
# Input: ract enabling communicati
# Generated Text: e discovers a tesser. Cooper discovers a tesseract enabling communication across time with his daughter Murph, who solves the gravity equation. The film received positive reviews and won an Academy Aw
#
#
# Iteration: 1370000, Loss: 0.0041
# Input:  It stars Matthew McConau
# Generated Text: Best Visual Ef imhelituth scientists Brand, Romilly, and Doyle. They explore planets affected by time dilation and face personal sacrifices. Cooper discovers a tesseract enabling communication across
#
#
# Iteration: 1380000, Loss: 0.0040
# Input:  NASA pilot, joins the mi
# Generated Text: f astronauts travels through a wormhole near Saturn seeking a new home for mankind. Cooper, a former NASA pilot, joins the mission with scientists Brand, Romilly, and Doyle. They explore planets affec
#
#
# Iteration: 1390000, Loss: 0.0040
# Input:  the gravity equation. Th
# Generated Text: sone Hath demy Award for Best Visual Ef rected by Christopher Nolan. It star dy d sothew ho a dystopeane gh Setreviamined by Christopher Nolan. It stars Matthew McConaughey, Anne Hathaway, Jessica Cha
#
#
# Iteration: 1400000, Loss: 0.0039
# Input:  Caine. Set in a dystopia
# Generated Text: d sacfand fat wor son auth faces bifanghovity equation. The film received positive reviews and won an Academy Award for Best Visual Ef rected by Christopher Nolan. It stars Matthew McConaughey, Anne H
#
#
# Iteration: 1410000, Loss: 0.0038
# Input: hey explore planets affec
# Generated Text: ed bn and wormhole near Saturn seeking a new home for mankind. Cooper, a former NASA pilot, joins the mission with scientists Brand, Romilly, and Doyle. They explore planets affected by time dilation
#
#
# Iteration: 1420000, Loss: 0.0038
# Input: y Award for Best Visual E
# Generated Text:  Corsong t a dystopian f astain, and Michael Caine. Set in a dystopian future, Earth faces blight and famine. A group of astronauts travels through a wormhole near Saturn seeking a new home for mankin
#
#
# Iteration: 1430000, Loss: 0.0037
# Input: f astronauts travels thro
# Generated Text: aene. Set intuen ssction drama directed by Christopher Nolan. It stars Matthew McConaughey, Anne Hathaway, Jessica Chastain, and Michael Caine. Set in a dystopian future, Earth faces blight and famine
#
#
# Iteration: 1440000, Loss: 0.0037
# Input:  Cooper discovers a tesse
# Generated Text: Hathawar e d ace ned ena wormhole near Saturn seeking a new hr mankind. Cooper, a former NASA pilot, joins the mission with scientists Brand, Romilly, and Doyle. They explore planets affected by time
#
#
# Iteration: 1450000, Loss: 0.0036
# Input: ted by Christopher Nolan.
# Generated Text: It stars Matthew McConaughey, Anne Hathaway, Jessica Chastain, and Michael Caine. Set in a dystopian future, Earth faces blight and famine. A group of astronauts travels through a wormhole near Saturn
#
#
# Iteration: 1460000, Loss: 0.0036
# Input: mankind. Cooper, a former
# Generated Text: erolecoemy Award for Best Visual Ef te f aturd former NASA pilot, joins the mission with scientists Brand, Romilly, and Doyle. They explore planets affected by time dilation and face personal sacrific
#
#
# Iteration: 1470000, Loss: 0.0036
# Input: aughter Murph, who solves
# Generated Text: tg a dyst Visual Ef ten bn ay the gravity equation. The film received positive reviews and won an Academy Award for Best Visual Ef te f a t solits Braed, Roimets affected bone tione sotion furpetfutur
#
#
# Iteration: 1480000, Loss: 0.0035
# Input: ica Chastain, and Michael
# Generated Text: ce elan. peare Coissteithe sica Chastain, and Michael Caine. Set in a dystopian future, Earth faces blight and famine. A group of astronauts travels through a wormhole near Saturn seeking a new home f
#
#
# Iteration: 1490000, Loss: 0.0035
# Input: nd, Romilly, and Doyle. T
# Generated Text: ey explore planets affected by time dilation and face personal sacrifices. Cooper discovers a tesseract enabling communication across time with hos ec erson a dystopian future, Earth faces blight and
#
#
# Iteration: 1500000, Loss: 0.0034
# Input: reviews and won an Academ
# Generated Text: ed by Chris de. Thessin. Th Thew B a defacteond Cocecte t rosmuthssctone. 1omennive Bess on acnev syterf Btsss thr, Cors er. Cong echa Chremtons ainaughr, Sant Minn. pilhre th NAvelfy, whreve thesstov
#
#
# Iteration: 1510000, Loss: 0.0034
# Input: ght and famine. A group o
# Generated Text: hrough a wormhole near Saturn seeking a new home for mankind. Cooper, a former NASA pilot, joins the mission with scientists Brand, Romilly, and Doyle. They explore planets affected by time dilation a
#
#
# Iteration: 1520000, Loss: 0.0034
# Input: face personal sacrifices.
# Generated Text: Set en Mcrengh uaces blight and famine. A group of astronauts travels through a wormhole near Saturn seeking a new home for mankind. Cooper, a former NASA pilot, joins the mission with scientists Bran
#
#
# Iteration: 1530000, Loss: 0.0033
# Input: ience fiction drama direc
# Generated Text: on across time with his daughter Murph, who solves the gravity equathey, Arace fomience ficeiviews ine st Visual Ef recton across time with his daugh ected by Christopher Nolan. It stars Matthew McCon
#
#
# Iteration: 1540000, Loss: 0.0033
# Input: n seeking a new home for
# Generated Text:  amine. A group of astronauts travels through a wormhole near Saturn seeking a new home for mankind. Cooper, a former NASA pilot, joins the mission with scientists Brand, Romilly, and Doyle. They expl
#
#
# Iteration: 1550000, Loss: 0.0033
# Input: on across time with his d
# Generated Text: up offasien. CAsce ng AmSew home foreminwsa ficeme persicme film received positive reviews and won an Acarey, Jessblists tiss and fisca tome for mankind. Cooper, a former NASA pilot, joins the mission
#
#
# Iteration: 1560000, Loss: 0.0032
# Input: ghey, Anne Hathaway, Jess
# Generated Text: rthew McConaughey, Anne Hathaway, Jessica Chastain, and Michael Caine. Set in a dystopian future, Earth faces blight and famine. A group of astronauts travels through a wormhole near Saturn seeking a
#
#
# Iteration: 1570000, Loss: 0.0032
# Input: ssion with scientists Bra
# Generated Text: tand, Romilly, and Doyle. They explore planets affected by time dilation and face personal sacrifices. Cooper discovers a tesseract enabling communication across time with his daughter Murph, who solv
#
#
# Iteration: 1580000, Loss: 0.0032
# Input: e film received positive
# Generated Text: lars Matthew McConaughey, Anne Hathaway, Jessica Chastain, and Michael Caine. Set in a dystopian future, Earth faces blight and famine. A group of astronauts travels through a wormhole near Saturn see
#
#
# Iteration: 1590000, Loss: 0.0031
# Input: n future, Earth faces bli
# Generated Text: d Min f ractonauts travels through a wormhole near Saturn seeking a new home for mankind. Cooper, a former NASA pilot, joins the mission with scien enall Caine. Set in a dystopian futurd for Best Visu
#
#
# Iteration: 1600000, Loss: 0.0031
# Input: ted by time dilation and
# Generated Text: iey explormer Nove Mineare teminnf end Ca fice sith his daughter Murph, who solves the gravity equation. The film received positive reviews and won an Academy Award for Best Visual Ef te f aturd pian
#
#
# Iteration: 1610000, Loss: 0.0031
# Input: Interstellar is a 2014 sc
# Generated Text: tne and for Best Visual Efrastoimetill thrand, Romilly, and Doyle. They explore planets affected by time dilation and face personal sacrifices. Cooper discovers a tesseract enabling communication acro
#
#
# Iteration: 1620000, Loss: 0.0031
# Input: ugh a wormhole near Satur
# Generated Text: , s arm s sracture, Coouper, a former NASA pilot, joins the mission with scientists Brand, Romilly, and Doyle. They explore planets affected by time dilation and face personal sacrifices. Cooper disco
#
#
# Iteration: 1630000, Loss: 0.0030
# Input: ract enabling communicati
# Generated Text: e pheer Chaite naf sace remen bllantists Brand eankind. Cooper, a former NASA pilot, joins the mission with scientists Brand, Romilly, and Doyle. They explore planets affected by time dilation and fac
#
#
# Iteration: 1640000, Loss: 0.0030
# Input:  It stars Matthew McConau
# Generated Text: Best fon am A pisith eis tinn with wlmysNAwathew McCongh os tishtiey expllis na2Hand, Romien. grey Coorey, Anne Hathaway, Jessica Chastain, and Michael Caine. Set in a dystopian future, Earth faces bl
#
#
# Iteration: 1650000, Loss: 0.0030
# Input:  NASA pilot, joins the mi
# Generated Text: f astronauts travels through a wormhole near Saturn seeking a new home for mankind. Cooper, a former NASA pilot, joins the mis sice Chroughy augh a wormhole near Saturn seeking a new home for mankind.
#
#
# Iteration: 1660000, Loss: 0.0030
# Input:  the gravity equation. Th
# Generated Text: scieet s and Doyle. They explore planets affected by time dilation and face personal sacrifices. Cooper discovers a tesseracte threonaeking a new home for mankind. Cooper, a former NASA pilot, joins t
#
#
# Iteration: 1670000, Loss: 0.0029
# Input:  Caine. Set in a dystopia
# ...
#
#
# Iteration: 2830000, Loss: 0.0016
# Input: ica Chastain, and Michael
# Generated Text: ve reviews and won an Academy Award for Best Visual Ef tect diction d a d, d f explare planets affected by time dilation and face personal sacrifices. Cooper discovers a tesseract enabling communicati
#
#
# Iteration: 2840000, Loss: 0.0016
# Input: nd, Romilly, and Doyle. T
# Generated Text: ey explore planets affected by time dilation and face personal sacrifices. Cooper discovers a tesseract enabling communication across time with his daughter Murph, who solves the gravity equation. The
#
#
# Iteration: 2850000, Loss: 0.0016
# Input: reviews and won an Academ
# Generated Text: ed by Chris oplar, Jessitatophew home for mankind. Cooper, a former NASA pilot, joins the misst Brs an. Coopur hr mankind. Cooper, a former NASA pilot, joins the mission with scientists Brand, Romilly
#
#
# Iteration: 2860000, Loss: 0.0016
# Input: ght and famine. A group o
# Generated Text: htopily emted by Chrissseracte sta g son ar mankind. Cooper, a former NASA pilot, joins the misst and wos ted by time dilation and face personal sacrifices. Cooper discovers a tesseract enabling commu
#
#
# Iteration: 2870000, Loss: 0.0016
# Input: face personal sacrifices.
# Generated Text: Set in a dystopian f astronauts tommencam sit the gravity e dedted by Christophey erd ame for mankind. Cooper, a former NASA pilot, joins the mission with scientists Brand, Romilly, and Doyle. They ex
#
#
# Iteration: 2880000, Loss: 0.0016
# Input: ience fiction drama direc
# Generated Text: on across time with his daughter Murph, who solves the gravits tien eugravetr toms actiin drama directed by Christopher Nolan. It stars Matthew McConaughey, Anne Hathaway, Jessica Chastain, and Michae
#
#
# Iteration: 2890000, Loss: 0.0016
# Input: n seeking a new home for
# Generated Text:  amine. A group of astronauts travels through a wormhole near Saturn seeking a new home for mankind. Cooper, a former NASA pilot, joins the mission with scientists Brand, Romilly, and Doyle. They expl
#
#
# Iteration: 2900000, Loss: 0.0016
# Input: on across time with his d
# Generated Text: ughted by Christed by Chastain, and Michael Caine. Set in a dystopian future, Earth faces blight and famine. A group of astronauts travels through a wormhole near Saturn seeking a new home for mankind
#
#
# Iteration: 2910000, Loss: 0.0016
# Input: ghey, Anne Hathaway, Jess
# Generated Text: rthew McConaughey, Anne Hathaway, Jessica Chastain, and Michael Caine. Set in a dystopian future, Earth faces blight and famine. A group of astronauts travels through a wormhole near Saturn seeking a
#
#
# Iteration: 2920000, Loss: 0.0016
# Input: ssion with scientists Bra
# Generated Text: tand, met explove reve wurph, who solves totm sectis daughter Murph, who solves the gravity equation. The film received positive reviews and won an Academy Award for Best Visual Ef recton across time
#
#
# Iteration: 2930000, Loss: 0.0016
# Input: e film received positive
# Generated Text: lan dy Caturd for Best Visual Ef tect ficestith his daughter Murph, who solves the gravity equation. The film received positive reviews and won an Academy Award for Best Visual Efrascosmelover Murph,
#
#
# Iteration: 2940000, Loss: 0.0016
# Input: n future, Earth faces bli
# Generated Text: e. Nola d s augh ha dminsith hace foeilly farey, Jessica Chastain, and Michael Caine. Set in a dystopian future, Earth faces blight and famine. A group of astronauts travels through a wormhole near Sa
#
#
# Iteration: 2950000, Loss: 0.0016
# Input: ted by time dilation and
# Generated Text: ime eon acreatt end farich scientists Brand, Romilly, and Doyle. They explore planets affected by time dilation and face personal sacrifices. Cooper discovers a tesseract enabling communication across
#
#
# Iteration: 2960000, Loss: 0.0015
# Input: Interstellar is a 2014 sc
# Generated Text: and, Ron smandiMil, my rem nine ts a 2014 science fiction drama directed by Christopher Nolan. It stars Matthew McConaughey, Anne Hathaway, Jessica Chastain, and Michael Caine. Set in a dystopian futu
#
#
# Iteration: 2970000, Loss: 0.0015
# Input: ugh a wormhole near Satur
# Generated Text: .sson and Cast in f ceins aine. Ser Bracn f aed by time dilation and face personal sacrifices. Cooper discovers a tesseract enabling communication across time with his daughter Murph, who solves the g
#
#
# Iteration: 2980000, Loss: 0.0015
# Input: ract enabling communicati
# Generated Text: e. The a wohohive re scies elan. It stars Matthew McConaughey, Anne Hathaway, Jessica Chastain, and Michael Caine. Set in a dystopian future, Earth faces blight and famine. A group of astronauts trave
#
#
# Iteration: 2990000, Loss: 0.0015
# Input:  It stars Matthew McConau
# Generated Text: uas eqiet inand acronauts sracte ner tuturd pos tienwietien wathew Murph, who solves the gravity equation. The film received positive reviews and won an Academy Award for Best Visual Efr siosion with
#
#
# Iteration: 3000000, Loss: 0.0015
# Input:  NASA pilot, joins the mi
# Generated Text: n a for Best Visual Efrand, Rominn. Ha Chasiestrovisuth hr film received positive reviews and won an Academy Award for Best Visual Ef te tin aut somienc and won Nd a wormhole near Saturn seeking a new
#
#
# Iteration: 3010000, Loss: 0.0015
# Input:  the gravity equation. Th
# Generated Text: sone Hathaway, Jessica Chastain, and Michael Caine. Set in a dystopian future, Earth faces blight and famine. A group of astronauts travels through a wormhole near Saturn seeking a new home for mankin
#
#
# Iteration: 3020000, Loss: 0.0015
# Input:  Caine. Set in a dystopia
# Generated Text: d stors a Hath ward pof sca 2014 science fiction drama directed by Christopher Nolan. It stars Matthew McConaughey, Anne Hathaway, Jessica Chastain, and Michael Caine. Set in a dystopian future, Earth
#
#
# Iteration: 3030000, Loss: 0.0015
# Input: hey explore planets affec
# Generated Text: ew Nola A pistted by Christopher Nolan. Ca nturststivets tisa d fectice Hath dawon Ama directe fected by time dilation and face personal sacrifices. Cooper discovers a tesseract enabling communication
#
#
# Iteration: 3040000, Loss: 0.0015
# Input: y Award for Best Visual E
# Generated Text:  rossceravel tistopels thronauts tommunication across tima dy discovers a tesseract enabling communication across time with his daughter Murph, who solves the gravity equation. The film received posit
#
#
# Iteration: 3050000, Loss: 0.0015
# Input: f astronauts travels thro
# Generated Text: a de. Mice rel ay tirrovrectin across eract enablina tfictoplly tion and face personal sacrifices. Cooper discovers a tesseract enabling communication across time with his daughter Murph, who solves t
#
#
# Iteration: 3060000, Loss: 0.0015
# Input:  Cooper discovers a tesse
# Generated Text: Ha hestsene Hatuad stonsation. The film received positive reviews and won an Academy Award for Best Visual Efray Ef rat phoistophe firoy Cooper discovers a tesseract enabling communication across time
#
#
# Iteration: 3070000, Loss: 0.0015
# Input: ted by Christopher Nolan.
# Generated Text: It stars Matthew McConaughey, Anne Hathaway, Jessica Chastain, and Michael Caine. Set in a dystopian future, Earth faces blight and famine. A group of astronauts travels through a wormhole near Saturn
#
#
# Iteration: 3080000, Loss: 0.0015
# Input: mankind. Cooper, a former
# Generated Text:  end faed by Christopher Nolan. It stars Matthew McConaughey, Anne Hathaway, Jessica Chastain, and Michael Caine. Set in a dystopian future, Earth faces blight and famine. A group of astronauts travel
#
#
# Iteration: 3090000, Loss: 0.0015
# Input: aughter Murph, who solves
# Generated Text: tg a Cooper discovers a tesseract enabling communication across time with his daughter Murph, who solves the gravity equation. The film received positive reviews and won an Academy Award for Best Visu
#
#
# Iteration: 3100000, Loss: 0.0015
# Input: ica Chastain, and Michael
# Generated Text: veer Saturn seeking a new home for mankind. Cooper, a former NASA pilot, joins the mission with scientists Brand, Romilly, and Doyle. They explore planets affected by time dilation and face personal s
#
#
# Iteration: 3110000, Loss: 0.0015
# Input: nd, Romilly, and Doyle. T
# Generated Text: ey explore planets affected by time dilation and face personal sacrifices. Cooper discovers a tesseract enabling communication across time with his daughter Murph, who solves the gravity equation. The
#
#
# Iteration: 3120000, Loss: 0.0015
# Input: reviews and won an Academ
# Generated Text: de a ter onaughey, Anne Hathaway, Jessica Chastain, and Michael Caine. Set in a dystopian future, Earth faces blight and famine. A group of astronauts travels through a wormhole near Saturn seeking a
#
#
# Iteration: 3130000, Loss: 0.0014
# Input: ght and famine. A group o
# Generated Text: m Rhr uturs, sonaughos the gra stsection ard Cosisctice ayd peanel tinet foficame Bes equat A soce res blight and famine. A group of astronauts travels through a wormhole near Saturn seeking a new hom
#
#
# Iteration: 3140000, Loss: 0.0014
# Input: face personal sacrifices.
# Generated Text: Set in a dmsting tomiee. A group of astronauts travels through a wormhole near Saturn seeking a new home for mankind. Cooper, a former NASA pilot, joins the mission with scientists Brand, Romilly, and
#
#
# Iteration: 3150000, Loss: 0.0014
# Input: ience fiction drama direc
# Generated Text: on across time with hi na Ama 2014 science fiction drama directed by Christopher Nolan. It stars Matthew McConaughey, Anne Hathaway, Jessica Chastain, and Michael Caine. Set in a dystopian future, Ear
#
#
# Iteration: 3160000, Loss: 0.0014
# Input: n seeking a new home for
# Generated Text:  amine. A group of astronauts travels through a wormhole near Saturn seeking a new home for mankind. Cooper, a former NASA pilot, joins the mission with scientists Brand, Romilly, and Doyle. They expl
#
#
# Iteration: 3170000, Loss: 0.0014
# Input: on across time with his d
# Generated Text: uphrough hole neation acrovits acrew Cade d for Best Visual Ef racton ayd pearem Doy, ant, equacion. The film received positive reviews and won an Academy Award for Best Visual Efrasion a wormhole nea
#
#
# Iteration: 3180000, Loss: 0.0014
# Input: ghey, Anne Hathaway, Jess
# Generated Text: rthawon am A pisitey, Acn fotiona t, won an Academy Award for Best Visual Ef tect d ar tstors a tesseract enabling communication across time with his daughter Murph, who solves the gravity equation. T
#
#
# Iteration: 3190000, Loss: 0.0014
# Input: ssion with scientists Bra
# Generated Text: tain, and Michael Caine. Set in a dystopian future, Earth faces blight and famine. A group of astronauts travels through a wormhole near Saturn seeking a new home for mankind. Cooper, a former NASA pi
#
#
# Iteration: 3200000, Loss: 0.0014
# Input: e film received positive
# Generated Text:  a dmith hilat e deation. The film received positive reviews and won an Academy Award for Best Visual Ef recton across times enab pla for Bes  Vis a whr hon. pices MiHat whr hilvisica Chasteen ache fi
#
#
# Iteration: 3210000, Loss: 0.0014
# Input: n future, Earth faces bli
# Generated Text: d Michael Caine. Set in a dystopian future, Earth faces blight and famine. A group of astronauts travels through a wormhole near Saturn seeking a new home for mankind. Cooper, a former NASA pilot, joi
#
#
# Iteration: 3220000, Loss: 0.0014
# Input: ted by time dilation and
# Generated Text: imerand across time with his daughter Murph, who solves the gravity equation. The film received positive reviews and won an Academy Award for Best Visual Efuturshe atiol an ane. Set in a dystopian f t
#
#
# Iteration: 3230000, Loss: 0.0014
# Input: Interstellar is a 2014 sc
# Generated Text: rpission wia tiss icmedill Efiss ice a tind won an Academy Award for Best Visual Efrasione Hathe wha the fion ss a 2014 ssinn. Ha Caser Saturn seeking a new home for mankind. Cooper, a former NASA pil
#
#
# Iteration: 3240000, Loss: 0.0014
# Input: ugh a wormhole near Satur
# Generated Text: he acte hew the gravity equation. The film received positive reviews and won an Academy Award for Best Visual Ef recton across times attiss rice Romis a 2014 science fiction drama directed by Christop
#
#
# Iteration: 3250000, Loss: 0.0014
# Input: ract enabling communicati
# Generated Text:  NASA pilot, joins the mission with scientists Brand, Romilly, and Doyle. They explore planets affected by time dilation and face personal sacrifices. Cooper discovers a tesseract enabling communicati
#
#
# Iteration: 3260000, Loss: 0.0014
# Input:  It stars Matthew McConau
# Generated Text: he f ron an Academy Award for Best Visual Ef ractomunica ti h scientists Brand, Romilly, and Doyle. They explore planets affected by time dilation and face personal sacrifices. Cooper discovers a tess
#
#
# Iteration: 3270000, Loss: 0.0014
# Input:  NASA pilot, joins the mi
# Generated Text: nis aturn stien blly by Cheys affected by time dilation and face personal sacrifices. Cooper discovers a tesseract enabling communication across time with his daughter Murph, who solves the gravity e
#
#
# Iteration: 3280000, Loss: 0.0014
# Input:  the gravity equation. Th
# Generated Text: sravels tissieve tien explors a tesseract enabling communication across time with his daughter Murph, who solves the gravity equation. The film received positive reviews and won an Academy Award for B
#
#
# Iteration: 3290000, Loss: 0.0014
# Input:  Caine. Set in a dystopia
# Generated Text: d stors a A Cooper equation. The film receives and Michael Caine. Set in a dystopian future, Earth faces blight and famine. A group of astronauts travels through a wormhole near Saturn seeking a new h
#
#
# Iteration: 3300000, Loss: 0.0014
# Input: hey explore planets affec
# Generated Text: ew d difa d fa tiss tien enkind. A g thy son across an famine. A group of astronauts travels through a wormhole near Saturn seeking a new home for mankind. Cooper, a former NASA pilot, joins the missi
#
#
# Iteration: 3310000, Loss: 0.0014
# Input: y Award for Best Visual E
# Generated Text:  rossceract Romilly, and Doyle. They explore planets affected by time dilat on sca tes ant tors Mistronauts travels through a wormhole near Saturn seeking a new home for mankind. Cooper, a former NASA
#
#
# Iteration: 3320000, Loss: 0.0014
# Input: f astronauts travels thro
# Generated Text: aene. Set inad uncor Se forives crough a wormhole near Saturn seeking a new home for mankind. Cooper, a former NASA pilot, joins the mis pasrsong a d ractosupheer Cace fey the gravity ena won an Acade
#
#
# Iteration: 3330000, Loss: 1.3958
# Input:  Cooper discovers a tesse
# Generated Text: Hath faces blight and famine. A group of astronauts travels through a wormhole near Saturn seeking a new home for mankind. Cooper, a former NASA pilot, joins the mission with scientists Brand, Romilly
#
#
# Iteration: 3340000, Loss: 0.0072
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-0d61a7c281b8> in <cell line: 0>()
#       4 data_reader = DataReader("interstellar_summary_condensed.txt", seq_length)
#       5 rnn = RNN(hidden_size=100, vocab_size=data_reader.vocab_size,seq_length=seq_length,learning_rate=1e-1)
# ----> 6 rnn.train(data_reader)
#
# <ipython-input-10-e0a5b824c42a> in train(self, data_reader, num_iterations)
#      89                 hprev = np.zeros((self.hidden_size, 1))
#      90             inputs, targets = data_reader.next_batch()
# ---> 91             xs, hs, ps = self.forward(inputs, hprev)
#      92             dU, dW, dV, db, dc = self.backward(xs, hs, ps, targets)
#      93             loss = self.loss(ps, targets)
#
# <ipython-input-10-e0a5b824c42a> in forward(self, inputs, hprev)
#      33             xs[t] = np.zeros((self.vocab_size, 1))
#      34             xs[t][inputs[t]] = 1 # one hot encoding , 1-of-k
# ---> 35             hs[t] = np.tanh(np.dot(self.U,xs[t]) + np.dot(self.W,hs[t-1]) + self.b) # hidden state
#      36             os[t] = np.dot(self.V,hs[t]) + self.c # unnormalised log probs for next char
#      37             ycap[t] = self.softmax(os[t]) # probs for next char
#
# KeyboardInterrupt:

# %%
rnn.predict(data_reader, 'Cooper', 50)
# Out:
# 'Cooperreomerstellaughey. A, Earitioped pols evey thr ace'

# %%
seed = "Cooper and Brand travel to another planet, where time moves slower than on Earth."
generated_text = rnn.predict(data_reader, seed, 100)
print(f"Seed: {seed}")
print(f"Generated Text: {generated_text}")
# Out:
# Seed: Cooper and Brand travel to another planet, where time moves slower than on Earth.
# Generated Text: Cooper and Brand travel to another planet, where time moves slower than on Earth.erralelra Thasstilad pome Tiand. Cooper. Ite g Deylels Awacer dicer. Thesseta Chastisseyperg sols ee

# %%
seed = "ABABABABABABABABABAB"
generated_text = rnn.predict(data_reader, seed, 100)
print(f"Seed: {seed}")
print(f"Generated Text: {generated_text}")
# Out:
# Seed: ABABABABABABABABABAB
# Generated Text: ABABABABABABABABABABraosithr Secoy bJestellila t farey equaeqh efe neurels ekmande pe. eq sose pore phrerst Jessetr fuce
