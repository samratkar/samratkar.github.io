# %% [markdown]
# <a href="https://colab.research.google.com/github/samratkar/samratkar.github.io/blob/main/_posts/concepts/genai/notes-codes/attention/Live_LLMScratch_Final_(2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # BUILD A LARGE LANGUAGE MODEL FROM SCRATCH

# %% [markdown]
# ### STEP 1: LOADING THE DATASET

# %%
# !git clone https://github.com/samratkar/samratkar.github.io.git
file_path = "/content/samratkar.github.io/assets/genai/attention/data/julius-caesar.txt"
# Out:
# Cloning into 'samratkar.github.io'...
# remote: Enumerating objects: 104935, done.
# remote: Counting objects: 100% (348/348), done.
# remote: Compressing objects: 100% (239/239), done.
# remote: Total 104935 (delta 211), reused 203 (delta 99), pack-reused 104587 (from 3)
# Receiving objects: 100% (104935/104935), 779.79 MiB | 17.16 MiB/s, done.
# Resolving deltas: 100% (2644/2644), done.
# Updating files: 100% (100736/100736), done.

# %%
import os

# Check if the file exists in the current directory (i.e., Colab session)
if os.path.exists(file_path):
    with open(file_path, "r", encoding="utf-8") as file:
        text_data = file.read()
    print(f"File '{file_path}' loaded with {len(text_data)} characters.")
else:
    print(f"File '{file_path}' not found. Please upload it to the Colab environment first.")
# Out:
# File '/content/samratkar.github.io/assets/genai/attention/data/julius-caesar.txt' loaded with 135828 characters.

# %% [markdown]
# ### STEP 2: IMPLEMENTING THE TOKENIZER

# %%
# !pip3 install tiktoken > /dev/null 2>&1

# %%
import importlib
import tiktoken

print("tiktoken version:", importlib.metadata.version("tiktoken"))
# Out:
# tiktoken version: 0.9.0

# %%
tokenizer = tiktoken.get_encoding("gpt2")

# %%
text = (
    "Hello, do you like tea? <|endoftext|> In the sunlit terraces"
     "of someunknownPlace."
)

integers = tokenizer.encode(text, allowed_special={"<|endoftext|>"})

print(integers)
# Out:
# [15496, 11, 466, 345, 588, 8887, 30, 220, 50256, 554, 262, 4252, 18250, 8812, 2114, 1659, 617, 34680, 27271, 13]

# %%
integers = tokenizer.encode("Akwirw ier")
print(integers)

strings = tokenizer.decode(integers)
print(strings)
# Out:
# [33901, 86, 343, 86, 220, 959]
# Akwirw ier

# %%
total_characters = len(text_data)
total_tokens = len(tokenizer.encode(text_data))

print("Characters:", total_characters)
print("Tokens:", total_tokens)
# Out:
# Characters: 135828
# Tokens: 42345

# %% [markdown]
# ### STEP 3: CREATING INPUT-TARGET PAIRS

# %%
with open(file_path, "r", encoding="utf-8") as f:
    raw_text = f.read()

enc_text = tokenizer.encode(raw_text)
print(len(enc_text))
# Out:
# 42345

# %%
from torch.utils.data import Dataset, DataLoader


class GPTDatasetV1(Dataset):
    def __init__(self, txt, tokenizer, max_length, stride):
        self.input_ids = []
        self.target_ids = []

        # Tokenize the entire text
        token_ids = tokenizer.encode(txt, allowed_special={"<|endoftext|>"})

        # Use a sliding window to chunk the book into overlapping sequences of max_length
        for i in range(0, len(token_ids) - max_length, stride):
            input_chunk = token_ids[i:i + max_length]
            target_chunk = token_ids[i + 1: i + max_length + 1]
            self.input_ids.append(torch.tensor(input_chunk))
            self.target_ids.append(torch.tensor(target_chunk))

    def __len__(self):
        return len(self.input_ids)

    def __getitem__(self, idx):
        return self.input_ids[idx], self.target_ids[idx]

# %%
def create_dataloader_v1(txt, batch_size=4, max_length=256,
                         stride=128, shuffle=True, drop_last=True,
                         num_workers=0):

    # Initialize the tokenizer
    tokenizer = tiktoken.get_encoding("gpt2")

    # Create dataset
    dataset = GPTDatasetV1(txt, tokenizer, max_length, stride)

    # Create dataloader
    dataloader = DataLoader(
        dataset,
        batch_size=batch_size,
        shuffle=shuffle,
        drop_last=drop_last,
        num_workers=num_workers
    )

    return dataloader

# %%
import torch
print("PyTorch version:", torch.__version__)
dataloader = create_dataloader_v1(
    raw_text, batch_size=1, max_length=4, stride=1, shuffle=False
)

data_iter = iter(dataloader)
first_batch = next(data_iter)
print(first_batch)
# Out:
# PyTorch version: 2.6.0+cu124
# [tensor([[171, 119, 123, 464]]), tensor([[ 119,  123,  464, 4935]])]

# %% [markdown]
# ### STEP 4: CREATING TOKEN EMBEDDINGS

# %%
vocab_size = 50257
output_dim = 256

token_embedding_layer = torch.nn.Embedding(vocab_size, output_dim)

# %%
max_length = 4
dataloader = create_dataloader_v1(
    raw_text, batch_size=8, max_length=max_length,
    stride=max_length, shuffle=False
)
data_iter = iter(dataloader)
inputs, targets = next(data_iter)

# %%
print("Token IDs:\n", inputs)
print("\nInputs shape:\n", inputs.shape)
# Out:
# Token IDs:
#  tensor([[  171,   119,   123,   464],
#         [ 4935, 20336, 46566,   286],
#         [32834, 24088,   198,   220],
#         [  220,   220,   220,   198],
#         [ 1212, 47179,   318,   329],
#         [  262,   779,   286,  2687],
#         [ 6609,   287,   262,  1578],
#         [ 1829,   290,   198,  1712]])
#
# Inputs shape:
#  torch.Size([8, 4])

# %%
token_embeddings = token_embedding_layer(inputs)
print(token_embeddings.shape)
# Out:
# torch.Size([8, 4, 256])

# %% [markdown]
# ### STEP 5: CREATING POSITIONAL EMBEDDINGS

# %%
context_length = max_length
pos_embedding_layer = torch.nn.Embedding(context_length, output_dim)

# %%
pos_embeddings = pos_embedding_layer(torch.arange(max_length))
print(pos_embeddings.shape)
# Out:
# torch.Size([4, 256])

# %% [markdown]
# ### STEP 6: CREATING INPUT EMBEDDINGS

# %%
input_embeddings = token_embeddings + pos_embeddings
print(input_embeddings.shape)
# Out:
# torch.Size([8, 4, 256])

# %% [markdown]
# ### STEP 7: IMPLEMENTING MULTI-HEAD ATTENTION

# %%
import torch.nn as nn

class MultiHeadAttention(nn.Module):
    def __init__(self, d_in, d_out, context_length, dropout, num_heads, qkv_bias=False):
        super().__init__()
        assert (d_out % num_heads == 0), \
            "d_out must be divisible by num_heads"

        self.d_out = d_out
        self.num_heads = num_heads
        self.head_dim = d_out // num_heads # Reduce the projection dim to match desired output dim

        self.W_query = nn.Linear(d_in, d_out, bias=qkv_bias)
        self.W_key = nn.Linear(d_in, d_out, bias=qkv_bias)
        self.W_value = nn.Linear(d_in, d_out, bias=qkv_bias)
        self.out_proj = nn.Linear(d_out, d_out)  # Linear layer to combine head outputs
        self.dropout = nn.Dropout(dropout)
        self.register_buffer(
            "mask",
            torch.triu(torch.ones(context_length, context_length),
                       diagonal=1)
        )

    def forward(self, x):
        b, num_tokens, d_in = x.shape

        keys = self.W_key(x) # Shape: (b, num_tokens, d_out)
        queries = self.W_query(x)
        values = self.W_value(x)

        # We implicitly split the matrix by adding a `num_heads` dimension
        # Unroll last dim: (b, num_tokens, d_out) -> (b, num_tokens, num_heads, head_dim)
        keys = keys.view(b, num_tokens, self.num_heads, self.head_dim)
        values = values.view(b, num_tokens, self.num_heads, self.head_dim)
        queries = queries.view(b, num_tokens, self.num_heads, self.head_dim)

        # Transpose: (b, num_tokens, num_heads, head_dim) -> (b, num_heads, num_tokens, head_dim)
        keys = keys.transpose(1, 2)
        queries = queries.transpose(1, 2)
        values = values.transpose(1, 2)

        # Compute scaled dot-product attention (aka self-attention) with a causal mask
        attn_scores = queries @ keys.transpose(2, 3)  # Dot product for each head

        # Original mask truncated to the number of tokens and converted to boolean
        mask_bool = self.mask.bool()[:num_tokens, :num_tokens]

        # Use the mask to fill attention scores
        attn_scores.masked_fill_(mask_bool, -torch.inf)

        attn_weights = torch.softmax(attn_scores / keys.shape[-1]**0.5, dim=-1)
        attn_weights = self.dropout(attn_weights)

        # Shape: (b, num_tokens, num_heads, head_dim)
        context_vec = (attn_weights @ values).transpose(1, 2)

        # Combine heads, where self.d_out = self.num_heads * self.head_dim
        context_vec = context_vec.contiguous().view(b, num_tokens, self.d_out)
        context_vec = self.out_proj(context_vec) # optional projection

        return context_vec

# %%
torch.manual_seed(123)

# Define the tensor with 3 rows and 6 columns
inputs = torch.tensor(
    [[0.43, 0.15, 0.89, 0.55, 0.87, 0.66],  # Row 1
     [0.57, 0.85, 0.64, 0.22, 0.58, 0.33],  # Row 2
     [0.77, 0.25, 0.10, 0.05, 0.80, 0.55]]  # Row 3
)

batch = torch.stack((inputs, inputs), dim=0)
print(batch.shape)

batch_size, context_length, d_in = batch.shape
d_out = 6
mha = MultiHeadAttention(d_in, d_out, context_length, 0.0, num_heads=2)
context_vecs = mha(batch)
print(context_vecs)
print("context_vecs.shape:", context_vecs.shape)
# Out:
# torch.Size([2, 3, 6])
# tensor([[[ 0.1569, -0.0873,  0.0210,  0.0215, -0.3243, -0.2518],
#          [ 0.1117, -0.0547,  0.0406, -0.0213, -0.3251, -0.2993],
#          [ 0.1196, -0.0491,  0.0318, -0.0635, -0.2788, -0.2578]],
#
#         [[ 0.1569, -0.0873,  0.0210,  0.0215, -0.3243, -0.2518],
#          [ 0.1117, -0.0547,  0.0406, -0.0213, -0.3251, -0.2993],
#          [ 0.1196, -0.0491,  0.0318, -0.0635, -0.2788, -0.2578]]],
#        grad_fn=<ViewBackward0>)
# context_vecs.shape: torch.Size([2, 3, 6])

# %% [markdown]
# ### STEP 8: IMPLEMENTING A GPT MODEL FROM SCRATCH TO GENERATE TEXT

# %%
GPT_CONFIG_124M = {
    "vocab_size": 50257,    # Vocabulary size
    "context_length": 256, # Context length
    "emb_dim": 768,         # Embedding dimension
    "n_heads": 12,          # Number of attention heads
    "n_layers": 12,         # Number of layers
    "drop_rate": 0.1,       # Dropout rate
    "qkv_bias": False       # Query-Key-Value bias
}

# %% [markdown]
# ### STEP 9: THE BUILDING BLOCKS-LAYER NORMALIZATION, GELU AND FEED-FORWARD NEURAL NETWORK

# %%
class LayerNorm(nn.Module):
    def __init__(self, emb_dim):
        super().__init__()
        self.eps = 1e-5
        self.scale = nn.Parameter(torch.ones(emb_dim))
        self.shift = nn.Parameter(torch.zeros(emb_dim))

    def forward(self, x):
        mean = x.mean(dim=-1, keepdim=True)
        var = x.var(dim=-1, keepdim=True, unbiased=False)
        norm_x = (x - mean) / torch.sqrt(var + self.eps)
        return self.scale * norm_x + self.shift

class GELU(nn.Module):
    def __init__(self):
        super().__init__()

    def forward(self, x):
        return 0.5 * x * (1 + torch.tanh(
            torch.sqrt(torch.tensor(2.0 / torch.pi)) *
            (x + 0.044715 * torch.pow(x, 3))
        ))


class FeedForward(nn.Module):
    def __init__(self, cfg):
        super().__init__()
        self.layers = nn.Sequential(
            nn.Linear(cfg["emb_dim"], 4 * cfg["emb_dim"]), ## Expansion
            GELU(), ## Activation
            nn.Linear(4 * cfg["emb_dim"], cfg["emb_dim"]), ## Contraction
        )

    def forward(self, x):
        return self.layers(x)

# %%
class TransformerBlock(nn.Module):
    def __init__(self, cfg):
        super().__init__()
        self.att = MultiHeadAttention(
            d_in=cfg["emb_dim"],
            d_out=cfg["emb_dim"],
            context_length=cfg["context_length"],
            num_heads=cfg["n_heads"],
            dropout=cfg["drop_rate"],
            qkv_bias=cfg["qkv_bias"])
        self.ff = FeedForward(cfg)
        self.norm1 = LayerNorm(cfg["emb_dim"])
        self.norm2 = LayerNorm(cfg["emb_dim"])
        self.drop_shortcut = nn.Dropout(cfg["drop_rate"])

    def forward(self, x):
        # Shortcut connection for attention block
        shortcut = x
        x = self.norm1(x)
        x = self.att(x)  # Shape [batch_size, num_tokens, emb_size]
        x = self.drop_shortcut(x)
        x = x + shortcut  # Add the original input back

        # Shortcut connection for feed forward block
        shortcut = x
        x = self.norm2(x)
        x = self.ff(x)
        # 2*4*768
        x = self.drop_shortcut(x)
        x = x + shortcut  # Add the original input back

        return x
        # 2*4*768

# %% [markdown]
# ### STEP 10: ENTIRE GPT MODEL ARCHITECTURE IMPLEMENTATION

# %%
class GPTModel(nn.Module):
    def __init__(self, cfg):
        super().__init__()
        self.tok_emb = nn.Embedding(cfg["vocab_size"], cfg["emb_dim"])
        self.pos_emb = nn.Embedding(cfg["context_length"], cfg["emb_dim"])
        self.drop_emb = nn.Dropout(cfg["drop_rate"])

        self.trf_blocks = nn.Sequential(
            *[TransformerBlock(cfg) for _ in range(cfg["n_layers"])])

        self.final_norm = LayerNorm(cfg["emb_dim"])
        self.out_head = nn.Linear(
            cfg["emb_dim"], cfg["vocab_size"], bias=False
        )

    def forward(self, in_idx):
        batch_size, seq_len = in_idx.shape
        tok_embeds = self.tok_emb(in_idx)
        pos_embeds = self.pos_emb(torch.arange(seq_len, device=in_idx.device))
        x = tok_embeds + pos_embeds  # Shape [batch_size, num_tokens, emb_size]
        x = self.drop_emb(x)
        x = self.trf_blocks(x)
        x = self.final_norm(x)
        logits = self.out_head(x)
        return logits

# %%
torch.manual_seed(123)

batch = []
txt1 = "Every effort moves you"
txt2 = "Every day holds a"
batch.append(torch.tensor(tokenizer.encode(txt1)))
batch.append(torch.tensor(tokenizer.encode(txt2)))
batch = torch.stack(batch, dim=0)

model = GPTModel(GPT_CONFIG_124M)
out = model(batch)
print("Input batch:\n", batch)
print("\nOutput shape:", out.shape)
print(out)
# Out:
# Input batch:
#  tensor([[6109, 3626, 6100,  345],
#         [6109, 1110, 6622,  257]])
#
# Output shape: torch.Size([2, 4, 50257])
# tensor([[[-0.4708,  0.5737, -0.5967,  ...,  0.2019, -0.5665,  0.1800],
#          [-0.3895, -0.1978, -0.8885,  ...,  0.2242, -1.2341,  0.1752],
#          [ 0.6973, -0.3432, -0.6080,  ...,  0.3747, -0.6967,  0.1088],
#          [-0.2962, -0.6957, -1.1371,  ...,  0.3579,  0.3058, -0.2915]],
#
#         [[-0.1514,  0.3329, -0.9740,  ..., -0.1368, -0.6974, -0.1851],
#          [-0.4894, -0.3492, -0.9759,  ...,  0.2951, -0.3396,  0.2109],
#          [ 0.5082, -0.1425,  0.2549,  ...,  0.1618,  0.1304, -0.3092],
#          [-0.4146, -0.0514, -0.5187,  ..., -0.1869, -0.1303, -0.4969]]],
#        grad_fn=<UnsafeViewBackward0>)

# %%
total_params = sum(p.numel() for p in model.parameters())
print(f"Total number of parameters: {total_params:,}")
# Out:
# Total number of parameters: 162,419,712

# %%
print("Token embedding layer shape:", model.tok_emb.weight.shape)
print("Output layer shape:", model.out_head.weight.shape)
# Out:
# Token embedding layer shape: torch.Size([50257, 768])
# Output layer shape: torch.Size([50257, 768])

# %%
total_size_bytes = total_params * 4 #A
total_size_mb = total_size_bytes / (1024 * 1024) #B
print(f"Total size of the model: {total_size_mb:.2f} MB")
# Out:
# Total size of the model: 619.58 MB

# %% [markdown]
# ### STEP 11: GENERATING TEXT FROM OUTPUT TOKENS

# %%
def generate_text_simple(model, idx, max_new_tokens, context_size):
    # idx is (batch, n_tokens) array of indices in the current context

    ###Input batch:
 ###tensor([[6109, 3626, 6100,  345],
        ##[6109, 1110, 6622,  257]])

    for _ in range(max_new_tokens):

        # Crop current context if it exceeds the supported context size
        # E.g., if LLM supports only 5 tokens, and the context size is 10
        # then only the last 5 tokens are used as context
        idx_cond = idx[:, -context_size:]

        # Get the predictions
        with torch.no_grad():
            logits = model(idx_cond) ### batch, n_tokens, vocab_size

        # Focus only on the last time step
        # (batch, n_tokens, vocab_size) becomes (batch, vocab_size)
        logits = logits[:, -1, :]

        # Apply softmax to get probabilities
        probas = torch.softmax(logits, dim=-1)  # (batch, vocab_size)

        # Get the idx of the vocab entry with the highest probability value
        idx_next = torch.argmax(probas, dim=-1, keepdim=True)  # (batch, 1)

        # Append sampled index to the running sequence
        idx = torch.cat((idx, idx_next), dim=1)  # (batch, n_tokens+1)

    return idx

# %%
import tiktoken

def text_to_token_ids(text, tokenizer):
    encoded = tokenizer.encode(text, allowed_special={'<|endoftext|>'})
    encoded_tensor = torch.tensor(encoded).unsqueeze(0) # add batch dimension
    return encoded_tensor

def token_ids_to_text(token_ids, tokenizer):
    flat = token_ids.squeeze(0) # remove batch dimension
    return tokenizer.decode(flat.tolist())

start_context = "He said we came here"



token_ids = generate_text_simple(
    model=model,
    idx=text_to_token_ids(start_context, tokenizer),
    max_new_tokens=10,
    context_size=GPT_CONFIG_124M["context_length"]
)

print("Output text:\n", token_ids_to_text(token_ids, tokenizer))
# Out:
# Output text:
#  He said we came here Evans Palestin Au Abram thousands personally observationillechild mL

# %% [markdown]
# ### STEP 12: CREATING TRAINING, TESTING AND VALIDATION DATA

# %%
# Train/validation ratio
train_ratio = 0.90
split_idx = int(train_ratio * len(text_data))
train_data = text_data[:split_idx]
val_data = text_data[split_idx:]


torch.manual_seed(123)

train_loader = create_dataloader_v1(
    train_data,
    batch_size=2,
    max_length=GPT_CONFIG_124M["context_length"],
    stride=GPT_CONFIG_124M["context_length"],
    drop_last=True,
    shuffle=True,
    num_workers=0
)

val_loader = create_dataloader_v1(
    val_data,
    batch_size=2,
    max_length=GPT_CONFIG_124M["context_length"],
    stride=GPT_CONFIG_124M["context_length"],
    drop_last=False,
    shuffle=False,
    num_workers=0
)

# %% [markdown]
# ### STEP 13: DEFINING THE CROSS ENTROPY LOSS FUNCTION

# %%
def calc_loss_batch(input_batch, target_batch, model, device):
    input_batch, target_batch = input_batch.to(device), target_batch.to(device)
    logits = model(input_batch)
    loss = torch.nn.functional.cross_entropy(logits.flatten(0, 1), target_batch.flatten())
    return loss


def calc_loss_loader(data_loader, model, device, num_batches=None):
    total_loss = 0.
    if len(data_loader) == 0:
        return float("nan")
    elif num_batches is None:
        num_batches = len(data_loader)
    else:
        # Reduce the number of batches to match the total number of batches in the data loader
        # if num_batches exceeds the number of batches in the data loader
        num_batches = min(num_batches, len(data_loader))
    for i, (input_batch, target_batch) in enumerate(data_loader):
        if i < num_batches:
            loss = calc_loss_batch(input_batch, target_batch, model, device)
            total_loss += loss.item()
        else:
            break
    return total_loss / num_batches

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Note:
# Uncommenting the following lines will allow the code to run on Apple Silicon chips, if applicable,
# which is approximately 2x faster than on an Apple CPU (as measured on an M3 MacBook Air).
# However, the resulting loss values may be slightly different.

#if torch.cuda.is_available():
#    device = torch.device("cuda")
#elif torch.backends.mps.is_available():
#    device = torch.device("mps")
#else:
#    device = torch.device("cpu")
#
# print(f"Using {device} device.")


model.to(device) # no assignment model = model.to(device) necessary for nn.Module classes


torch.manual_seed(123) # For reproducibility due to the shuffling in the data loader

with torch.no_grad(): # Disable gradient tracking for efficiency because we are not training, yet
    train_loss = calc_loss_loader(train_loader, model, device)
    val_loss = calc_loss_loader(val_loader, model, device)

print("Training loss:", train_loss)
print("Validation loss:", val_loss)
# Out:
# Training loss: 10.963872482902126
# Validation loss: 10.980794906616211

# %%
print(device)
# Out:
# cuda

# %% [markdown]
# ### STEP 14: TRAINING LOOP FOR THE LLM

# %%
def train_model_simple(model, train_loader, val_loader, optimizer, device, num_epochs,
                       eval_freq, eval_iter, start_context, tokenizer):
    # Initialize lists to track losses and tokens seen
    train_losses, val_losses, track_tokens_seen = [], [], []
    tokens_seen, global_step = 0, -1

    # Main training loop
    for epoch in range(num_epochs):
        model.train()  # Set model to training mode

        for input_batch, target_batch in train_loader:
            optimizer.zero_grad() # Reset loss gradients from previous batch iteration
            loss = calc_loss_batch(input_batch, target_batch, model, device)
            loss.backward() # Calculate loss gradients
            optimizer.step() # Update model weights using loss gradients
            tokens_seen += input_batch.numel() # Returns the total number of elements (or tokens) in the input_batch.
            global_step += 1

            # Optional evaluation step
            if global_step % eval_freq == 0:
                train_loss, val_loss = evaluate_model(
                    model, train_loader, val_loader, device, eval_iter)
                train_losses.append(train_loss)
                val_losses.append(val_loss)
                track_tokens_seen.append(tokens_seen)
                print(f"Ep {epoch+1} (Step {global_step:06d}): "
                      f"Train loss {train_loss:.3f}, Val loss {val_loss:.3f}")

        # Print a sample text after each epoch
        generate_and_print_sample(
            model, tokenizer, device, start_context
        )

    return train_losses, val_losses, track_tokens_seen

# %%
def evaluate_model(model, train_loader, val_loader, device, eval_iter):
    model.eval()
    with torch.no_grad():
        train_loss = calc_loss_loader(train_loader, model, device, num_batches=eval_iter)
        val_loss = calc_loss_loader(val_loader, model, device, num_batches=eval_iter)
    model.train()
    return train_loss, val_loss

# %%
def generate_and_print_sample(model, tokenizer, device, start_context):
    model.eval()
    context_size = model.pos_emb.weight.shape[0]
    encoded = text_to_token_ids(start_context, tokenizer).to(device)
    with torch.no_grad():
        token_ids = generate_text_simple(
            model=model, idx=encoded,
            max_new_tokens=50, context_size=context_size
        )
    decoded_text = token_ids_to_text(token_ids, tokenizer)
    print(decoded_text.replace("\n", " "))  # Compact print format
    model.train()

# %%
#!pip uninstall sympy -y
#!pip install sympy==1.12


import time
start_time = time.time()

torch.manual_seed(123)
model = GPTModel(GPT_CONFIG_124M)
model.to(device)
optimizer = torch.optim.AdamW(model.parameters(), lr=0.0004, weight_decay=0.1) #A

num_epochs =2000
train_losses, val_losses, tokens_seen = train_model_simple(
    model, train_loader, val_loader, optimizer, device,
    num_epochs=num_epochs, eval_freq=5, eval_iter=1,
    start_context="Friends, Romans, countrymen", tokenizer=tokenizer
)

end_time = time.time()
execution_time_minutes = (end_time - start_time) / 60
print(f"Training completed in {execution_time_minutes:.2f} minutes.")
# Out:
# Streaming output truncated to the last 5000 lines.
# Ep 1692 (Step 128550): Train loss 0.013, Val loss 9.245
# Ep 1692 (Step 128555): Train loss 0.025, Val loss 9.243
# Ep 1692 (Step 128560): Train loss 0.008, Val loss 9.269
# Ep 1692 (Step 128565): Train loss 0.007, Val loss 9.371
# Ep 1692 (Step 128570): Train loss 0.015, Val loss 9.420
# Ep 1692 (Step 128575): Train loss 0.001, Val loss 9.452
# Ep 1692 (Step 128580): Train loss 0.009, Val loss 9.490
# Ep 1692 (Step 128585): Train loss 0.006, Val loss 9.415
# Ep 1692 (Step 128590): Train loss 0.005, Val loss 9.369
# Friends, Romans, countrymen; but love Brutus and I honour him; Say I fear’d Caesar, honour’d him, and lov’d him. If Brutus will vouchsafe that Antony May safely come to him,
# Ep 1693 (Step 128595): Train loss 0.007, Val loss 9.371
# Ep 1693 (Step 128600): Train loss 0.022, Val loss 9.393
# Ep 1693 (Step 128605): Train loss 0.001, Val loss 9.447
# Ep 1693 (Step 128610): Train loss 0.021, Val loss 9.543
# Ep 1727 (Step 131185): Train loss 0.000, Val loss 9.356
# Ep 1727 (Step 131190): Train loss 0.000, Val loss 9.323
# Ep 1727 (Step 131195): Train loss 0.005, Val loss 9.307
# Ep 1727 (Step 131200): Train loss 0.008, Val loss 9.259
# Ep 1727 (Step 131205): Train loss 0.003, Val loss 9.272
# Ep 1727 (Step 131210): Train loss 0.003, Val loss 9.323
# Ep 1727 (Step 131215): Train loss 0.001, Val loss 9.369
# Ep 1727 (Step 131220): Train loss 0.000, Val loss 9.405
# Ep 1727 (Step 131225): Train loss 0.009, Val loss 9.415
# Ep 1727 (Step 131230): Train loss 0.013, Val loss 9.417
# Ep 1727 (Step 131235): Train loss 0.009, Val loss 9.407
# Ep 1727 (Step 131240): Train loss 0.005, Val loss 9.370
# Ep 1727 (Step 131245): Train loss 0.003, Val loss 9.263
# Ep 1727 (Step 131250): Train loss 0.002, Val loss 9.183
# Friends, Romans, countrymen, And very wisely threat before you sting.  ANTONY. Villains, you did not so when your vile daggers Hack’d one another in the sides of Caesar: You show’d your teeth like
# Ep 1728 (Step 131255): Train loss 0.001, Val loss 9.146
# Ep 1728 (Step 131260): Train loss 0.010, Val loss 9.155
# Ep 1728 (Step 131265): Train loss 0.005, Val loss 9.184
# Ep 1728 (Step 131270): Train loss 0.013, Val loss 9.222
# Ep 1728 (Step 131275): Train loss 0.007, Val loss 9.214
# Ep 1728 (Step 131280): Train loss 0.000, Val loss 9.226
# Ep 1728 (Step 131285): Train loss 0.007, Val loss 9.238
# Ep 1728 (Step 131290): Train loss 0.009, Val loss 9.204
# Ep 1728 (Step 131295): Train loss 0.010, Val loss 9.124
# Ep 1728 (Step 131300): Train loss 0.001, Val loss 9.099
# Ep 1728 (Step 131305): Train loss 0.012, Val loss 9.139
# Ep 1728 (Step 131310): Train loss 0.020, Val loss 9.195
# Ep 1728 (Step 131315): Train loss 0.010, Val loss 9.228
# Ep 1728 (Step 131320): Train loss 0.006, Val loss 9.299
# Ep 1728 (Step 131325): Train loss 0.001, Val loss 9.371
# Friends, Romans, countrymen, Set a huge mountain ’tween my heart and tongue! I have a man’s mind, but a woman’s might. How hard it is for women to keep counsel! Art thou here yet?
# Ep 1729 (Step 131330): Train loss 0.006, Val loss 9.436
# Ep 1729 (Step 131335): Train loss 0.029, Val loss 9.505
# Ep 1729 (Step 131340): Train loss 0.005, Val loss 9.563
# Ep 1729 (Step 131345): Train loss 0.005, Val loss 9.563
# Ep 1729 (Step 131350): Train loss 0.004, Val loss 9.505
# Ep 1729 (Step 131355): Train loss 0.006, Val loss 9.408
# Ep 1729 (Step 131360): Train loss 0.007, Val loss 9.384
# Ep 1729 (Step 131365): Train loss 0.000, Val loss 9.299
# Ep 1729 (Step 131370): Train loss 0.040, Val loss 9.247
# Ep 1729 (Step 131375): Train loss 0.000, Val loss 9.212
# Ep 1729 (Step 131380): Train loss 0.005, Val loss 9.188
# Ep 1729 (Step 131385): Train loss 0.001, Val loss 9.160
# Ep 1729 (Step 131390): Train loss 0.026, Val loss 9.118
# Ep 1729 (Step 131395): Train loss 0.014, Val loss 9.079
# Ep 1729 (Step 131400): Train loss 0.007, Val loss 9.072
# Friends, Romans, countrymen.   MESSALA. Then like a Roman bear the truth I tell, For certain she is dead, and by strange manner.  BRUTUS. Why, farewell, Portia. We must die,
# Ep 1730 (Step 131405): Train loss 0.007, Val loss 9.087
# Ep 1730 (Step 131410): Train loss 0.006, Val loss 9.079
# Ep 1730 (Step 131415): Train loss 0.000, Val loss 9.111
# Ep 1730 (Step 131420): Train loss 0.000, Val loss 9.157
# Ep 1730 (Step 131425): Train loss 0.005, Val loss 9.195
# Ep 1730 (Step 131430): Train loss 0.006, Val loss 9.216
# Ep 1730 (Step 131435): Train loss 0.006, Val loss 9.225
# Ep 1730 (Step 131440): Train loss 0.008, Val loss 9.274
# Ep 1730 (Step 131445): Train loss 0.011, Val loss 9.293
# Ep 1730 (Step 131450): Train loss 0.000, Val loss 9.281
# Ep 1730 (Step 131455): Train loss 0.012, Val loss 9.221
# Ep 1730 (Step 131460): Train loss 0.007, Val loss 9.145
# Ep 1730 (Step 131465): Train loss 0.003, Val loss 9.117
# Ep 1730 (Step 131470): Train loss 0.000, Val loss 9.146
# Ep 1730 (Step 131475): Train loss 0.007, Val loss 9.198
# Friends, Romans, countrymen, And very wisely threat before you sting.  ANTONY. Villains, you did not so when your vile daggers Hack’d one another in the sides of Caesar: You show’d your teeth like
# Ep 1731 (Step 131480): Train loss 0.007, Val loss 9.226
# Ep 1731 (Step 131485): Train loss 0.006, Val loss 9.259
# Ep 1731 (Step 131490): Train loss 0.007, Val loss 9.283
# Ep 1731 (Step 131495): Train loss 0.012, Val loss 9.298
# Ep 1731 (Step 131500): Train loss 0.005, Val loss 9.298
# Ep 1731 (Step 131505): Train loss 0.000, Val loss 9.304
# Ep 1731 (Step 131510): Train loss 0.003, Val loss 9.306
# Ep 1731 (Step 131515): Train loss 0.002, Val loss 9.237
# Ep 1731 (Step 131520): Train loss 0.001, Val loss 9.159
# Ep 1731 (Step 131525): Train loss 0.006, Val loss 9.085
# Ep 1731 (Step 131530): Train loss 0.006, Val loss 9.030
# Ep 1731 (Step 131535): Train loss 0.015, Val loss 9.025
# Ep 1731 (Step 131540): Train loss 0.000, Val loss 9.045
# Ep 1731 (Step 131545): Train loss 0.003, Val loss 9.077
# Ep 1731 (Step 131550): Train loss 0.005, Val loss 9.109
# Ep 1731 (Step 131555): Train loss 0.004, Val loss 9.152
# Friends, Romans, countrymen, And ghost.  MESSALA. Believe not so.  CASSIUS. I but believe it partly, For I am fresh of spirit, and resolv’d To meet
# Ep 1732 (Step 131560): Train loss 0.016, Val loss 9.198
# Ep 1732 (Step 131565): Train loss 0.005, Val loss 9.221
# Ep 1732 (Step 131570): Train loss 0.000, Val loss 9.234
# Ep 1732 (Step 131575): Train loss 0.004, Val loss 9.242
# Ep 1732 (Step 131580): Train loss 0.007, Val loss 9.245
# Ep 1732 (Step 131585): Train loss 0.003, Val loss 9.221
# Ep 1732 (Step 131590): Train loss 0.006, Val loss 9.149
# Ep 1732 (Step 131595): Train loss 0.011, Val loss 9.099
# Ep 1732 (Step 131600): Train loss 0.023, Val loss 9.063
# Ep 1732 (Step 131605): Train loss 0.023, Val loss 9.059
# Ep 1732 (Step 131610): Train loss 0.009, Val loss 9.100
# Ep 1732 (Step 131615): Train loss 0.005, Val loss 9.122
# Ep 1732 (Step 131620): Train loss 0.005, Val loss 9.133
# Ep 1732 (Step 131625): Train loss 0.006, Val loss 9.145
# Ep 1732 (Step 131630): Train loss 0.007, Val loss 9.159
# Friends, Romans, countrymen, But honours you; and everyone doth wish You had but that opinion of yourself Which every noble Roman bears of you. This is Trebonius.  BRUTUS. He is welcome hither.
# Ep 1733 (Step 131635): Train loss 0.000, Val loss 9.148
# Ep 1733 (Step 131640): Train loss 0.008, Val loss 9.127
# Ep 1733 (Step 131645): Train loss 0.002, Val loss 9.165
# Ep 1733 (Step 131650): Train loss 0.008, Val loss 9.190
# Ep 1733 (Step 131655): Train loss 0.007, Val loss 9.180
# Ep 1733 (Step 131660): Train loss 0.004, Val loss 9.167
# Ep 1733 (Step 131665): Train loss 0.011, Val loss 9.127
# Ep 1733 (Step 131670): Train loss 0.004, Val loss 9.101
# Ep 1733 (Step 131675): Train loss 0.000, Val loss 9.097
# Ep 1733 (Step 131680): Train loss 0.009, Val loss 9.136
# Ep 1733 (Step 131685): Train loss 0.003, Val loss 9.176
# Ep 1733 (Step 131690): Train loss 0.014, Val loss 9.197
# Ep 1733 (Step 131695): Train loss 0.026, Val loss 9.170
# Ep 1733 (Step 131700): Train loss 0.000, Val loss 9.118
# Ep 1733 (Step 131705): Train loss 0.005, Val loss 9.089
# Friends, Romans, countrymen, But honours you; and everyone doth wish You had but that opinion of yourself Which every noble Roman bears of you. This is Trebonius.  BRUTUS. He is welcome hither.
# Ep 1734 (Step 131710): Train loss 0.000, Val loss 9.067
# Ep 1734 (Step 131715): Train loss 0.003, Val loss 9.029
# Ep 1734 (Step 131720): Train loss 0.000, Val loss 8.982
# Ep 1734 (Step 131725): Train loss 0.000, Val loss 8.979
# Ep 1734 (Step 131730): Train loss 0.004, Val loss 8.995
# Ep 1734 (Step 131735): Train loss 0.016, Val loss 9.015
# Ep 1734 (Step 131740): Train loss 0.000, Val loss 9.048
# Ep 1734 (Step 131745): Train loss 0.007, Val loss 9.104
# Ep 1734 (Step 131750): Train loss 0.001, Val loss 9.159
# Ep 1734 (Step 131755): Train loss 0.005, Val loss 9.170
# Ep 1734 (Step 131760): Train loss 0.010, Val loss 9.176
# Ep 1734 (Step 131765): Train loss 0.007, Val loss 9.213
# Ep 1734 (Step 131770): Train loss 0.047, Val loss 9.242
# Ep 1734 (Step 131775): Train loss 0.009, Val loss 9.290
# Ep 1734 (Step 131780): Train loss 0.005, Val loss 9.260
# Friends, Romans, countrymen, And very wisely threat before you sting.  ANTONY. Villains, you did not so when your vile daggers Hack’d one another in the sides of Caesar: You show’d your teeth like
# Ep 1735 (Step 131785): Train loss 0.009, Val loss 9.219
# Ep 1735 (Step 131790): Train loss 0.012, Val loss 9.184
# Ep 1735 (Step 131795): Train loss 0.011, Val loss 9.149
# Ep 1735 (Step 131800): Train loss 0.001, Val loss 9.160
# Ep 1735 (Step 131805): Train loss 0.002, Val loss 9.195
# Ep 1735 (Step 131810): Train loss 0.000, Val loss 9.188
# Ep 1735 (Step 131815): Train loss 0.012, Val loss 9.089
# Ep 1735 (Step 131820): Train loss 0.007, Val loss 8.987
# Ep 1735 (Step 131825): Train loss 0.010, Val loss 8.916
# Ep 1735 (Step 131830): Train loss 0.008, Val loss 8.884
# Ep 1735 (Step 131835): Train loss 0.001, Val loss 8.912
# Ep 1735 (Step 131840): Train loss 0.004, Val loss 8.908
# Ep 1735 (Step 131845): Train loss 0.003, Val loss 8.949
# Ep 1735 (Step 131850): Train loss 0.006, Val loss 8.977
# Ep 1735 (Step 131855): Train loss 0.007, Val loss 9.046
# Friends, Romans, countrymen, But honours you; and everyone doth wish You had but that opinion of yourself Which every noble Roman bears of you. This is Trebonius.  BRUTUS. He is welcome hither.
# Ep 1736 (Step 131860): Train loss 0.013, Val loss 9.132
# Ep 1736 (Step 131865): Train loss 0.000, Val loss 9.231
# Ep 1736 (Step 131870): Train loss 0.035, Val loss 9.278
# Ep 1736 (Step 131875): Train loss 0.013, Val loss 9.284
# Ep 1736 (Step 131880): Train loss 0.006, Val loss 9.151
# Ep 1736 (Step 131885): Train loss 0.002, Val loss 9.061
# Ep 1736 (Step 131890): Train loss 0.008, Val loss 9.027
# Ep 1736 (Step 131895): Train loss 0.007, Val loss 9.021
# Ep 1736 (Step 131900): Train loss 0.006, Val loss 9.031
# Ep 1736 (Step 131905): Train loss 0.016, Val loss 9.096
# Ep 1736 (Step 131910): Train loss 0.035, Val loss 9.166
# Ep 1736 (Step 131915): Train loss 0.002, Val loss 9.192
# Ep 1736 (Step 131920): Train loss 0.002, Val loss 9.171
# Ep 1736 (Step 131925): Train loss 0.004, Val loss 9.158
# Ep 1736 (Step 131930): Train loss 0.000, Val loss 9.115
# Ep 1736 (Step 131935): Train loss 0.000, Val loss 9.035
# Friends, Romans, countrymen, But honours you shall have your hand. Now, go on his rank, Unshak’d of motion: and that I am he, Let this day forth, I’ll use you for my
# Ep 1737 (Step 131940): Train loss 0.004, Val loss 9.014
# Ep 1737 (Step 131945): Train loss 0.016, Val loss 9.040
# Ep 1737 (Step 131950): Train loss 0.009, Val loss 9.066
# Ep 1737 (Step 131955): Train loss 0.006, Val loss 9.044
# Ep 1737 (Step 131960): Train loss 0.001, Val loss 8.976
# Ep 1737 (Step 131965): Train loss 0.025, Val loss 9.076
# Ep 1737 (Step 131970): Train loss 0.022, Val loss 9.300
# Ep 1737 (Step 131975): Train loss 0.004, Val loss 9.423
# Ep 1737 (Step 131980): Train loss 0.016, Val loss 9.445
# Ep 1737 (Step 131985): Train loss 0.001, Val loss 9.414
# Ep 1737 (Step 131990): Train loss 0.010, Val loss 9.391
# Ep 1737 (Step 131995): Train loss 0.012, Val loss 9.301
# Ep 1737 (Step 132000): Train loss 0.006, Val loss 9.245
# Ep 1737 (Step 132005): Train loss 0.003, Val loss 9.319
# Ep 1737 (Step 132010): Train loss 0.006, Val loss 9.481
# Friends, Romans, countrymen, And will follow, That should be in his tent, That day he overcame the Nervii. Look, thou hast lost the breed of noble bloods!  That mothers shall but smile when they behold Their infants
# Ep 1738 (Step 132015): Train loss 0.002, Val loss 9.431
# Ep 1738 (Step 132020): Train loss 0.218, Val loss 9.374
# Ep 1738 (Step 132025): Train loss 0.035, Val loss 9.104
# Ep 1738 (Step 132030): Train loss 0.021, Val loss 8.954
# Ep 1738 (Step 132035): Train loss 0.009, Val loss 8.984
# Ep 1738 (Step 132040): Train loss 0.022, Val loss 9.057
# Ep 1738 (Step 132045): Train loss 0.001, Val loss 9.110
# Ep 1738 (Step 132050): Train loss 0.009, Val loss 9.043
# Ep 1738 (Step 132055): Train loss 0.012, Val loss 8.987
# Ep 1738 (Step 132060): Train loss 0.030, Val loss 8.993
# Ep 1738 (Step 132065): Train loss 0.011, Val loss 9.104
# Ep 1738 (Step 132070): Train loss 0.004, Val loss 9.259
# Ep 1738 (Step 132075): Train loss 0.004, Val loss 9.256
# ...
# Ep 1985 (Step 150850): Train loss 0.006, Val loss 9.437
# Ep 1985 (Step 150855): Train loss 0.005, Val loss 9.482
# Friends, Romans, countrymen!  SECOND CITIZEN. They were villains, murderers. The will! Read the will!  ANTONY. You will compel me then to read the will? Then make a ring about the corpse of Caesar
# Ep 1986 (Step 150860): Train loss 0.006, Val loss 9.470
# Ep 1986 (Step 150865): Train loss 0.002, Val loss 9.418
# Ep 1986 (Step 150870): Train loss 0.002, Val loss 9.419
# Ep 1986 (Step 150875): Train loss 0.009, Val loss 9.417
# Ep 1986 (Step 150880): Train loss 0.000, Val loss 9.396
# Ep 1986 (Step 150885): Train loss 0.012, Val loss 9.382
# Ep 1986 (Step 150890): Train loss 0.000, Val loss 9.376
# Ep 1986 (Step 150895): Train loss 0.008, Val loss 9.365
# Ep 1986 (Step 150900): Train loss 0.006, Val loss 9.369
# Ep 1986 (Step 150905): Train loss 0.012, Val loss 9.381
# Ep 1986 (Step 150910): Train loss 0.000, Val loss 9.395
# Ep 1986 (Step 150915): Train loss 0.020, Val loss 9.406
# Ep 1986 (Step 150920): Train loss 0.031, Val loss 9.361
# Ep 1986 (Step 150925): Train loss 0.004, Val loss 9.311
# Ep 1986 (Step 150930): Train loss 0.000, Val loss 9.268
# Ep 1986 (Step 150935): Train loss 0.067, Val loss 9.279
# Friends, Romans, countrymen.  MARULLUS. Where is thy leather apron and thy rule? What dost thou with thy best apparel on? You, sir, what trade are you?  COBBLER. Truly,
# Ep 1987 (Step 150940): Train loss 0.000, Val loss 9.337
# Ep 1987 (Step 150945): Train loss 0.005, Val loss 9.364
# Ep 1987 (Step 150950): Train loss 0.009, Val loss 9.347
# Ep 1987 (Step 150955): Train loss 0.000, Val loss 9.258
# Ep 1987 (Step 150960): Train loss 0.000, Val loss 9.189
# Ep 1987 (Step 150965): Train loss 0.019, Val loss 9.145
# Ep 1987 (Step 150970): Train loss 0.005, Val loss 9.132
# Ep 1987 (Step 150975): Train loss 0.008, Val loss 9.184
# Ep 1987 (Step 150980): Train loss 0.008, Val loss 9.248
# Ep 1987 (Step 150985): Train loss 0.008, Val loss 9.276
# Ep 1987 (Step 150990): Train loss 0.009, Val loss 9.286
# Ep 1990 (Step 151195): Train loss 0.001, Val loss 9.314
# Ep 1990 (Step 151200): Train loss 0.000, Val loss 9.331
# Ep 1990 (Step 151205): Train loss 0.010, Val loss 9.342
# Ep 1990 (Step 151210): Train loss 0.007, Val loss 9.352
# Ep 1990 (Step 151215): Train loss 0.009, Val loss 9.358
# Ep 1990 (Step 151220): Train loss 0.007, Val loss 9.337
# Ep 1990 (Step 151225): Train loss 0.003, Val loss 9.349
# Ep 1990 (Step 151230): Train loss 0.006, Val loss 9.356
# Ep 1990 (Step 151235): Train loss 0.006, Val loss 9.360
# Friends, Romans, countrymen!  SECOND CITIZEN. They were villains, murderers. The will! Read the will!  ANTONY. You will compel me then to read the will? Then make a ring about the corpse of Caesar
# Ep 1991 (Step 151240): Train loss 0.003, Val loss 9.371
# Ep 1991 (Step 151245): Train loss 0.011, Val loss 9.380
# Ep 1991 (Step 151250): Train loss 0.002, Val loss 9.374
# Ep 1991 (Step 151255): Train loss 0.013, Val loss 9.336
# Ep 1991 (Step 151260): Train loss 0.006, Val loss 9.333
# Ep 1991 (Step 151265): Train loss 0.011, Val loss 9.350
# Ep 1991 (Step 151270): Train loss 0.013, Val loss 9.314
# Ep 1991 (Step 151275): Train loss 0.003, Val loss 9.274
# Ep 1991 (Step 151280): Train loss 0.000, Val loss 9.265
# Ep 1991 (Step 151285): Train loss 0.007, Val loss 9.305
# Ep 1991 (Step 151290): Train loss 0.004, Val loss 9.359
# Ep 1991 (Step 151295): Train loss 0.008, Val loss 9.397
# Ep 1991 (Step 151300): Train loss 0.014, Val loss 9.423
# Ep 1991 (Step 151305): Train loss 0.006, Val loss 9.400
# Ep 1991 (Step 151310): Train loss 0.013, Val loss 9.336
# Ep 1991 (Step 151315): Train loss 0.006, Val loss 9.288
# Friends, Romans, countrymen.  SECOND CITIZEN. They were villains, murderers. The will! Read the will!  ANTONY. You will compel me then to read the will? Then make a ring about the corpse of Caesar
# Ep 1992 (Step 151320): Train loss 0.001, Val loss 9.273
# Ep 1992 (Step 151325): Train loss 0.000, Val loss 9.266
# Ep 1992 (Step 151330): Train loss 0.000, Val loss 9.284
# Ep 1992 (Step 151335): Train loss 0.005, Val loss 9.353
# Ep 1992 (Step 151340): Train loss 0.010, Val loss 9.396
# Ep 1992 (Step 151345): Train loss 0.004, Val loss 9.434
# Ep 1992 (Step 151350): Train loss 0.004, Val loss 9.458
# Ep 1992 (Step 151355): Train loss 0.006, Val loss 9.530
# Ep 1992 (Step 151360): Train loss 0.007, Val loss 9.563
# Ep 1992 (Step 151365): Train loss 0.001, Val loss 9.558
# Ep 1992 (Step 151370): Train loss 0.006, Val loss 9.561
# Ep 1992 (Step 151375): Train loss 0.108, Val loss 9.549
# Ep 1992 (Step 151380): Train loss 0.012, Val loss 9.534
# Ep 1992 (Step 151385): Train loss 0.010, Val loss 9.557
# Ep 1992 (Step 151390): Train loss 0.001, Val loss 9.568
# Friends, Romans, countrymen!  MARULLUS. Where is thy leather apron and thy rule? What dost thou with thy best apparel on? You, sir, what trade are you?  COBBLER. Truly,
# Ep 1993 (Step 151395): Train loss 0.003, Val loss 9.551
# Ep 1993 (Step 151400): Train loss 0.011, Val loss 9.553
# Ep 1993 (Step 151405): Train loss 0.008, Val loss 9.591
# Ep 1993 (Step 151410): Train loss 0.020, Val loss 9.698
# Ep 1993 (Step 151415): Train loss 0.000, Val loss 9.798
# Ep 1993 (Step 151420): Train loss 0.012, Val loss 9.611
# Ep 1993 (Step 151425): Train loss 0.011, Val loss 9.356
# Ep 1993 (Step 151430): Train loss 0.004, Val loss 9.139
# Ep 1993 (Step 151435): Train loss 0.006, Val loss 9.061
# Ep 1993 (Step 151440): Train loss 0.006, Val loss 9.119
# Ep 1993 (Step 151445): Train loss 0.012, Val loss 9.261
# Ep 1993 (Step 151450): Train loss 0.000, Val loss 9.386
# Ep 1993 (Step 151455): Train loss 0.111, Val loss 9.448
# Ep 1993 (Step 151460): Train loss 0.005, Val loss 9.420
# Ep 1993 (Step 151465): Train loss 0.011, Val loss 9.173
# Friends, Romans, countrymen. This is a Summer’s evening, in his tent, That day he overcame the Nervii. Look, in this place ran Cassius’ dagger through: See what a rent the envious Casca made:
# Ep 1994 (Step 151470): Train loss 0.010, Val loss 9.081
# Ep 1994 (Step 151475): Train loss 0.007, Val loss 9.077
# Ep 1994 (Step 151480): Train loss 0.006, Val loss 9.185
# Ep 1994 (Step 151485): Train loss 0.012, Val loss 9.278
# Ep 1994 (Step 151490): Train loss 0.000, Val loss 9.350
# Ep 1994 (Step 151495): Train loss 0.025, Val loss 9.426
# Ep 1994 (Step 151500): Train loss 0.009, Val loss 9.500
# Ep 1994 (Step 151505): Train loss 0.004, Val loss 9.498
# Ep 1994 (Step 151510): Train loss 0.007, Val loss 9.480
# Ep 1994 (Step 151515): Train loss 0.009, Val loss 9.430
# Ep 1994 (Step 151520): Train loss 0.006, Val loss 9.338
# Ep 1994 (Step 151525): Train loss 0.038, Val loss 9.376
# Ep 1994 (Step 151530): Train loss 0.046, Val loss 9.448
# Ep 1994 (Step 151535): Train loss 0.000, Val loss 9.407
# Ep 1994 (Step 151540): Train loss 0.009, Val loss 9.306
# Friends, Romans, countrymen!  MARULLUS. Where is thy leather apron and thy rule? What dost thou with thy best apparel on? You, sir, what trade are you?  COBBLER. Truly,
# Ep 1995 (Step 151545): Train loss 0.015, Val loss 9.270
# Ep 1995 (Step 151550): Train loss 0.012, Val loss 9.274
# Ep 1995 (Step 151555): Train loss 0.002, Val loss 9.319
# Ep 1995 (Step 151560): Train loss 0.014, Val loss 9.429
# Ep 1995 (Step 151565): Train loss 0.008, Val loss 9.517
# Ep 1995 (Step 151570): Train loss 0.011, Val loss 9.492
# Ep 1995 (Step 151575): Train loss 0.001, Val loss 9.383
# Ep 1995 (Step 151580): Train loss 0.003, Val loss 9.304
# Ep 1995 (Step 151585): Train loss 0.000, Val loss 9.243
# Ep 1995 (Step 151590): Train loss 0.005, Val loss 9.330
# Ep 1995 (Step 151595): Train loss 0.010, Val loss 9.424
# Ep 1995 (Step 151600): Train loss 0.011, Val loss 9.508
# Ep 1998 (Step 151800): Train loss 0.002, Val loss 9.650
# Ep 1998 (Step 151805): Train loss 0.005, Val loss 9.649
# Ep 1998 (Step 151810): Train loss 0.003, Val loss 9.620
# Ep 1998 (Step 151815): Train loss 0.000, Val loss 9.501
# Ep 1998 (Step 151820): Train loss 0.034, Val loss 9.397
# Ep 1998 (Step 151825): Train loss 0.014, Val loss 9.363
# Ep 1998 (Step 151830): Train loss 0.013, Val loss 9.331
# Ep 1998 (Step 151835): Train loss 0.005, Val loss 9.295
# Ep 1998 (Step 151840): Train loss 0.014, Val loss 9.299
# Ep 1998 (Step 151845): Train loss 0.010, Val loss 9.316
# Friends, Romans, countrymen, And bring us.  OCTAVIUS. Mark Antony, shall we give sign of battle?  ANTONY. No, Caesar, we will answer on their charge. Make forth; the generals would
# Ep 1999 (Step 151850): Train loss 0.020, Val loss 9.325
# Ep 1999 (Step 151855): Train loss 0.017, Val loss 9.289
# Ep 1999 (Step 151860): Train loss 0.036, Val loss 9.272
# Ep 1999 (Step 151865): Train loss 0.007, Val loss 9.248
# Ep 1999 (Step 151870): Train loss 0.001, Val loss 9.281
# Ep 1999 (Step 151875): Train loss 0.014, Val loss 9.307
# Ep 1999 (Step 151880): Train loss 0.004, Val loss 9.323
# Ep 1999 (Step 151885): Train loss 0.032, Val loss 9.332
# Ep 1999 (Step 151890): Train loss 0.006, Val loss 9.338
# Ep 1999 (Step 151895): Train loss 0.000, Val loss 9.366
# Ep 1999 (Step 151900): Train loss 0.001, Val loss 9.346
# Ep 1999 (Step 151905): Train loss 0.014, Val loss 9.285
# Ep 1999 (Step 151910): Train loss 0.008, Val loss 9.260
# Ep 1999 (Step 151915): Train loss 0.020, Val loss 9.272
# Ep 1999 (Step 151920): Train loss 0.005, Val loss 9.292
# Friends, Romans, countrymen, and wash. How many ages hence Shall this our lofty scene be acted over In States unborn, and accents yet unknown!  BRUTUS. How many times shall Caesar bleed in sport, That now on Pompey
# Ep 2000 (Step 151925): Train loss 0.007, Val loss 9.347
# Ep 2000 (Step 151930): Train loss 0.005, Val loss 9.433
# Ep 2000 (Step 151935): Train loss 0.007, Val loss 9.411
# Ep 2000 (Step 151940): Train loss 0.001, Val loss 9.300
# Ep 2000 (Step 151945): Train loss 0.049, Val loss 9.210
# Ep 2000 (Step 151950): Train loss 0.009, Val loss 9.194
# Ep 2000 (Step 151955): Train loss 0.007, Val loss 9.210
# Ep 2000 (Step 151960): Train loss 0.029, Val loss 9.295
# Ep 2000 (Step 151965): Train loss 0.011, Val loss 9.371
# Ep 2000 (Step 151970): Train loss 0.007, Val loss 9.364
# Ep 2000 (Step 151975): Train loss 0.007, Val loss 9.261
# Ep 2000 (Step 151980): Train loss 0.000, Val loss 9.225
# Ep 2000 (Step 151985): Train loss 0.011, Val loss 9.252
# Ep 2000 (Step 151990): Train loss 0.002, Val loss 9.308
# Ep 2000 (Step 151995): Train loss 0.009, Val loss 9.344
# Friends, Romans, countrymen, And this night in commons hear the terms of the Project Gutenberg trademark. If you do not charge anything for copies of this eBook, complying with the trademark license is very easy. You may use this eBook for nearly any purpose such
# Training completed in 348.73 minutes.

# %% [markdown]
# As we can see, based on the results printed during the training, the training loss improve drastically, starting with a value of 9.558 and converging to 0.762.
#
# The language skills of
# the model have improved quite a lot. In the beginning, the model is only able to append
# commas to the start context ("Every effort moves you,,,,,,,,,,,,") or repeat the
# word "and". At the end of the training, it can generate grammatically correct text.
#
#
# Similar to the training set loss, we can see that the validation loss starts high (9.856)
# and decreases during the training. However, it never becomes as small as the training set
# loss and remains at 6.372 after the 10th epoch.

# %% [markdown]
# ### STEP 15: PLOTTING THE LOSSES

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator


def plot_losses(epochs_seen, tokens_seen, train_losses, val_losses):
    fig, ax1 = plt.subplots(figsize=(5, 3))

    # Plot training and validation loss against epochs
    ax1.plot(epochs_seen, train_losses, label="Training loss")
    ax1.plot(epochs_seen, val_losses, linestyle="-.", label="Validation loss")
    ax1.set_xlabel("Epochs")
    ax1.set_ylabel("Loss")
    ax1.legend(loc="upper right")
    ax1.xaxis.set_major_locator(MaxNLocator(integer=True))  # only show integer labels on x-axis

    # Create a second x-axis for tokens seen
    ax2 = ax1.twiny()  # Create a second x-axis that shares the same y-axis
    ax2.plot(tokens_seen, train_losses, alpha=0)  # Invisible plot for aligning ticks
    ax2.set_xlabel("Tokens seen")

    fig.tight_layout()  # Adjust layout to make room
    plt.savefig("loss-plot.pdf")
    plt.show()

epochs_tensor = torch.linspace(0, num_epochs, len(train_losses))
plot_losses(epochs_tensor, tokens_seen, train_losses, val_losses)

# %%
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Move model to device
model = model.to(device)

# Prepare token_ids
token_ids = text_to_token_ids("one expects that", tokenizer)
token_ids = token_ids.to(device)  # Move token_ids to the correct device

# Generate text
token_ids = generate_text_simple(
    model=model,
    idx=token_ids,  # Ensure token_ids are on the correct device
    max_new_tokens=25,
    context_size=GPT_CONFIG_124M["context_length"]
)

# Convert token_ids back to text
print("Output text:\n", token_ids_to_text(token_ids, tokenizer))
# Out:
# Output text:
#  one expects that will. Ahest._]
#
# PORTIA.
# I must go in.
# [_Aside._] Ay me,

# %% [markdown]
# ### STEP 16: IMPLEMENTING TEMPERATURE SCALING AND TOP-K SAMPLING

# %%
def generate(model, idx, max_new_tokens, context_size, temperature=0.0, top_k=None, eos_id=None):

    # For-loop is the same as before: Get logits, and only focus on last time step
    for _ in range(max_new_tokens):
        idx_cond = idx[:, -context_size:]
        with torch.no_grad():
            logits = model(idx_cond)
        logits = logits[:, -1, :]

        # New: Filter logits with top_k sampling
        if top_k is not None:
            # Keep only top_k values
            top_logits, _ = torch.topk(logits, top_k)
            min_val = top_logits[:, -1]
            logits = torch.where(logits < min_val, torch.tensor(float("-inf")).to(logits.device), logits)

        # New: Apply temperature scaling
        if temperature > 0.0:
            logits = logits / temperature

            # Apply softmax to get probabilities
            probs = torch.softmax(logits, dim=-1)  # (batch_size, context_len)

            # Sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1)  # (batch_size, 1)

        # Otherwise same as before: get idx of the vocab entry with the highest logits value
        else:
            idx_next = torch.argmax(logits, dim=-1, keepdim=True)  # (batch_size, 1)

        if idx_next == eos_id:  # Stop generating early if end-of-sequence token is encountered and eos_id is specified
            break

        # Same as before: append sampled index to the running sequence
        idx = torch.cat((idx, idx_next), dim=1)  # (batch_size, num_tokens+1)

    return idx

# %%
import torch

# Set random seed for reproducibility
torch.manual_seed(123)

# Define the device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Move model to the device
model = model.to(device)

# Prepare token_ids
token_ids = text_to_token_ids("Every effort moves you", tokenizer)
token_ids = token_ids.to(device)  # Move token_ids to the correct device

# Generate text with specific parameters
token_ids = generate(
    model=model,
    idx=token_ids,  # Ensure token_ids are on the correct device
    max_new_tokens=15,
    context_size=GPT_CONFIG_124M["context_length"],
    top_k=25,
    temperature=1.4
)

# Convert token_ids back to text and print
print("Output text:\n", token_ids_to_text(token_ids, tokenizer))
# Out:
# Output text:
#  Every effort moves you;
# Of all be, I do I take.
#  A street

# %% [markdown]
# ### STEP 17: SAVING THE MODEL PARAMETERS

# %%
model = GPTModel(GPT_CONFIG_124M)
torch.save(model.state_dict(), "model.pth")

# %%
model = GPTModel(GPT_CONFIG_124M)
model.load_state_dict(torch.load("model.pth"))
model.eval()
# Out:
# GPTModel(
#   (tok_emb): Embedding(50257, 768)
#   (pos_emb): Embedding(256, 768)
#   (drop_emb): Dropout(p=0.1, inplace=False)
#   (trf_blocks): Sequential(
#     (0): TransformerBlock(
#       (att): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=False)
#         (W_key): Linear(in_features=768, out_features=768, bias=False)
#         (W_value): Linear(in_features=768, out_features=768, bias=False)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU()
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNorm()
#       (norm2): LayerNorm()
#       (drop_shortcut): Dropout(p=0.1, inplace=False)
#     )
#     (1): TransformerBlock(
#       (att): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=False)
#         (W_key): Linear(in_features=768, out_features=768, bias=False)
#         (W_value): Linear(in_features=768, out_features=768, bias=False)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU()
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNorm()
#       (norm2): LayerNorm()
#       (drop_shortcut): Dropout(p=0.1, inplace=False)
#     )
#     (2): TransformerBlock(
#       (att): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=False)
#         (W_key): Linear(in_features=768, out_features=768, bias=False)
#         (W_value): Linear(in_features=768, out_features=768, bias=False)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU()
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNorm()
#       (norm2): LayerNorm()
#       (drop_shortcut): Dropout(p=0.1, inplace=False)
#     )
#     (3): TransformerBlock(
#       (att): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=False)
#         (W_key): Linear(in_features=768, out_features=768, bias=False)
#         (W_value): Linear(in_features=768, out_features=768, bias=False)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU()
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNorm()
#       (norm2): LayerNorm()
#       (drop_shortcut): Dropout(p=0.1, inplace=False)
#     )
#     (4): TransformerBlock(
#       (att): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=False)
#         (W_key): Linear(in_features=768, out_features=768, bias=False)
#         (W_value): Linear(in_features=768, out_features=768, bias=False)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU()
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNorm()
#       (norm2): LayerNorm()
#       (drop_shortcut): Dropout(p=0.1, inplace=False)
#     )
#     (5): TransformerBlock(
#       (att): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=False)
#         (W_key): Linear(in_features=768, out_features=768, bias=False)
#         (W_value): Linear(in_features=768, out_features=768, bias=False)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU()
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNorm()
#       (norm2): LayerNorm()
#       (drop_shortcut): Dropout(p=0.1, inplace=False)
#     )
#     (6): TransformerBlock(
#       (att): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=False)
#         (W_key): Linear(in_features=768, out_features=768, bias=False)
#         (W_value): Linear(in_features=768, out_features=768, bias=False)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU()
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNorm()
#       (norm2): LayerNorm()
#       (drop_shortcut): Dropout(p=0.1, inplace=False)
#     )
#     (7): TransformerBlock(
#       (att): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=False)
#         (W_key): Linear(in_features=768, out_features=768, bias=False)
#         (W_value): Linear(in_features=768, out_features=768, bias=False)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU()
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNorm()
#       (norm2): LayerNorm()
#       (drop_shortcut): Dropout(p=0.1, inplace=False)
#     )
#     (8): TransformerBlock(
#       (att): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=False)
#         (W_key): Linear(in_features=768, out_features=768, bias=False)
#         (W_value): Linear(in_features=768, out_features=768, bias=False)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU()
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNorm()
#       (norm2): LayerNorm()
#       (drop_shortcut): Dropout(p=0.1, inplace=False)
#     )
#     (9): TransformerBlock(
#       (att): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=False)
#         (W_key): Linear(in_features=768, out_features=768, bias=False)
#         (W_value): Linear(in_features=768, out_features=768, bias=False)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU()
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNorm()
#       (norm2): LayerNorm()
#       (drop_shortcut): Dropout(p=0.1, inplace=False)
#     )
#     (10): TransformerBlock(
#       (att): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=False)
#         (W_key): Linear(in_features=768, out_features=768, bias=False)
#         (W_value): Linear(in_features=768, out_features=768, bias=False)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU()
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNorm()
#       (norm2): LayerNorm()
#       (drop_shortcut): Dropout(p=0.1, inplace=False)
#     )
#     (11): TransformerBlock(
#       (att): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=False)
#         (W_key): Linear(in_features=768, out_features=768, bias=False)
#         (W_value): Linear(in_features=768, out_features=768, bias=False)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU()
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNorm()
#       (norm2): LayerNorm()
#       (drop_shortcut): Dropout(p=0.1, inplace=False)
#     )
#   )
#   (final_norm): LayerNorm()
#   (out_head): Linear(in_features=768, out_features=50257, bias=False)
# )

# %%
optimizer = torch.optim.AdamW(model.parameters(), lr=0.0004, weight_decay=0.1)

torch.save({
    "model_state_dict": model.state_dict(),
    "optimizer_state_dict": optimizer.state_dict(),
    },
    "model_and_optimizer.pth"
)

# %%
checkpoint = torch.load("model_and_optimizer.pth")
model = GPTModel(GPT_CONFIG_124M)
model.load_state_dict(checkpoint["model_state_dict"])
optimizer = torch.optim.AdamW(model.parameters(), lr=5e-4, weight_decay=0.1)
optimizer.load_state_dict(checkpoint["optimizer_state_dict"])
model.train();
