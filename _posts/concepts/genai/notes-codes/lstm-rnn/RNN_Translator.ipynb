# %%
import torch
import torch.nn as nn
import torch.optim as optim

# --------------------------
# 1. A Tiny Manual RNN Encoder
# --------------------------
class TinyEncoder(nn.Module):
    def __init__(self, input_vocab_size, embed_size, hidden_size):
        super().__init__()
        self.embedding = nn.Embedding(input_vocab_size, embed_size)

        # RNN parameters
        self.hidden_size = hidden_size
        self.W_h = nn.Parameter(torch.randn(hidden_size, hidden_size)*0.1)
        self.W_x = nn.Parameter(torch.randn(hidden_size, embed_size)*0.1)
        self.b   = nn.Parameter(torch.zeros(hidden_size))

    def forward(self, src_tokens):
        """
        src_tokens: shape (src_len,)
        Returns final hidden state (hidden_size,).
        """
        h = torch.zeros(self.hidden_size)

        for t in range(src_tokens.shape[0]):
            token_id = src_tokens[t]
            x_t = self.embedding(token_id)

            h = torch.tanh(
                torch.mv(self.W_h, h) +
                torch.mv(self.W_x, x_t) +
                self.b
            )

        return h


# -------------------------
# 2. A Tiny Manual RNN Decoder
# -------------------------
class TinyDecoder(nn.Module):
    def __init__(self, output_vocab_size, embed_size, hidden_size):
        super().__init__()
        self.embedding = nn.Embedding(output_vocab_size, embed_size)

        self.hidden_size = hidden_size
        self.W_h = nn.Parameter(torch.randn(hidden_size, hidden_size)*0.1)
        self.W_x = nn.Parameter(torch.randn(hidden_size, embed_size)*0.1)
        self.b   = nn.Parameter(torch.zeros(hidden_size))

        # Output projection
        self.W_out = nn.Parameter(torch.randn(output_vocab_size, hidden_size)*0.1)
        self.b_out = nn.Parameter(torch.zeros(output_vocab_size))

    def forward(self, dec_tokens, init_hidden):
        h = init_hidden
        logits_list = []

        for t in range(dec_tokens.shape[0]):
            token_id = dec_tokens[t]
            x_t = self.embedding(token_id)

            h = torch.tanh(
                torch.mv(self.W_h, h) +
                torch.mv(self.W_x, x_t) +
                self.b
            )
            logits_t = torch.mv(self.W_out, h) + self.b_out
            logits_list.append(logits_t.unsqueeze(0))

        return torch.cat(logits_list, dim=0)


# -------------------------------------
# 3. Example Data: "I go <EOS>" -> "मैं जाता हूँ <EOS>"
# -------------------------------------
ENG_VOCAB_SIZE = 3  # I=0, go=1, <EOS>=2
HIN_VOCAB_SIZE = 5  # <GO>=0, मैं=1, जाता=2, हूँ=3, <EOS>=4

# Map IDs to words for printing
HIN_ID2WORD = {
    0: "<GO>",
    1: "मैं",
    2: "जाता",
    3: "हूँ",
    4: "<EOS>"
}

EMBED_SIZE = 1
HIDDEN_SIZE = 2

encoder = TinyEncoder(ENG_VOCAB_SIZE, EMBED_SIZE, HIDDEN_SIZE)
decoder = TinyDecoder(HIN_VOCAB_SIZE, EMBED_SIZE, HIDDEN_SIZE)

# Source: "I go <EOS>" => [0,1,2]
encoder_input = torch.tensor([0,1,2])

# Decoder target: "मैं जाता हूँ <EOS>" => [1,2,3,4]
# We'll do teacher forcing in training:
decoder_input  = torch.tensor([0,1,2,3])  # <GO>, मैं, जाता, हूँ
decoder_target = torch.tensor([1,2,3,4])  #     मैं, जाता, हूँ, <EOS>

# ----------------------------------
# 4. Training Loop (Cross Entropy)
# ----------------------------------
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(list(encoder.parameters()) + list(decoder.parameters()), lr=0.5)

num_epochs = 5000
for epoch in range(num_epochs):
    optimizer.zero_grad()

    # 1) Encode
    enc_hidden = encoder(encoder_input)  # shape (2,)

    # 2) Decode
    logits = decoder(decoder_input, enc_hidden)  # (4,5)

    # 3) Compute cross-entropy
    loss = criterion(logits, decoder_target)

    # 4) Backprop + update
    loss.backward()
    optimizer.step()

    # Print stats
    if (epoch+1) % 5 == 0:
        print(f"Epoch {epoch+1}/{num_epochs}, Loss = {loss.item():.4f}")

    # ------------------------------
    # Print generated words every 20 epochs
    # ------------------------------
    if (epoch+1) % 20 == 0:
        print(f"\n--- Decoding after epoch {epoch+1} ---")
        with torch.no_grad():
            # Re-encode
            enc_hidden = encoder(encoder_input)

            # Start <GO>=0
            current_token = torch.tensor(0)
            h = enc_hidden.clone()

            generated_tokens = []
            for _ in range(6):
                x_t = decoder.embedding(current_token)
                h = torch.tanh(
                    torch.mv(decoder.W_h, h) +
                    torch.mv(decoder.W_x, x_t) +
                    decoder.b
                )

                logits_t = torch.mv(decoder.W_out, h) + decoder.b_out
                next_token = torch.argmax(logits_t).item()
                generated_tokens.append(next_token)

                if next_token == 4:  # <EOS>
                    break
                current_token = torch.tensor(next_token)

            # Convert IDs to words
            generated_words = [HIN_ID2WORD[t] for t in generated_tokens]
            print("Generated tokens:", generated_words)
        print("-----------------------------------\n")
# Out:
# Epoch 5/5000, Loss = 1.5082
# Epoch 10/5000, Loss = 1.3279
# Epoch 15/5000, Loss = 1.0741
# Epoch 20/5000, Loss = 0.9155
#
# --- Decoding after epoch 20 ---
# Generated tokens: ['मैं', 'हूँ', 'मैं', 'हूँ', 'मैं', 'हूँ']
# -----------------------------------
#
# Epoch 25/5000, Loss = 0.8037
# Epoch 30/5000, Loss = 0.6522
# Epoch 35/5000, Loss = 0.4441
# Epoch 40/5000, Loss = 0.2977
#
# --- Decoding after epoch 40 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 45/5000, Loss = 0.2163
# Epoch 50/5000, Loss = 0.1686
# Epoch 55/5000, Loss = 0.1381
# Epoch 60/5000, Loss = 0.1170
#
# --- Decoding after epoch 60 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 65/5000, Loss = 0.1016
# Epoch 70/5000, Loss = 0.0898
# Epoch 75/5000, Loss = 0.0805
# Epoch 80/5000, Loss = 0.0730
#
# --- Decoding after epoch 80 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 85/5000, Loss = 0.0667
# Epoch 90/5000, Loss = 0.0615
# Epoch 95/5000, Loss = 0.0570
# Epoch 100/5000, Loss = 0.0532
#
# --- Decoding after epoch 100 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 105/5000, Loss = 0.0498
# Epoch 110/5000, Loss = 0.0468
# Epoch 115/5000, Loss = 0.0442
# Epoch 120/5000, Loss = 0.0419
#
# --- Decoding after epoch 120 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 125/5000, Loss = 0.0398
# Epoch 130/5000, Loss = 0.0379
# Epoch 135/5000, Loss = 0.0361
# Epoch 140/5000, Loss = 0.0346
#
# --- Decoding after epoch 140 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 145/5000, Loss = 0.0331
# Epoch 150/5000, Loss = 0.0318
# Epoch 155/5000, Loss = 0.0306
# Epoch 160/5000, Loss = 0.0294
#
# --- Decoding after epoch 160 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 165/5000, Loss = 0.0284
# Epoch 170/5000, Loss = 0.0274
# Epoch 175/5000, Loss = 0.0265
# Epoch 180/5000, Loss = 0.0256
#
# --- Decoding after epoch 180 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 185/5000, Loss = 0.0248
# Epoch 190/5000, Loss = 0.0241
# Epoch 195/5000, Loss = 0.0234
# Epoch 200/5000, Loss = 0.0227
#
# --- Decoding after epoch 200 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 205/5000, Loss = 0.0221
# Epoch 210/5000, Loss = 0.0215
# Epoch 215/5000, Loss = 0.0209
# Epoch 220/5000, Loss = 0.0204
#
# --- Decoding after epoch 220 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 225/5000, Loss = 0.0199
# Epoch 230/5000, Loss = 0.0194
# Epoch 235/5000, Loss = 0.0189
# Epoch 240/5000, Loss = 0.0185
#
# --- Decoding after epoch 240 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 245/5000, Loss = 0.0180
# Epoch 250/5000, Loss = 0.0176
# Epoch 255/5000, Loss = 0.0173
# Epoch 260/5000, Loss = 0.0169
#
# --- Decoding after epoch 260 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 265/5000, Loss = 0.0165
# Epoch 270/5000, Loss = 0.0162
# Epoch 275/5000, Loss = 0.0159
# Epoch 280/5000, Loss = 0.0156
#
# --- Decoding after epoch 280 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 285/5000, Loss = 0.0153
# Epoch 290/5000, Loss = 0.0150
# Epoch 295/5000, Loss = 0.0147
# Epoch 300/5000, Loss = 0.0144
#
# --- Decoding after epoch 300 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 305/5000, Loss = 0.0142
# Epoch 310/5000, Loss = 0.0139
# Epoch 315/5000, Loss = 0.0137
# Epoch 320/5000, Loss = 0.0135
#
# --- Decoding after epoch 320 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 325/5000, Loss = 0.0132
# Epoch 330/5000, Loss = 0.0130
# Epoch 335/5000, Loss = 0.0128
# Epoch 340/5000, Loss = 0.0126
#
# --- Decoding after epoch 340 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 345/5000, Loss = 0.0124
# Epoch 350/5000, Loss = 0.0122
# Epoch 355/5000, Loss = 0.0120
# Epoch 360/5000, Loss = 0.0119
#
# --- Decoding after epoch 360 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 365/5000, Loss = 0.0117
# Epoch 370/5000, Loss = 0.0115
# Epoch 375/5000, Loss = 0.0113
# Epoch 380/5000, Loss = 0.0112
#
# --- Decoding after epoch 380 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 385/5000, Loss = 0.0110
# Epoch 390/5000, Loss = 0.0109
# Epoch 395/5000, Loss = 0.0107
# Epoch 400/5000, Loss = 0.0106
#
# --- Decoding after epoch 400 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 405/5000, Loss = 0.0105
# Epoch 410/5000, Loss = 0.0103
# Epoch 415/5000, Loss = 0.0102
# Epoch 420/5000, Loss = 0.0101
#
# --- Decoding after epoch 420 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 425/5000, Loss = 0.0099
# Epoch 430/5000, Loss = 0.0098
# Epoch 435/5000, Loss = 0.0097
# Epoch 440/5000, Loss = 0.0096
#
# --- Decoding after epoch 440 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 445/5000, Loss = 0.0095
# Epoch 450/5000, Loss = 0.0093
# Epoch 455/5000, Loss = 0.0092
# Epoch 460/5000, Loss = 0.0091
#
# --- Decoding after epoch 460 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 465/5000, Loss = 0.0090
# Epoch 470/5000, Loss = 0.0089
# Epoch 475/5000, Loss = 0.0088
# Epoch 480/5000, Loss = 0.0087
#
# --- Decoding after epoch 480 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 485/5000, Loss = 0.0086
# Epoch 490/5000, Loss = 0.0085
# Epoch 495/5000, Loss = 0.0085
# Epoch 500/5000, Loss = 0.0084
#
# --- Decoding after epoch 500 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 505/5000, Loss = 0.0083
# Epoch 510/5000, Loss = 0.0082
# Epoch 515/5000, Loss = 0.0081
# Epoch 520/5000, Loss = 0.0080
#
# --- Decoding after epoch 520 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 525/5000, Loss = 0.0079
# Epoch 530/5000, Loss = 0.0079
# Epoch 535/5000, Loss = 0.0078
# Epoch 540/5000, Loss = 0.0077
#
# --- Decoding after epoch 540 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 545/5000, Loss = 0.0076
# Epoch 550/5000, Loss = 0.0076
# Epoch 555/5000, Loss = 0.0075
# Epoch 560/5000, Loss = 0.0074
#
# --- Decoding after epoch 560 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 565/5000, Loss = 0.0074
# Epoch 570/5000, Loss = 0.0073
# Epoch 575/5000, Loss = 0.0072
# Epoch 580/5000, Loss = 0.0072
#
# --- Decoding after epoch 580 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 585/5000, Loss = 0.0071
# Epoch 590/5000, Loss = 0.0070
# Epoch 595/5000, Loss = 0.0070
# Epoch 600/5000, Loss = 0.0069
#
# --- Decoding after epoch 600 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 605/5000, Loss = 0.0068
# Epoch 610/5000, Loss = 0.0068
# Epoch 615/5000, Loss = 0.0067
# Epoch 620/5000, Loss = 0.0067
#
# --- Decoding after epoch 620 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 625/5000, Loss = 0.0066
# Epoch 630/5000, Loss = 0.0066
# Epoch 635/5000, Loss = 0.0065
# Epoch 640/5000, Loss = 0.0065
#
# --- Decoding after epoch 640 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 645/5000, Loss = 0.0064
# Epoch 650/5000, Loss = 0.0064
# Epoch 655/5000, Loss = 0.0063
# Epoch 660/5000, Loss = 0.0063
#
# --- Decoding after epoch 660 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 665/5000, Loss = 0.0062
# Epoch 670/5000, Loss = 0.0062
# Epoch 675/5000, Loss = 0.0061
# Epoch 680/5000, Loss = 0.0061
#
# --- Decoding after epoch 680 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 685/5000, Loss = 0.0060
# Epoch 690/5000, Loss = 0.0060
# Epoch 695/5000, Loss = 0.0059
# Epoch 700/5000, Loss = 0.0059
#
# --- Decoding after epoch 700 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 705/5000, Loss = 0.0058
# Epoch 710/5000, Loss = 0.0058
# Epoch 715/5000, Loss = 0.0058
# Epoch 720/5000, Loss = 0.0057
#
# --- Decoding after epoch 720 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 725/5000, Loss = 0.0057
# Epoch 730/5000, Loss = 0.0056
# Epoch 735/5000, Loss = 0.0056
# Epoch 740/5000, Loss = 0.0056
#
# --- Decoding after epoch 740 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 745/5000, Loss = 0.0055
# Epoch 750/5000, Loss = 0.0055
# Epoch 755/5000, Loss = 0.0054
# Epoch 760/5000, Loss = 0.0054
#
# --- Decoding after epoch 760 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 765/5000, Loss = 0.0054
# Epoch 770/5000, Loss = 0.0053
# Epoch 775/5000, Loss = 0.0053
# Epoch 780/5000, Loss = 0.0053
#
# --- Decoding after epoch 780 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 785/5000, Loss = 0.0052
# Epoch 790/5000, Loss = 0.0052
# Epoch 795/5000, Loss = 0.0052
# Epoch 800/5000, Loss = 0.0051
#
# --- Decoding after epoch 800 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 805/5000, Loss = 0.0051
# Epoch 810/5000, Loss = 0.0051
# Epoch 815/5000, Loss = 0.0050
# Epoch 820/5000, Loss = 0.0050
#
# --- Decoding after epoch 820 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 825/5000, Loss = 0.0050
# Epoch 830/5000, Loss = 0.0049
# Epoch 835/5000, Loss = 0.0049
# Epoch 840/5000, Loss = 0.0049
#
# --- Decoding after epoch 840 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 845/5000, Loss = 0.0048
# Epoch 850/5000, Loss = 0.0048
# Epoch 855/5000, Loss = 0.0048
# Epoch 860/5000, Loss = 0.0048
#
# --- Decoding after epoch 860 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 865/5000, Loss = 0.0047
# Epoch 870/5000, Loss = 0.0047
# Epoch 875/5000, Loss = 0.0047
# Epoch 880/5000, Loss = 0.0046
#
# --- Decoding after epoch 880 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 885/5000, Loss = 0.0046
# Epoch 890/5000, Loss = 0.0046
# Epoch 895/5000, Loss = 0.0046
# Epoch 900/5000, Loss = 0.0045
#
# --- Decoding after epoch 900 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 905/5000, Loss = 0.0045
# Epoch 910/5000, Loss = 0.0045
# Epoch 915/5000, Loss = 0.0045
# Epoch 920/5000, Loss = 0.0044
#
# --- Decoding after epoch 920 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 925/5000, Loss = 0.0044
# Epoch 930/5000, Loss = 0.0044
# Epoch 935/5000, Loss = 0.0044
# Epoch 940/5000, Loss = 0.0043
#
# --- Decoding after epoch 940 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 945/5000, Loss = 0.0043
# Epoch 950/5000, Loss = 0.0043
# Epoch 955/5000, Loss = 0.0043
# Epoch 960/5000, Loss = 0.0043
#
# --- Decoding after epoch 960 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 965/5000, Loss = 0.0042
# Epoch 970/5000, Loss = 0.0042
# Epoch 975/5000, Loss = 0.0042
# Epoch 980/5000, Loss = 0.0042
#
# --- Decoding after epoch 980 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 985/5000, Loss = 0.0041
# Epoch 990/5000, Loss = 0.0041
# Epoch 995/5000, Loss = 0.0041
# Epoch 1000/5000, Loss = 0.0041
#
# --- Decoding after epoch 1000 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 1005/5000, Loss = 0.0041
# Epoch 1010/5000, Loss = 0.0040
# Epoch 1015/5000, Loss = 0.0040
# Epoch 1020/5000, Loss = 0.0040
#
# --- Decoding after epoch 1020 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 1025/5000, Loss = 0.0040
# Epoch 1030/5000, Loss = 0.0040
# Epoch 1035/5000, Loss = 0.0039
# Epoch 1040/5000, Loss = 0.0039
#
# --- Decoding after epoch 1040 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 1045/5000, Loss = 0.0039
# Epoch 1050/5000, Loss = 0.0039
# Epoch 1055/5000, Loss = 0.0039
# Epoch 1060/5000, Loss = 0.0038
#
# --- Decoding after epoch 1060 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 1065/5000, Loss = 0.0038
# Epoch 1070/5000, Loss = 0.0038
# Epoch 1075/5000, Loss = 0.0038
# Epoch 1080/5000, Loss = 0.0038
#
# --- Decoding after epoch 1080 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 1085/5000, Loss = 0.0037
# Epoch 1090/5000, Loss = 0.0037
# Epoch 1095/5000, Loss = 0.0037
# Epoch 1100/5000, Loss = 0.0037
#
# --- Decoding after epoch 1100 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 1105/5000, Loss = 0.0037
# Epoch 1110/5000, Loss = 0.0037
# Epoch 1115/5000, Loss = 0.0036
# Epoch 1120/5000, Loss = 0.0036
#
# --- Decoding after epoch 1120 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 1125/5000, Loss = 0.0036
# Epoch 1130/5000, Loss = 0.0036
# Epoch 1135/5000, Loss = 0.0036
# Epoch 1140/5000, Loss = 0.0036
#
# --- Decoding after epoch 1140 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 1145/5000, Loss = 0.0035
# Epoch 1150/5000, Loss = 0.0035
# Epoch 1155/5000, Loss = 0.0035
# Epoch 1160/5000, Loss = 0.0035
#
# --- Decoding after epoch 1160 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 1165/5000, Loss = 0.0035
# Epoch 1170/5000, Loss = 0.0035
# Epoch 1175/5000, Loss = 0.0035
# Epoch 1180/5000, Loss = 0.0034
#
# --- Decoding after epoch 1180 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 1185/5000, Loss = 0.0034
# Epoch 1190/5000, Loss = 0.0034
# Epoch 1195/5000, Loss = 0.0034
# Epoch 1200/5000, Loss = 0.0034
#
# --- Decoding after epoch 1200 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 1205/5000, Loss = 0.0034
# Epoch 1210/5000, Loss = 0.0034
# Epoch 1215/5000, Loss = 0.0033
# Epoch 1220/5000, Loss = 0.0033
#
# --- Decoding after epoch 1220 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 1225/5000, Loss = 0.0033
# Epoch 1230/5000, Loss = 0.0033
# Epoch 1235/5000, Loss = 0.0033
# Epoch 1240/5000, Loss = 0.0033
#
# --- Decoding after epoch 1240 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 1245/5000, Loss = 0.0033
# Epoch 1250/5000, Loss = 0.0032
# Epoch 1255/5000, Loss = 0.0032
# Epoch 1260/5000, Loss = 0.0032
#
# --- Decoding after epoch 1260 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 1265/5000, Loss = 0.0032
# Epoch 1270/5000, Loss = 0.0032
# Epoch 1275/5000, Loss = 0.0032
# Epoch 1280/5000, Loss = 0.0032
#
# --- Decoding after epoch 1280 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 1285/5000, Loss = 0.0032
# Epoch 1290/5000, Loss = 0.0031
# Epoch 1295/5000, Loss = 0.0031
# Epoch 1300/5000, Loss = 0.0031
#
# --- Decoding after epoch 1300 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 1305/5000, Loss = 0.0031
# Epoch 1310/5000, Loss = 0.0031
# Epoch 1315/5000, Loss = 0.0031
# Epoch 1320/5000, Loss = 0.0031
#
# --- Decoding after epoch 1320 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 1325/5000, Loss = 0.0031
# Epoch 1330/5000, Loss = 0.0030
# Epoch 1335/5000, Loss = 0.0030
# Epoch 1340/5000, Loss = 0.0030
#
# --- Decoding after epoch 1340 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 1345/5000, Loss = 0.0030
# Epoch 1350/5000, Loss = 0.0030
# Epoch 1355/5000, Loss = 0.0030
# Epoch 1360/5000, Loss = 0.0030
#
# --- Decoding after epoch 1360 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 1365/5000, Loss = 0.0030
# Epoch 1370/5000, Loss = 0.0030
# Epoch 1375/5000, Loss = 0.0029
# Epoch 1380/5000, Loss = 0.0029
#
# --- Decoding after epoch 1380 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 1385/5000, Loss = 0.0029
# Epoch 1390/5000, Loss = 0.0029
# Epoch 1395/5000, Loss = 0.0029
# Epoch 1400/5000, Loss = 0.0029
#
# --- Decoding after epoch 1400 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 1405/5000, Loss = 0.0029
# Epoch 1410/5000, Loss = 0.0029
# Epoch 1415/5000, Loss = 0.0029
# Epoch 1420/5000, Loss = 0.0028
#
# --- Decoding after epoch 1420 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 1425/5000, Loss = 0.0028
# Epoch 1430/5000, Loss = 0.0028
# Epoch 1435/5000, Loss = 0.0028
# Epoch 1440/5000, Loss = 0.0028
#
# --- Decoding after epoch 1440 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 1445/5000, Loss = 0.0028
# Epoch 1450/5000, Loss = 0.0028
# Epoch 1455/5000, Loss = 0.0028
# Epoch 1460/5000, Loss = 0.0028
#
# --- Decoding after epoch 1460 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 1465/5000, Loss = 0.0028
# Epoch 1470/5000, Loss = 0.0028
# Epoch 1475/5000, Loss = 0.0027
# Epoch 1480/5000, Loss = 0.0027
#
# --- Decoding after epoch 1480 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 1485/5000, Loss = 0.0027
# Epoch 1490/5000, Loss = 0.0027
# Epoch 1495/5000, Loss = 0.0027
# Epoch 1500/5000, Loss = 0.0027
#
# --- Decoding after epoch 1500 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 1505/5000, Loss = 0.0027
# Epoch 1510/5000, Loss = 0.0027
# Epoch 1515/5000, Loss = 0.0027
# Epoch 1520/5000, Loss = 0.0027
#
# --- Decoding after epoch 1520 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 1525/5000, Loss = 0.0027
# Epoch 1530/5000, Loss = 0.0026
# Epoch 1535/5000, Loss = 0.0026
# Epoch 1540/5000, Loss = 0.0026
#
# --- Decoding after epoch 1540 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 1545/5000, Loss = 0.0026
# Epoch 1550/5000, Loss = 0.0026
# Epoch 1555/5000, Loss = 0.0026
# Epoch 1560/5000, Loss = 0.0026
#
# --- Decoding after epoch 1560 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 1565/5000, Loss = 0.0026
# Epoch 1570/5000, Loss = 0.0026
# Epoch 1575/5000, Loss = 0.0026
# Epoch 1580/5000, Loss = 0.0026
#
# --- Decoding after epoch 1580 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 1585/5000, Loss = 0.0025
# Epoch 1590/5000, Loss = 0.0025
# Epoch 1595/5000, Loss = 0.0025
# Epoch 1600/5000, Loss = 0.0025
#
# --- Decoding after epoch 1600 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 1605/5000, Loss = 0.0025
# Epoch 1610/5000, Loss = 0.0025
# Epoch 1615/5000, Loss = 0.0025
# Epoch 1620/5000, Loss = 0.0025
#
# --- Decoding after epoch 1620 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 1625/5000, Loss = 0.0025
# Epoch 1630/5000, Loss = 0.0025
# Epoch 1635/5000, Loss = 0.0025
# Epoch 1640/5000, Loss = 0.0025
#
# --- Decoding after epoch 1640 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 1645/5000, Loss = 0.0025
# Epoch 1650/5000, Loss = 0.0024
# Epoch 1655/5000, Loss = 0.0024
# Epoch 1660/5000, Loss = 0.0024
#
# --- Decoding after epoch 1660 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 1665/5000, Loss = 0.0024
# Epoch 1670/5000, Loss = 0.0024
# Epoch 1675/5000, Loss = 0.0024
# Epoch 1680/5000, Loss = 0.0024
#
# --- Decoding after epoch 1680 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 1685/5000, Loss = 0.0024
# Epoch 1690/5000, Loss = 0.0024
# Epoch 1695/5000, Loss = 0.0024
# Epoch 1700/5000, Loss = 0.0024
#
# --- Decoding after epoch 1700 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 1705/5000, Loss = 0.0024
# Epoch 1710/5000, Loss = 0.0024
# Epoch 1715/5000, Loss = 0.0024
# Epoch 1720/5000, Loss = 0.0023
#
# --- Decoding after epoch 1720 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 1725/5000, Loss = 0.0023
# Epoch 1730/5000, Loss = 0.0023
# Epoch 1735/5000, Loss = 0.0023
# Epoch 1740/5000, Loss = 0.0023
#
# --- Decoding after epoch 1740 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 1745/5000, Loss = 0.0023
# Epoch 1750/5000, Loss = 0.0023
# Epoch 1755/5000, Loss = 0.0023
# Epoch 1760/5000, Loss = 0.0023
#
# --- Decoding after epoch 1760 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 1765/5000, Loss = 0.0023
# Epoch 1770/5000, Loss = 0.0023
# Epoch 1775/5000, Loss = 0.0023
# Epoch 1780/5000, Loss = 0.0023
#
# --- Decoding after epoch 1780 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 1785/5000, Loss = 0.0023
# Epoch 1790/5000, Loss = 0.0023
# Epoch 1795/5000, Loss = 0.0022
# Epoch 1800/5000, Loss = 0.0022
#
# --- Decoding after epoch 1800 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 1805/5000, Loss = 0.0022
# Epoch 1810/5000, Loss = 0.0022
# Epoch 1815/5000, Loss = 0.0022
# Epoch 1820/5000, Loss = 0.0022
#
# --- Decoding after epoch 1820 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 1825/5000, Loss = 0.0022
# Epoch 1830/5000, Loss = 0.0022
# Epoch 1835/5000, Loss = 0.0022
# Epoch 1840/5000, Loss = 0.0022
#
# --- Decoding after epoch 1840 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 1845/5000, Loss = 0.0022
# Epoch 1850/5000, Loss = 0.0022
# Epoch 1855/5000, Loss = 0.0022
# Epoch 1860/5000, Loss = 0.0022
#
# --- Decoding after epoch 1860 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 1865/5000, Loss = 0.0022
# Epoch 1870/5000, Loss = 0.0022
# Epoch 1875/5000, Loss = 0.0021
# Epoch 1880/5000, Loss = 0.0021
#
# --- Decoding after epoch 1880 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 1885/5000, Loss = 0.0021
# Epoch 1890/5000, Loss = 0.0021
# Epoch 1895/5000, Loss = 0.0021
# Epoch 1900/5000, Loss = 0.0021
#
# --- Decoding after epoch 1900 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 1905/5000, Loss = 0.0021
# Epoch 1910/5000, Loss = 0.0021
# Epoch 1915/5000, Loss = 0.0021
# Epoch 1920/5000, Loss = 0.0021
#
# --- Decoding after epoch 1920 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 1925/5000, Loss = 0.0021
# Epoch 1930/5000, Loss = 0.0021
# Epoch 1935/5000, Loss = 0.0021
# Epoch 1940/5000, Loss = 0.0021
#
# --- Decoding after epoch 1940 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 1945/5000, Loss = 0.0021
# Epoch 1950/5000, Loss = 0.0021
# Epoch 1955/5000, Loss = 0.0021
# Epoch 1960/5000, Loss = 0.0021
#
# --- Decoding after epoch 1960 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 1965/5000, Loss = 0.0020
# Epoch 1970/5000, Loss = 0.0020
# Epoch 1975/5000, Loss = 0.0020
# Epoch 1980/5000, Loss = 0.0020
#
# --- Decoding after epoch 1980 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 1985/5000, Loss = 0.0020
# Epoch 1990/5000, Loss = 0.0020
# Epoch 1995/5000, Loss = 0.0020
# Epoch 2000/5000, Loss = 0.0020
#
# --- Decoding after epoch 2000 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 2005/5000, Loss = 0.0020
# Epoch 2010/5000, Loss = 0.0020
# Epoch 2015/5000, Loss = 0.0020
# Epoch 2020/5000, Loss = 0.0020
#
# --- Decoding after epoch 2020 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 2025/5000, Loss = 0.0020
# Epoch 2030/5000, Loss = 0.0020
# Epoch 2035/5000, Loss = 0.0020
# Epoch 2040/5000, Loss = 0.0020
#
# --- Decoding after epoch 2040 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 2045/5000, Loss = 0.0020
# Epoch 2050/5000, Loss = 0.0020
# Epoch 2055/5000, Loss = 0.0020
# Epoch 2060/5000, Loss = 0.0020
#
# --- Decoding after epoch 2060 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 2065/5000, Loss = 0.0019
# Epoch 2070/5000, Loss = 0.0019
# Epoch 2075/5000, Loss = 0.0019
# Epoch 2080/5000, Loss = 0.0019
#
# --- Decoding after epoch 2080 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 2085/5000, Loss = 0.0019
# Epoch 2090/5000, Loss = 0.0019
# Epoch 2095/5000, Loss = 0.0019
# Epoch 2100/5000, Loss = 0.0019
#
# --- Decoding after epoch 2100 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 2105/5000, Loss = 0.0019
# Epoch 2110/5000, Loss = 0.0019
# Epoch 2115/5000, Loss = 0.0019
# Epoch 2120/5000, Loss = 0.0019
#
# --- Decoding after epoch 2120 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 2125/5000, Loss = 0.0019
# Epoch 2130/5000, Loss = 0.0019
# Epoch 2135/5000, Loss = 0.0019
# Epoch 2140/5000, Loss = 0.0019
#
# --- Decoding after epoch 2140 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 2145/5000, Loss = 0.0019
# Epoch 2150/5000, Loss = 0.0019
# Epoch 2155/5000, Loss = 0.0019
# Epoch 2160/5000, Loss = 0.0019
#
# --- Decoding after epoch 2160 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 2165/5000, Loss = 0.0019
# Epoch 2170/5000, Loss = 0.0019
# Epoch 2175/5000, Loss = 0.0018
# Epoch 2180/5000, Loss = 0.0018
#
# --- Decoding after epoch 2180 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 2185/5000, Loss = 0.0018
# Epoch 2190/5000, Loss = 0.0018
# Epoch 2195/5000, Loss = 0.0018
# Epoch 2200/5000, Loss = 0.0018
#
# --- Decoding after epoch 2200 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 2205/5000, Loss = 0.0018
# Epoch 2210/5000, Loss = 0.0018
# Epoch 2215/5000, Loss = 0.0018
# Epoch 2220/5000, Loss = 0.0018
#
# --- Decoding after epoch 2220 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 2225/5000, Loss = 0.0018
# Epoch 2230/5000, Loss = 0.0018
# Epoch 2235/5000, Loss = 0.0018
# Epoch 2240/5000, Loss = 0.0018
#
# --- Decoding after epoch 2240 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 2245/5000, Loss = 0.0018
# Epoch 2250/5000, Loss = 0.0018
# Epoch 2255/5000, Loss = 0.0018
# Epoch 2260/5000, Loss = 0.0018
#
# --- Decoding after epoch 2260 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 2265/5000, Loss = 0.0018
# Epoch 2270/5000, Loss = 0.0018
# Epoch 2275/5000, Loss = 0.0018
# Epoch 2280/5000, Loss = 0.0018
#
# --- Decoding after epoch 2280 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 2285/5000, Loss = 0.0018
# Epoch 2290/5000, Loss = 0.0018
# Epoch 2295/5000, Loss = 0.0018
# Epoch 2300/5000, Loss = 0.0017
#
# --- Decoding after epoch 2300 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 2305/5000, Loss = 0.0017
# Epoch 2310/5000, Loss = 0.0017
# Epoch 2315/5000, Loss = 0.0017
# Epoch 2320/5000, Loss = 0.0017
#
# --- Decoding after epoch 2320 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 2325/5000, Loss = 0.0017
# Epoch 2330/5000, Loss = 0.0017
# Epoch 2335/5000, Loss = 0.0017
# Epoch 2340/5000, Loss = 0.0017
#
# --- Decoding after epoch 2340 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 2345/5000, Loss = 0.0017
# Epoch 2350/5000, Loss = 0.0017
# Epoch 2355/5000, Loss = 0.0017
# Epoch 2360/5000, Loss = 0.0017
#
# --- Decoding after epoch 2360 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 2365/5000, Loss = 0.0017
# Epoch 2370/5000, Loss = 0.0017
# Epoch 2375/5000, Loss = 0.0017
# Epoch 2380/5000, Loss = 0.0017
#
# --- Decoding after epoch 2380 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 2385/5000, Loss = 0.0017
# Epoch 2390/5000, Loss = 0.0017
# Epoch 2395/5000, Loss = 0.0017
# Epoch 2400/5000, Loss = 0.0017
#
# --- Decoding after epoch 2400 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 2405/5000, Loss = 0.0017
# Epoch 2410/5000, Loss = 0.0017
# Epoch 2415/5000, Loss = 0.0017
# Epoch 2420/5000, Loss = 0.0017
#
# --- Decoding after epoch 2420 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 2425/5000, Loss = 0.0017
# Epoch 2430/5000, Loss = 0.0017
# Epoch 2435/5000, Loss = 0.0017
# Epoch 2440/5000, Loss = 0.0016
#
# --- Decoding after epoch 2440 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 2445/5000, Loss = 0.0016
# Epoch 2450/5000, Loss = 0.0016
# Epoch 2455/5000, Loss = 0.0016
# Epoch 2460/5000, Loss = 0.0016
#
# --- Decoding after epoch 2460 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 2465/5000, Loss = 0.0016
# Epoch 2470/5000, Loss = 0.0016
# Epoch 2475/5000, Loss = 0.0016
# Epoch 2480/5000, Loss = 0.0016
#
# --- Decoding after epoch 2480 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 2485/5000, Loss = 0.0016
# Epoch 2490/5000, Loss = 0.0016
# Epoch 2495/5000, Loss = 0.0016
# Epoch 2500/5000, Loss = 0.0016
#
# --- Decoding after epoch 2500 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 2505/5000, Loss = 0.0016
# Epoch 2510/5000, Loss = 0.0016
# Epoch 2515/5000, Loss = 0.0016
# Epoch 2520/5000, Loss = 0.0016
#
# --- Decoding after epoch 2520 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 2525/5000, Loss = 0.0016
# Epoch 2530/5000, Loss = 0.0016
# Epoch 2535/5000, Loss = 0.0016
# Epoch 2540/5000, Loss = 0.0016
#
# --- Decoding after epoch 2540 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 2545/5000, Loss = 0.0016
# Epoch 2550/5000, Loss = 0.0016
# Epoch 2555/5000, Loss = 0.0016
# Epoch 2560/5000, Loss = 0.0016
#
# --- Decoding after epoch 2560 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 2565/5000, Loss = 0.0016
# Epoch 2570/5000, Loss = 0.0016
# Epoch 2575/5000, Loss = 0.0016
# Epoch 2580/5000, Loss = 0.0016
#
# --- Decoding after epoch 2580 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 2585/5000, Loss = 0.0016
# Epoch 2590/5000, Loss = 0.0016
# Epoch 2595/5000, Loss = 0.0015
# Epoch 2600/5000, Loss = 0.0015
#
# --- Decoding after epoch 2600 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 2605/5000, Loss = 0.0015
# Epoch 2610/5000, Loss = 0.0015
# Epoch 2615/5000, Loss = 0.0015
# Epoch 2620/5000, Loss = 0.0015
#
# --- Decoding after epoch 2620 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 2625/5000, Loss = 0.0015
# Epoch 2630/5000, Loss = 0.0015
# Epoch 2635/5000, Loss = 0.0015
# Epoch 2640/5000, Loss = 0.0015
#
# --- Decoding after epoch 2640 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 2645/5000, Loss = 0.0015
# Epoch 2650/5000, Loss = 0.0015
# Epoch 2655/5000, Loss = 0.0015
# Epoch 2660/5000, Loss = 0.0015
#
# --- Decoding after epoch 2660 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 2665/5000, Loss = 0.0015
# Epoch 2670/5000, Loss = 0.0015
# Epoch 2675/5000, Loss = 0.0015
# Epoch 2680/5000, Loss = 0.0015
#
# --- Decoding after epoch 2680 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 2685/5000, Loss = 0.0015
# Epoch 2690/5000, Loss = 0.0015
# Epoch 2695/5000, Loss = 0.0015
# Epoch 2700/5000, Loss = 0.0015
#
# --- Decoding after epoch 2700 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 2705/5000, Loss = 0.0015
# Epoch 2710/5000, Loss = 0.0015
# Epoch 2715/5000, Loss = 0.0015
# Epoch 2720/5000, Loss = 0.0015
#
# --- Decoding after epoch 2720 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 2725/5000, Loss = 0.0015
# Epoch 2730/5000, Loss = 0.0015
# Epoch 2735/5000, Loss = 0.0015
# Epoch 2740/5000, Loss = 0.0015
#
# --- Decoding after epoch 2740 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 2745/5000, Loss = 0.0015
# Epoch 2750/5000, Loss = 0.0015
# Epoch 2755/5000, Loss = 0.0015
# Epoch 2760/5000, Loss = 0.0015
#
# --- Decoding after epoch 2760 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 2765/5000, Loss = 0.0015
# Epoch 2770/5000, Loss = 0.0014
# Epoch 2775/5000, Loss = 0.0014
# Epoch 2780/5000, Loss = 0.0014
#
# --- Decoding after epoch 2780 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 2785/5000, Loss = 0.0014
# Epoch 2790/5000, Loss = 0.0014
# Epoch 2795/5000, Loss = 0.0014
# Epoch 2800/5000, Loss = 0.0014
#
# --- Decoding after epoch 2800 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 2805/5000, Loss = 0.0014
# Epoch 2810/5000, Loss = 0.0014
# Epoch 2815/5000, Loss = 0.0014
# Epoch 2820/5000, Loss = 0.0014
#
# --- Decoding after epoch 2820 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 2825/5000, Loss = 0.0014
# Epoch 2830/5000, Loss = 0.0014
# Epoch 2835/5000, Loss = 0.0014
# Epoch 2840/5000, Loss = 0.0014
#
# --- Decoding after epoch 2840 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 2845/5000, Loss = 0.0014
# Epoch 2850/5000, Loss = 0.0014
# Epoch 2855/5000, Loss = 0.0014
# Epoch 2860/5000, Loss = 0.0014
#
# --- Decoding after epoch 2860 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 2865/5000, Loss = 0.0014
# Epoch 2870/5000, Loss = 0.0014
# Epoch 2875/5000, Loss = 0.0014
# Epoch 2880/5000, Loss = 0.0014
#
# --- Decoding after epoch 2880 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 2885/5000, Loss = 0.0014
# Epoch 2890/5000, Loss = 0.0014
# Epoch 2895/5000, Loss = 0.0014
# Epoch 2900/5000, Loss = 0.0014
#
# --- Decoding after epoch 2900 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 2905/5000, Loss = 0.0014
# Epoch 2910/5000, Loss = 0.0014
# Epoch 2915/5000, Loss = 0.0014
# Epoch 2920/5000, Loss = 0.0014
#
# --- Decoding after epoch 2920 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 2925/5000, Loss = 0.0014
# Epoch 2930/5000, Loss = 0.0014
# Epoch 2935/5000, Loss = 0.0014
# Epoch 2940/5000, Loss = 0.0014
#
# --- Decoding after epoch 2940 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 2945/5000, Loss = 0.0014
# Epoch 2950/5000, Loss = 0.0014
# Epoch 2955/5000, Loss = 0.0014
# Epoch 2960/5000, Loss = 0.0014
#
# --- Decoding after epoch 2960 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 2965/5000, Loss = 0.0014
# Epoch 2970/5000, Loss = 0.0014
# Epoch 2975/5000, Loss = 0.0013
# Epoch 2980/5000, Loss = 0.0013
#
# --- Decoding after epoch 2980 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 2985/5000, Loss = 0.0013
# Epoch 2990/5000, Loss = 0.0013
# Epoch 2995/5000, Loss = 0.0013
# Epoch 3000/5000, Loss = 0.0013
#
# --- Decoding after epoch 3000 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 3005/5000, Loss = 0.0013
# Epoch 3010/5000, Loss = 0.0013
# Epoch 3015/5000, Loss = 0.0013
# Epoch 3020/5000, Loss = 0.0013
#
# --- Decoding after epoch 3020 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 3025/5000, Loss = 0.0013
# Epoch 3030/5000, Loss = 0.0013
# Epoch 3035/5000, Loss = 0.0013
# Epoch 3040/5000, Loss = 0.0013
#
# --- Decoding after epoch 3040 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 3045/5000, Loss = 0.0013
# Epoch 3050/5000, Loss = 0.0013
# Epoch 3055/5000, Loss = 0.0013
# Epoch 3060/5000, Loss = 0.0013
#
# --- Decoding after epoch 3060 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 3065/5000, Loss = 0.0013
# Epoch 3070/5000, Loss = 0.0013
# Epoch 3075/5000, Loss = 0.0013
# Epoch 3080/5000, Loss = 0.0013
#
# --- Decoding after epoch 3080 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 3085/5000, Loss = 0.0013
# Epoch 3090/5000, Loss = 0.0013
# Epoch 3095/5000, Loss = 0.0013
# Epoch 3100/5000, Loss = 0.0013
#
# --- Decoding after epoch 3100 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 3105/5000, Loss = 0.0013
# Epoch 3110/5000, Loss = 0.0013
# Epoch 3115/5000, Loss = 0.0013
# Epoch 3120/5000, Loss = 0.0013
#
# --- Decoding after epoch 3120 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 3125/5000, Loss = 0.0013
# Epoch 3130/5000, Loss = 0.0013
# Epoch 3135/5000, Loss = 0.0013
# Epoch 3140/5000, Loss = 0.0013
#
# --- Decoding after epoch 3140 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 3145/5000, Loss = 0.0013
# Epoch 3150/5000, Loss = 0.0013
# Epoch 3155/5000, Loss = 0.0013
# Epoch 3160/5000, Loss = 0.0013
#
# --- Decoding after epoch 3160 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 3165/5000, Loss = 0.0013
# Epoch 3170/5000, Loss = 0.0013
# Epoch 3175/5000, Loss = 0.0013
# Epoch 3180/5000, Loss = 0.0013
#
# --- Decoding after epoch 3180 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 3185/5000, Loss = 0.0013
# Epoch 3190/5000, Loss = 0.0013
# Epoch 3195/5000, Loss = 0.0013
# Epoch 3200/5000, Loss = 0.0013
#
# --- Decoding after epoch 3200 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 3205/5000, Loss = 0.0013
# Epoch 3210/5000, Loss = 0.0012
# Epoch 3215/5000, Loss = 0.0012
# Epoch 3220/5000, Loss = 0.0012
#
# --- Decoding after epoch 3220 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 3225/5000, Loss = 0.0012
# Epoch 3230/5000, Loss = 0.0012
# Epoch 3235/5000, Loss = 0.0012
# Epoch 3240/5000, Loss = 0.0012
#
# --- Decoding after epoch 3240 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 3245/5000, Loss = 0.0012
# Epoch 3250/5000, Loss = 0.0012
# Epoch 3255/5000, Loss = 0.0012
# Epoch 3260/5000, Loss = 0.0012
#
# --- Decoding after epoch 3260 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 3265/5000, Loss = 0.0012
# Epoch 3270/5000, Loss = 0.0012
# Epoch 3275/5000, Loss = 0.0012
# Epoch 3280/5000, Loss = 0.0012
#
# --- Decoding after epoch 3280 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 3285/5000, Loss = 0.0012
# Epoch 3290/5000, Loss = 0.0012
# Epoch 3295/5000, Loss = 0.0012
# Epoch 3300/5000, Loss = 0.0012
#
# --- Decoding after epoch 3300 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 3305/5000, Loss = 0.0012
# Epoch 3310/5000, Loss = 0.0012
# Epoch 3315/5000, Loss = 0.0012
# Epoch 3320/5000, Loss = 0.0012
#
# --- Decoding after epoch 3320 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 3325/5000, Loss = 0.0012
# Epoch 3330/5000, Loss = 0.0012
# Epoch 3335/5000, Loss = 0.0012
# Epoch 3340/5000, Loss = 0.0012
#
# --- Decoding after epoch 3340 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 3345/5000, Loss = 0.0012
# Epoch 3350/5000, Loss = 0.0012
# Epoch 3355/5000, Loss = 0.0012
# Epoch 3360/5000, Loss = 0.0012
#
# --- Decoding after epoch 3360 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 3365/5000, Loss = 0.0012
# Epoch 3370/5000, Loss = 0.0012
# Epoch 3375/5000, Loss = 0.0012
# Epoch 3380/5000, Loss = 0.0012
#
# --- Decoding after epoch 3380 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 3385/5000, Loss = 0.0012
# Epoch 3390/5000, Loss = 0.0012
# Epoch 3395/5000, Loss = 0.0012
# Epoch 3400/5000, Loss = 0.0012
#
# --- Decoding after epoch 3400 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 3405/5000, Loss = 0.0012
# Epoch 3410/5000, Loss = 0.0012
# Epoch 3415/5000, Loss = 0.0012
# Epoch 3420/5000, Loss = 0.0012
#
# --- Decoding after epoch 3420 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 3425/5000, Loss = 0.0012
# Epoch 3430/5000, Loss = 0.0012
# Epoch 3435/5000, Loss = 0.0012
# Epoch 3440/5000, Loss = 0.0012
#
# --- Decoding after epoch 3440 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 3445/5000, Loss = 0.0012
# Epoch 3450/5000, Loss = 0.0012
# Epoch 3455/5000, Loss = 0.0012
# Epoch 3460/5000, Loss = 0.0012
#
# --- Decoding after epoch 3460 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 3465/5000, Loss = 0.0012
# Epoch 3470/5000, Loss = 0.0012
# Epoch 3475/5000, Loss = 0.0012
# Epoch 3480/5000, Loss = 0.0012
#
# --- Decoding after epoch 3480 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 3485/5000, Loss = 0.0011
# Epoch 3490/5000, Loss = 0.0011
# Epoch 3495/5000, Loss = 0.0011
# Epoch 3500/5000, Loss = 0.0011
#
# --- Decoding after epoch 3500 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 3505/5000, Loss = 0.0011
# Epoch 3510/5000, Loss = 0.0011
# Epoch 3515/5000, Loss = 0.0011
# Epoch 3520/5000, Loss = 0.0011
#
# --- Decoding after epoch 3520 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 3525/5000, Loss = 0.0011
# Epoch 3530/5000, Loss = 0.0011
# Epoch 3535/5000, Loss = 0.0011
# Epoch 3540/5000, Loss = 0.0011
#
# --- Decoding after epoch 3540 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 3545/5000, Loss = 0.0011
# Epoch 3550/5000, Loss = 0.0011
# Epoch 3555/5000, Loss = 0.0011
# Epoch 3560/5000, Loss = 0.0011
#
# --- Decoding after epoch 3560 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 3565/5000, Loss = 0.0011
# Epoch 3570/5000, Loss = 0.0011
# Epoch 3575/5000, Loss = 0.0011
# Epoch 3580/5000, Loss = 0.0011
#
# --- Decoding after epoch 3580 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 3585/5000, Loss = 0.0011
# Epoch 3590/5000, Loss = 0.0011
# Epoch 3595/5000, Loss = 0.0011
# Epoch 3600/5000, Loss = 0.0011
#
# --- Decoding after epoch 3600 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 3605/5000, Loss = 0.0011
# Epoch 3610/5000, Loss = 0.0011
# Epoch 3615/5000, Loss = 0.0011
# Epoch 3620/5000, Loss = 0.0011
#
# --- Decoding after epoch 3620 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 3625/5000, Loss = 0.0011
# Epoch 3630/5000, Loss = 0.0011
# Epoch 3635/5000, Loss = 0.0011
# Epoch 3640/5000, Loss = 0.0011
#
# --- Decoding after epoch 3640 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 3645/5000, Loss = 0.0011
# Epoch 3650/5000, Loss = 0.0011
# Epoch 3655/5000, Loss = 0.0011
# Epoch 3660/5000, Loss = 0.0011
#
# --- Decoding after epoch 3660 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 3665/5000, Loss = 0.0011
# Epoch 3670/5000, Loss = 0.0011
# Epoch 3675/5000, Loss = 0.0011
# Epoch 3680/5000, Loss = 0.0011
#
# --- Decoding after epoch 3680 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 3685/5000, Loss = 0.0011
# Epoch 3690/5000, Loss = 0.0011
# Epoch 3695/5000, Loss = 0.0011
# Epoch 3700/5000, Loss = 0.0011
#
# --- Decoding after epoch 3700 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 3705/5000, Loss = 0.0011
# Epoch 3710/5000, Loss = 0.0011
# Epoch 3715/5000, Loss = 0.0011
# Epoch 3720/5000, Loss = 0.0011
#
# --- Decoding after epoch 3720 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 3725/5000, Loss = 0.0011
# Epoch 3730/5000, Loss = 0.0011
# Epoch 3735/5000, Loss = 0.0011
# Epoch 3740/5000, Loss = 0.0011
#
# --- Decoding after epoch 3740 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 3745/5000, Loss = 0.0011
# Epoch 3750/5000, Loss = 0.0011
# Epoch 3755/5000, Loss = 0.0011
# Epoch 3760/5000, Loss = 0.0011
#
# --- Decoding after epoch 3760 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 3765/5000, Loss = 0.0011
# Epoch 3770/5000, Loss = 0.0011
# Epoch 3775/5000, Loss = 0.0011
# Epoch 3780/5000, Loss = 0.0011
#
# --- Decoding after epoch 3780 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 3785/5000, Loss = 0.0011
# Epoch 3790/5000, Loss = 0.0011
# Epoch 3795/5000, Loss = 0.0011
# Epoch 3800/5000, Loss = 0.0011
#
# --- Decoding after epoch 3800 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 3805/5000, Loss = 0.0011
# Epoch 3810/5000, Loss = 0.0011
# Epoch 3815/5000, Loss = 0.0010
# Epoch 3820/5000, Loss = 0.0010
#
# --- Decoding after epoch 3820 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 3825/5000, Loss = 0.0010
# Epoch 3830/5000, Loss = 0.0010
# Epoch 3835/5000, Loss = 0.0010
# Epoch 3840/5000, Loss = 0.0010
#
# --- Decoding after epoch 3840 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 3845/5000, Loss = 0.0010
# Epoch 3850/5000, Loss = 0.0010
# Epoch 3855/5000, Loss = 0.0010
# Epoch 3860/5000, Loss = 0.0010
#
# --- Decoding after epoch 3860 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 3865/5000, Loss = 0.0010
# Epoch 3870/5000, Loss = 0.0010
# Epoch 3875/5000, Loss = 0.0010
# Epoch 3880/5000, Loss = 0.0010
#
# --- Decoding after epoch 3880 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 3885/5000, Loss = 0.0010
# Epoch 3890/5000, Loss = 0.0010
# Epoch 3895/5000, Loss = 0.0010
# Epoch 3900/5000, Loss = 0.0010
#
# --- Decoding after epoch 3900 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 3905/5000, Loss = 0.0010
# Epoch 3910/5000, Loss = 0.0010
# Epoch 3915/5000, Loss = 0.0010
# Epoch 3920/5000, Loss = 0.0010
#
# --- Decoding after epoch 3920 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 3925/5000, Loss = 0.0010
# Epoch 3930/5000, Loss = 0.0010
# Epoch 3935/5000, Loss = 0.0010
# Epoch 3940/5000, Loss = 0.0010
#
# --- Decoding after epoch 3940 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 3945/5000, Loss = 0.0010
# Epoch 3950/5000, Loss = 0.0010
# Epoch 3955/5000, Loss = 0.0010
# Epoch 3960/5000, Loss = 0.0010
#
# --- Decoding after epoch 3960 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 3965/5000, Loss = 0.0010
# Epoch 3970/5000, Loss = 0.0010
# Epoch 3975/5000, Loss = 0.0010
# Epoch 3980/5000, Loss = 0.0010
#
# --- Decoding after epoch 3980 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 3985/5000, Loss = 0.0010
# Epoch 3990/5000, Loss = 0.0010
# Epoch 3995/5000, Loss = 0.0010
# Epoch 4000/5000, Loss = 0.0010
#
# --- Decoding after epoch 4000 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 4005/5000, Loss = 0.0010
# Epoch 4010/5000, Loss = 0.0010
# Epoch 4015/5000, Loss = 0.0010
# Epoch 4020/5000, Loss = 0.0010
#
# --- Decoding after epoch 4020 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 4025/5000, Loss = 0.0010
# Epoch 4030/5000, Loss = 0.0010
# Epoch 4035/5000, Loss = 0.0010
# Epoch 4040/5000, Loss = 0.0010
#
# --- Decoding after epoch 4040 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 4045/5000, Loss = 0.0010
# Epoch 4050/5000, Loss = 0.0010
# Epoch 4055/5000, Loss = 0.0010
# Epoch 4060/5000, Loss = 0.0010
#
# --- Decoding after epoch 4060 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 4065/5000, Loss = 0.0010
# Epoch 4070/5000, Loss = 0.0010
# Epoch 4075/5000, Loss = 0.0010
# Epoch 4080/5000, Loss = 0.0010
#
# --- Decoding after epoch 4080 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 4085/5000, Loss = 0.0010
# Epoch 4090/5000, Loss = 0.0010
# Epoch 4095/5000, Loss = 0.0010
# Epoch 4100/5000, Loss = 0.0010
#
# --- Decoding after epoch 4100 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 4105/5000, Loss = 0.0010
# Epoch 4110/5000, Loss = 0.0010
# Epoch 4115/5000, Loss = 0.0010
# Epoch 4120/5000, Loss = 0.0010
#
# --- Decoding after epoch 4120 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 4125/5000, Loss = 0.0010
# Epoch 4130/5000, Loss = 0.0010
# Epoch 4135/5000, Loss = 0.0010
# Epoch 4140/5000, Loss = 0.0010
#
# --- Decoding after epoch 4140 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 4145/5000, Loss = 0.0010
# Epoch 4150/5000, Loss = 0.0010
# Epoch 4155/5000, Loss = 0.0010
# Epoch 4160/5000, Loss = 0.0010
#
# --- Decoding after epoch 4160 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 4165/5000, Loss = 0.0010
# Epoch 4170/5000, Loss = 0.0010
# Epoch 4175/5000, Loss = 0.0010
# Epoch 4180/5000, Loss = 0.0010
#
# --- Decoding after epoch 4180 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 4185/5000, Loss = 0.0010
# Epoch 4190/5000, Loss = 0.0010
# Epoch 4195/5000, Loss = 0.0010
# Epoch 4200/5000, Loss = 0.0010
#
# --- Decoding after epoch 4200 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 4205/5000, Loss = 0.0010
# Epoch 4210/5000, Loss = 0.0010
# Epoch 4215/5000, Loss = 0.0009
# Epoch 4220/5000, Loss = 0.0009
#
# --- Decoding after epoch 4220 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 4225/5000, Loss = 0.0009
# Epoch 4230/5000, Loss = 0.0009
# Epoch 4235/5000, Loss = 0.0009
# Epoch 4240/5000, Loss = 0.0009
#
# --- Decoding after epoch 4240 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 4245/5000, Loss = 0.0009
# Epoch 4250/5000, Loss = 0.0009
# Epoch 4255/5000, Loss = 0.0009
# Epoch 4260/5000, Loss = 0.0009
#
# --- Decoding after epoch 4260 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 4265/5000, Loss = 0.0009
# Epoch 4270/5000, Loss = 0.0009
# Epoch 4275/5000, Loss = 0.0009
# Epoch 4280/5000, Loss = 0.0009
#
# --- Decoding after epoch 4280 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 4285/5000, Loss = 0.0009
# Epoch 4290/5000, Loss = 0.0009
# Epoch 4295/5000, Loss = 0.0009
# Epoch 4300/5000, Loss = 0.0009
#
# --- Decoding after epoch 4300 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 4305/5000, Loss = 0.0009
# Epoch 4310/5000, Loss = 0.0009
# Epoch 4315/5000, Loss = 0.0009
# Epoch 4320/5000, Loss = 0.0009
#
# --- Decoding after epoch 4320 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 4325/5000, Loss = 0.0009
# Epoch 4330/5000, Loss = 0.0009
# Epoch 4335/5000, Loss = 0.0009
# Epoch 4340/5000, Loss = 0.0009
#
# --- Decoding after epoch 4340 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 4345/5000, Loss = 0.0009
# Epoch 4350/5000, Loss = 0.0009
# Epoch 4355/5000, Loss = 0.0009
# Epoch 4360/5000, Loss = 0.0009
#
# --- Decoding after epoch 4360 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 4365/5000, Loss = 0.0009
# Epoch 4370/5000, Loss = 0.0009
# Epoch 4375/5000, Loss = 0.0009
# Epoch 4380/5000, Loss = 0.0009
#
# --- Decoding after epoch 4380 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 4385/5000, Loss = 0.0009
# Epoch 4390/5000, Loss = 0.0009
# Epoch 4395/5000, Loss = 0.0009
# Epoch 4400/5000, Loss = 0.0009
#
# --- Decoding after epoch 4400 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 4405/5000, Loss = 0.0009
# Epoch 4410/5000, Loss = 0.0009
# Epoch 4415/5000, Loss = 0.0009
# Epoch 4420/5000, Loss = 0.0009
#
# --- Decoding after epoch 4420 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 4425/5000, Loss = 0.0009
# Epoch 4430/5000, Loss = 0.0009
# Epoch 4435/5000, Loss = 0.0009
# Epoch 4440/5000, Loss = 0.0009
#
# --- Decoding after epoch 4440 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 4445/5000, Loss = 0.0009
# Epoch 4450/5000, Loss = 0.0009
# Epoch 4455/5000, Loss = 0.0009
# Epoch 4460/5000, Loss = 0.0009
#
# --- Decoding after epoch 4460 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 4465/5000, Loss = 0.0009
# Epoch 4470/5000, Loss = 0.0009
# Epoch 4475/5000, Loss = 0.0009
# Epoch 4480/5000, Loss = 0.0009
#
# --- Decoding after epoch 4480 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 4485/5000, Loss = 0.0009
# Epoch 4490/5000, Loss = 0.0009
# Epoch 4495/5000, Loss = 0.0009
# Epoch 4500/5000, Loss = 0.0009
#
# --- Decoding after epoch 4500 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 4505/5000, Loss = 0.0009
# Epoch 4510/5000, Loss = 0.0009
# Epoch 4515/5000, Loss = 0.0009
# Epoch 4520/5000, Loss = 0.0009
#
# --- Decoding after epoch 4520 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 4525/5000, Loss = 0.0009
# Epoch 4530/5000, Loss = 0.0009
# Epoch 4535/5000, Loss = 0.0009
# Epoch 4540/5000, Loss = 0.0009
#
# --- Decoding after epoch 4540 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 4545/5000, Loss = 0.0009
# Epoch 4550/5000, Loss = 0.0009
# Epoch 4555/5000, Loss = 0.0009
# Epoch 4560/5000, Loss = 0.0009
#
# --- Decoding after epoch 4560 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 4565/5000, Loss = 0.0009
# Epoch 4570/5000, Loss = 0.0009
# Epoch 4575/5000, Loss = 0.0009
# Epoch 4580/5000, Loss = 0.0009
#
# --- Decoding after epoch 4580 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 4585/5000, Loss = 0.0009
# Epoch 4590/5000, Loss = 0.0009
# Epoch 4595/5000, Loss = 0.0009
# Epoch 4600/5000, Loss = 0.0009
#
# --- Decoding after epoch 4600 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 4605/5000, Loss = 0.0009
# Epoch 4610/5000, Loss = 0.0009
# Epoch 4615/5000, Loss = 0.0009
# Epoch 4620/5000, Loss = 0.0009
#
# --- Decoding after epoch 4620 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 4625/5000, Loss = 0.0009
# Epoch 4630/5000, Loss = 0.0009
# Epoch 4635/5000, Loss = 0.0009
# Epoch 4640/5000, Loss = 0.0009
#
# --- Decoding after epoch 4640 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 4645/5000, Loss = 0.0009
# Epoch 4650/5000, Loss = 0.0009
# Epoch 4655/5000, Loss = 0.0009
# Epoch 4660/5000, Loss = 0.0009
#
# --- Decoding after epoch 4660 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 4665/5000, Loss = 0.0009
# Epoch 4670/5000, Loss = 0.0009
# Epoch 4675/5000, Loss = 0.0009
# Epoch 4680/5000, Loss = 0.0009
#
# --- Decoding after epoch 4680 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 4685/5000, Loss = 0.0009
# Epoch 4690/5000, Loss = 0.0009
# Epoch 4695/5000, Loss = 0.0009
# Epoch 4700/5000, Loss = 0.0009
#
# --- Decoding after epoch 4700 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 4705/5000, Loss = 0.0009
# Epoch 4710/5000, Loss = 0.0008
# Epoch 4715/5000, Loss = 0.0008
# Epoch 4720/5000, Loss = 0.0008
#
# --- Decoding after epoch 4720 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 4725/5000, Loss = 0.0008
# Epoch 4730/5000, Loss = 0.0008
# Epoch 4735/5000, Loss = 0.0008
# Epoch 4740/5000, Loss = 0.0008
#
# --- Decoding after epoch 4740 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 4745/5000, Loss = 0.0008
# Epoch 4750/5000, Loss = 0.0008
# Epoch 4755/5000, Loss = 0.0008
# Epoch 4760/5000, Loss = 0.0008
#
# --- Decoding after epoch 4760 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 4765/5000, Loss = 0.0008
# Epoch 4770/5000, Loss = 0.0008
# Epoch 4775/5000, Loss = 0.0008
# Epoch 4780/5000, Loss = 0.0008
#
# --- Decoding after epoch 4780 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 4785/5000, Loss = 0.0008
# Epoch 4790/5000, Loss = 0.0008
# Epoch 4795/5000, Loss = 0.0008
# Epoch 4800/5000, Loss = 0.0008
#
# --- Decoding after epoch 4800 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 4805/5000, Loss = 0.0008
# Epoch 4810/5000, Loss = 0.0008
# Epoch 4815/5000, Loss = 0.0008
# Epoch 4820/5000, Loss = 0.0008
#
# --- Decoding after epoch 4820 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 4825/5000, Loss = 0.0008
# Epoch 4830/5000, Loss = 0.0008
# Epoch 4835/5000, Loss = 0.0008
# Epoch 4840/5000, Loss = 0.0008
#
# --- Decoding after epoch 4840 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 4845/5000, Loss = 0.0008
# Epoch 4850/5000, Loss = 0.0008
# Epoch 4855/5000, Loss = 0.0008
# Epoch 4860/5000, Loss = 0.0008
#
# --- Decoding after epoch 4860 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 4865/5000, Loss = 0.0008
# Epoch 4870/5000, Loss = 0.0008
# Epoch 4875/5000, Loss = 0.0008
# Epoch 4880/5000, Loss = 0.0008
#
# --- Decoding after epoch 4880 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 4885/5000, Loss = 0.0008
# Epoch 4890/5000, Loss = 0.0008
# Epoch 4895/5000, Loss = 0.0008
# Epoch 4900/5000, Loss = 0.0008
#
# --- Decoding after epoch 4900 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 4905/5000, Loss = 0.0008
# Epoch 4910/5000, Loss = 0.0008
# Epoch 4915/5000, Loss = 0.0008
# Epoch 4920/5000, Loss = 0.0008
#
# --- Decoding after epoch 4920 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 4925/5000, Loss = 0.0008
# Epoch 4930/5000, Loss = 0.0008
# Epoch 4935/5000, Loss = 0.0008
# Epoch 4940/5000, Loss = 0.0008
#
# --- Decoding after epoch 4940 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 4945/5000, Loss = 0.0008
# Epoch 4950/5000, Loss = 0.0008
# Epoch 4955/5000, Loss = 0.0008
# Epoch 4960/5000, Loss = 0.0008
#
# --- Decoding after epoch 4960 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 4965/5000, Loss = 0.0008
# Epoch 4970/5000, Loss = 0.0008
# Epoch 4975/5000, Loss = 0.0008
# Epoch 4980/5000, Loss = 0.0008
#
# --- Decoding after epoch 4980 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
#
# Epoch 4985/5000, Loss = 0.0008
# Epoch 4990/5000, Loss = 0.0008
# Epoch 4995/5000, Loss = 0.0008
# Epoch 5000/5000, Loss = 0.0008
#
# --- Decoding after epoch 5000 ---
# Generated tokens: ['मैं', 'जाता', 'हूँ', '<EOS>']
# -----------------------------------
